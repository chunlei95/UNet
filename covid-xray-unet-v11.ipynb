# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import random

import numpy as np
import torch
import torchvision.transforms
import torchvision.transforms.functional as Func


class ToPILImage(object):
    def __call__(self, image, target=None):
        image = Func.to_pil_image(image)
        if target is not None:
            target = Func.to_pil_image(target)
        return image, target


class RandomCrop(object):
    def __init__(self, size):
        self.size = size

    def __call__(self, image, target=None):
        seed = np.random.randint(65536)
        torch.manual_seed(seed)
        crop = torchvision.transforms.RandomCrop(self.size)
        image = crop(image)
        if target is not None:
            target = crop(target)
        return image, target


class Resize(object):
    def __init__(self, size):
        super(Resize, self).__init__()
        self.size = size

    def __call__(self, image, target=None):
        image = Func.resize(image, self.size)
        if target is not None:
            target = Func.resize(target, self.size, interpolation=Func.InterpolationMode.NEAREST)
        return image, target


class RandomHorizontalFlip(object):
    def __init__(self, flip_prob=0.5):
        self.flip_prob = flip_prob

    def __call__(self, image, target=None):
        if random.random() < self.flip_prob:
            image = Func.hflip(image)
            if target is not None:
                target = Func.hflip(target)
        return image, target


class ColorJitter(object):
    def __call__(self, image, target):
        color_jitter = torchvision.transforms.ColorJitter()
        image = color_jitter(image)
        return image, target


class GrayScale(object):
    def __call__(self, image, target):
        gray_scale = torchvision.transforms.Grayscale()
        image = gray_scale(image)
        return image, target


class RandomRotation(object):
    def __init__(self, degrees):
        super(RandomRotation, self).__init__()
        self.degrees = degrees

    def __call__(self, image, target=None):
        degree = random.randint(self.degrees[0], self.degrees[1])
        image = Func.rotate(image, degree)
        if target is not None:
            target = Func.rotate(target, degree)
        return image, target


class Normalize(object):
    def __init__(self, mean, std):
        super(Normalize, self).__init__()
        self.mean = mean
        self.std = std

    def __call__(self, image, target):
        image = Func.normalize(image, mean=self.mean, std=self.std)
        return image, target


class ToTensor(object):
    def __call__(self, image, target=None):
        image = Func.to_tensor(image)
        if target is not None:
            target = torch.as_tensor(np.array(target), dtype=torch.int64)
        return image, target


class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target

# %%
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Dataset

class CustomDataset(Dataset):
    def __init__(self, data_path, target_path, transforms=None):
        super(CustomDataset, self).__init__()
        self.data_paths = data_path
        self.target_paths = target_path
        self.transforms = transforms

    def __getitem__(self, item):

        image = plt.imread(self.data_paths[item])
        target = plt.imread(self.target_paths[item])

        image = np.expand_dims(image, axis=-1)

        # image = torch.from_numpy(image)
        # target = torch.from_numpy(target)

        if self.transforms is not None:
            image, target = self.transforms(image, target)
        return image, target

    def __len__(self):
        return len(self.data_paths)


def load_data(data_path, target_path, batch_size, drop_last=False, transforms=None):
    datas = CustomDataset(data_path=data_path, target_path=target_path, transforms=transforms)
    data_loader = DataLoader(datas, shuffle=True, batch_size=batch_size, drop_last=drop_last)
    return data_loader

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.transforms.functional as functional


class UNet(nn.Module):
    """U-Net模型的pytorch实现。
    论文地址：https://arxiv.org/abs/1505.04597
    模型的总体结构: 编码器 -> 一个ConvBlock -> 解码器 -> 一个Conv 1 * 1
    """

    def __init__(self):
        super(UNet, self).__init__()
        # 编码器部分
        self.eb1 = EncoderBlock(1, 64, 64, kernel_size=2)
        self.eb2 = EncoderBlock(64, 128, 128, kernel_size=2)
        self.eb3 = EncoderBlock(128, 256, 256, kernel_size=2)
        self.eb4 = EncoderBlock(256, 512, 512, kernel_size=2)
        # 编码器与解码器之间有一个ConvBlock
        self.cb = ConvBlock(512, 1024, 1024)
        # 解码器部分
        self.db1 = DecoderBlock(1024, 512, 512)
        self.db2 = DecoderBlock(512, 512, 256)
        self.db3 = DecoderBlock(256, 128, 128)
        self.db4 = DecoderBlock(128, 64, 64)
        # 一个Conv 1 * 1, 二分类，结果为两个通道
        self.conv1x1 = nn.Conv2d(64, 2, kernel_size=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        ex1, skip_x1 = self.eb1(x)
        ex2, skip_x2 = self.eb2(ex1)
        ex3, skip_x3 = self.eb3(ex2)
        ex4, skip_x4 = self.eb4(ex3)
        cbx = self.cb(ex4)
        dx1 = self.db1(cbx, skip_x4)
        dx2 = self.db2(dx1, skip_x3)
        dx3 = self.db3(dx2, skip_x2)
        dx4 = self.db4(dx3, skip_x1)
        crop = transforms.CenterCrop(size=(x.shape[-1], x.shape[-2]))
        # normalize = transforms.Normalize((0.5,), (0.5,))
        return self.sigmoid(self.conv1x1(crop(dx4)))


class ConvBlock(nn.Module):
    """一个Conv2d卷积后跟一个Relu激活函数，卷积核大小为3 * 3

    :param in_channels: 层次块的输入通道数
    :param mid_channels: 层次块中间一层卷积的通道数
    :param out_channels: 层次块输出层的通道数
    """

    def __init__(self, in_channels, mid_channels, out_channels):
        super(ConvBlock, self).__init__()
        conv_relu_list = [nn.Conv2d(in_channels=in_channels, out_channels=mid_channels, kernel_size=2),
                          nn.BatchNorm2d(mid_channels),
                          nn.ReLU(inplace=True),
                          nn.Conv2d(in_channels=mid_channels, out_channels=out_channels, kernel_size=2),
                          nn.BatchNorm2d(out_channels),
                          nn.ReLU(inplace=True)]
        self.conv_relu = nn.Sequential(*conv_relu_list)

    def forward(self, x):
        return self.conv_relu(x)


class DownSampling(nn.Module):
    """下采样，使用max pool方法执行，核大小为 2 * 2，用在编码器的ConvBlock后面

    :param kernel_size: 下采样层（即最大池化层）的核大小
    """

    def __init__(self, kernel_size):
        super(DownSampling, self).__init__()
        self.down_sample = nn.MaxPool2d(kernel_size=kernel_size)

    def forward(self, x):
        return self.down_sample(x)


class UpSampling(nn.Module):
    """上采样，用在解码器的ConvBlock前面，使用转置卷积，同时通道数减半，

    C_out = out_channels
    H_out = (H_in - 1) * stride - 2 * padding + dilation * (kernel_size - 1) + output_padding + 1
    W_out = (W_in - 1) * stride - 2 * padding + dilation * (kernel_size - 1) + output_padding + 1

    :param in_channels: 转置卷积的输入通道数
    :param out_channels: 转置卷积的输出通道数
    :param kernel_size: 转置卷积的卷积核大小，默认为2
    :param stride: 转置卷积的步幅，默认为2
    """

    def __init__(self, in_channels, out_channels, kernel_size=7, stride=2, dilation=1, padding=0, output_padding=1):
        super(UpSampling, self).__init__()
        # self.up_sample = nn.Upsample(scale_factor=scale_factor, mode='bilinear')
        # stride=2, kernel_size=2相当于宽高翻倍
        self.up_sample = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride,
                                            dilation=dilation, padding=padding, output_padding=output_padding)

    def forward(self, x):
        return self.up_sample(x)


class EncoderBlock(nn.Module):
    """编码器中的一个层次块

    :param in_channels: 层次块的输入通道数
    :param mid_channels: 层次块中间一层卷积的通道数
    :param out_channels: 层次块输出层的通道数
    :param kernel_size: 下采样层（即最大池化层）的核大小
    """

    def __init__(self, in_channels, mid_channels, out_channels, kernel_size):
        super(EncoderBlock, self).__init__()
        self.conv_block = ConvBlock(in_channels, mid_channels, out_channels)
        self.down_sample = DownSampling(kernel_size)

    def forward(self, x):
        x1 = self.conv_block(x)
        return self.down_sample(x1), x1


class ConcatLayer(nn.Module):
    """跳跃连接，在通道维上连接

    """

    def __init__(self):
        super(ConcatLayer, self).__init__()

    def forward(self, x, skip_x):
        # 将从编码器传过来的特征图裁剪到与输入相同尺寸
        x1 = functional.center_crop(skip_x, [x.shape[-2], x.shape[-1]])
        if x1.shape != x.shape:
            raise Exception('要连接的两个特征图尺寸不一致，skip_x.shape={}，x.shape={}'.format(skip_x.shape, x.shape))
        # 通道维连接
        return torch.cat([x, x1], dim=1)


class DecoderBlock(nn.Module):
    """解码器中的层次块，每个层次块都是UpSampling -> Concat -> ConvBlock

    :param in_channels: 层次块的输入通道数
    :param mid_channels: 层次块中间一层卷积的通道数
    :param out_channels: 层次块输出层的通道数
    """

    def __init__(self, in_channels, mid_channels, out_channels):
        super(DecoderBlock, self).__init__()
        self.up_sample = UpSampling(in_channels, out_channels)
        self.conv_block = ConvBlock(in_channels, mid_channels, out_channels)

    def forward(self, x, skip_x):
        x1 = self.up_sample(x)
        concat = ConcatLayer()
        x2 = concat(x1, skip_x)
        return self.conv_block(x2)

# %%
def dice_coef(predict, target, ep=1e-8):
    """dice相似系数（值域为[0,1]），也称为重叠指数，表示两个物体相交的面积占总面积的比值
    用于相似性评估

    :param ep: 平滑系数
    :param predict: 预测值
    :param target: 目标值
    :return: 相似系数
    """
    num = predict.size(0)
    pre = predict.view(num, -1)
    tar = target.view(num, -1)
    intersection = (pre * tar).sum()
    return (2. * intersection + ep) / (pre.sum() + tar.sum() + ep)


class DiceLoss(nn.Module):
    """Dice相似系数损失函数，训练过程可能出现不稳定的情况

    """

    def __init__(self, ep=1e-8):
        super(DiceLoss, self).__init__()
        self.epsilon = ep

    def forward(self, predict, target):
        score = dice_coef(predict, target, self.epsilon)
        return 1 - score

# %%
from argparse import ArgumentParser
from glob import glob

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


# noinspection PyShadowingNames,SpellCheckingInspection
def train(train_loader, valid_loader, model, criterion, optimizer, total_epoch, current_epoch=0, num_classes=2,
          device='cpu'):
    model.to(device)
    criterion.to(device)
    loss_change_list = []
    valid_loss_change_list = []
    saved_last = {}
    saved_best = {}
    loss_change = {}

    search_best = SearchBest()

    for i in range(current_epoch, total_epoch):
        model.train()
        total_loss = 0.0
        for index, (x, y) in enumerate(train_loader):
            x = x.to(device)
            y = y.to(device)
#             y_onehot = convert_to_one_hot(y, num_classes=num_classes)
            predict = model(x)
            
            predict_mask = torch.max(predict, dim=1)[1].to(torch.float32)
            y = y.to(torch.float32)
            
            loss_value = criterion(predict_mask, y)
            loss_value.requires_grad_(True)
            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()

            total_loss += loss_value.item()
            print('Epoch {}: Batch {}/{} loss: {:.4f}'.format(i + 1, index + 1, len(train_loader), loss_value.item()))

        loss_change_list.append(total_loss / len(train_loader))
        valid_avg_loss = valid(model, criterion, valid_loader, num_classes, device)
        valid_loss_change_list.append(valid_avg_loss)
        print('Epoch {} train loss: {:.4f} valid loss: {:.4f}'.format(i + 1, total_loss / len(train_loader),
                                                                      valid_avg_loss))
        search_best(valid_avg_loss)
        if search_best.counter == 0:
            # save the relevant params of the best model state in the current time.
            saved_best['best_model_state_dict'] = model.state_dict()
            saved_best['best_optimizer_state_dict'] = optimizer.state_dict()
            saved_best['epoch'] = i + 1
    loss_change['train_loss_change_history'] = loss_change_list
    loss_change['valid_loss_change_history'] = valid_loss_change_list
    saved_last['last_model_state_dict'] = model.state_dict()
    saved_last['last_optimizer_state_dict'] = optimizer.state_dict()
    saved_last['epoch'] = total_epoch
    torch.save(saved_best, './best_model.pth')
    torch.save(saved_last, './last_model.pth')
    torch.save(loss_change, './loss_change.pth')


def convert_to_one_hot(data, num_classes):
    if type(data) is not torch.Tensor:
        raise RuntimeError('data must be a torch.Tensor')
    if data.dtype is not torch.int64:
        data = data.to(torch.int64)
    data = F.one_hot(data, num_classes=num_classes).permute((0, -1, 1, 2))
    return data.to(torch.float32)


class SearchBest(object):
    def __init__(self, min_delta=0, verbose=True):
        super(SearchBest, self).__init__()
        self.counter = 0
        self.min_delta = min_delta
        self.best_score = None
        self.verbose = verbose

    def __call__(self, valid_loss):
        if self.best_score is None:
            self.best_score = valid_loss
        elif self.best_score - valid_loss >= self.min_delta:
            self.best_score = valid_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print('performance reducing: {}'.format(self.counter))


# noinspection PyShadowingNames
def valid(model, criterion, valid_loader, num_classes, device):
    """
    :return: validate loss
    """
    model.eval()
    valid_total_loss = 0.0
    for index, (x, y) in enumerate(valid_loader):
        x = x.to(device)
        y = y.to(device)
#         y_onehot = convert_to_one_hot(y, num_classes)
        with torch.no_grad():
            predict = model(x)
            predict = torch.max(predict, dim=1)[1]
            predict_mask = predict.to(torch.float32)
            y = y.to(torch.float32)
            valid_loss = criterion(predict_mask, y)
            valid_total_loss += valid_loss.item()
    return valid_total_loss / len(valid_loader)

# %%
if __name__ == '__main__':
    lr = 3e-4
    
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = UNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.5, 0.999))
    
    # 后面修改为Dice损失函数看看效果
    criterion = DiceLoss()

    train_image_path = glob('../input/d/chunlei11/covid19xray/covid19-xray/train/images/*')
    train_mask_path = glob('../input/d/chunlei11/covid19xray/covid19-xray/train/masks/*')
    
    val_image_path = glob('../input/d/chunlei11/covid19xray/covid19-xray/val/images/*')
    val_mask_path = glob('../input/d/chunlei11/covid19xray/covid19-xray/val/masks/*')

    train_transforms = Compose([
        # todo 先Resize试一下
        ToPILImage(),
        RandomHorizontalFlip(),
        RandomRotation(degrees=(0, 180)),
#         ColorJitter(), # 这个有问题，但是是什么问题？
#         GrayScale(), # 这个貌似也有问题，问题更大
        RandomCrop(256),
        ToTensor(),
        Normalize((0.5,), (0.5,))
    ])
    valid_transforms = Compose([
        ToPILImage(),
        Resize(256),
        ToTensor(),
        Normalize((0.5,), (0.5,))
    ])
    
    train_loader = load_data(train_image_path, train_mask_path, batch_size=16, drop_last=True,
                             transforms=train_transforms)
    valid_loader = load_data(val_image_path, val_mask_path, batch_size=16, transforms=valid_transforms)
    
    continue_train = False
    
    if not continue_train:
        epoch = 180
        train(train_loader, valid_loader, model, criterion, optimizer, epoch, device=device)
    else:
        total_epoch = 200
        pretrain_params = torch.load('../input/covid-xray-unet/last_model.pth')
        model.load_state_dict(pretrain_params['last_model_state_dict'])
        optimizer.load_state_dict(pretrain_params['last_optimizer_state_dict'])
        current_epoch = pretrain_params['epoch']
        model.train()
        train(train_loader, valid_loader, model, criterion, optimizer, total_epoch, current_epoch, device=device)
# Out:
# Epoch 1: Batch 1/233 loss: 0.8902
# Epoch 1: Batch 2/233 loss: 0.9234
# Epoch 1: Batch 3/233 loss: 0.8878
# Epoch 1: Batch 4/233 loss: 0.8584
# Epoch 1: Batch 5/233 loss: 0.8746
# Epoch 1: Batch 6/233 loss: 0.9032
# Epoch 1: Batch 7/233 loss: 0.9354
# Epoch 1: Batch 8/233 loss: 0.8925
# Epoch 1: Batch 9/233 loss: 0.8630
# Epoch 1: Batch 10/233 loss: 0.8484
# Epoch 1: Batch 11/233 loss: 0.9897
# Epoch 1: Batch 12/233 loss: 0.8945
# Epoch 1: Batch 13/233 loss: 0.9103
# Epoch 1: Batch 14/233 loss: 0.9631
# Epoch 1: Batch 15/233 loss: 0.9050
# Epoch 1: Batch 16/233 loss: 0.9211
# Epoch 1: Batch 17/233 loss: 0.8705
# Epoch 1: Batch 18/233 loss: 0.8932
# Epoch 1: Batch 19/233 loss: 0.9883
# Epoch 1: Batch 20/233 loss: 0.9293
# Epoch 1: Batch 21/233 loss: 0.8971
# Epoch 1: Batch 22/233 loss: 0.8518
# Epoch 1: Batch 23/233 loss: 0.8614
# Epoch 1: Batch 24/233 loss: 0.8535
# Epoch 1: Batch 25/233 loss: 0.9176
# Epoch 1: Batch 26/233 loss: 0.8894
# Epoch 1: Batch 27/233 loss: 0.9312
# Epoch 1: Batch 28/233 loss: 0.9770
# Epoch 1: Batch 29/233 loss: 0.8951
# Epoch 1: Batch 30/233 loss: 0.9082
# Epoch 1: Batch 31/233 loss: 0.7742
# Epoch 1: Batch 32/233 loss: 0.9704
# Epoch 1: Batch 33/233 loss: 0.9385
# Epoch 1: Batch 34/233 loss: 0.8558
# Epoch 1: Batch 35/233 loss: 0.8885
# Epoch 1: Batch 36/233 loss: 0.8903
# Epoch 1: Batch 37/233 loss: 0.8711
# Epoch 1: Batch 38/233 loss: 0.9277
# Epoch 1: Batch 39/233 loss: 0.9171
# Epoch 1: Batch 40/233 loss: 0.8871
# Epoch 1: Batch 41/233 loss: 0.9159
# Epoch 1: Batch 42/233 loss: 0.8450
# Epoch 1: Batch 43/233 loss: 0.9494
# Epoch 1: Batch 44/233 loss: 0.8711
# Epoch 1: Batch 45/233 loss: 0.8299
# Epoch 1: Batch 46/233 loss: 0.9121
# Epoch 1: Batch 47/233 loss: 0.8135
# Epoch 1: Batch 48/233 loss: 0.9293
# Epoch 1: Batch 49/233 loss: 0.9136
# Epoch 1: Batch 50/233 loss: 0.9020
# Epoch 1: Batch 51/233 loss: 0.8846
# Epoch 1: Batch 52/233 loss: 0.8545
# Epoch 1: Batch 53/233 loss: 0.8403
# Epoch 1: Batch 54/233 loss: 0.8674
# Epoch 1: Batch 55/233 loss: 0.9194
# Epoch 1: Batch 56/233 loss: 0.8961
# Epoch 1: Batch 57/233 loss: 0.8901
# Epoch 1: Batch 58/233 loss: 0.8851
# Epoch 1: Batch 59/233 loss: 0.9230
# Epoch 1: Batch 60/233 loss: 0.8806
# Epoch 1: Batch 61/233 loss: 0.8849
# Epoch 1: Batch 62/233 loss: 0.8639
# Epoch 1: Batch 63/233 loss: 0.8670
# Epoch 1: Batch 64/233 loss: 0.8872
# Epoch 1: Batch 65/233 loss: 0.8915
# Epoch 1: Batch 66/233 loss: 0.8579
# Epoch 1: Batch 67/233 loss: 0.8186
# Epoch 1: Batch 68/233 loss: 0.8448
# Epoch 1: Batch 69/233 loss: 0.8994
# Epoch 1: Batch 70/233 loss: 0.8828
# Epoch 1: Batch 71/233 loss: 0.8015
# Epoch 1: Batch 72/233 loss: 0.8552
# Epoch 1: Batch 73/233 loss: 0.9157
# Epoch 1: Batch 74/233 loss: 0.8293
# Epoch 1: Batch 75/233 loss: 0.9063
# Epoch 1: Batch 76/233 loss: 0.9681
# Epoch 1: Batch 77/233 loss: 0.9122
# Epoch 1: Batch 78/233 loss: 0.9380
# Epoch 1: Batch 79/233 loss: 0.9146
# Epoch 1: Batch 80/233 loss: 0.8765
# Epoch 1: Batch 81/233 loss: 0.8538
# Epoch 1: Batch 82/233 loss: 0.8816
# Epoch 1: Batch 83/233 loss: 0.9483
# Epoch 1: Batch 84/233 loss: 0.9079
# Epoch 1: Batch 85/233 loss: 0.8506
# Epoch 1: Batch 86/233 loss: 0.7988
# Epoch 1: Batch 87/233 loss: 0.8689
# Epoch 1: Batch 88/233 loss: 0.8312
# Epoch 1: Batch 89/233 loss: 0.9064
# Epoch 1: Batch 90/233 loss: 0.9276
# Epoch 1: Batch 91/233 loss: 0.8783
# Epoch 1: Batch 92/233 loss: 0.8792
# Epoch 1: Batch 93/233 loss: 0.8627
# Epoch 1: Batch 94/233 loss: 0.9739
# Epoch 1: Batch 95/233 loss: 0.9070
# Epoch 1: Batch 96/233 loss: 0.8656
# Epoch 1: Batch 97/233 loss: 0.9095
# Epoch 1: Batch 98/233 loss: 0.8555
# Epoch 1: Batch 99/233 loss: 0.8719
# Epoch 1: Batch 100/233 loss: 0.9433
# Epoch 1: Batch 101/233 loss: 0.8897
# Epoch 1: Batch 102/233 loss: 0.9038
# Epoch 1: Batch 103/233 loss: 0.8941
# Epoch 1: Batch 104/233 loss: 0.8836
# Epoch 1: Batch 105/233 loss: 0.8092
# Epoch 1: Batch 106/233 loss: 0.9305
# Epoch 1: Batch 107/233 loss: 0.9280
# Epoch 1: Batch 108/233 loss: 0.8764
# Epoch 1: Batch 109/233 loss: 0.8613
# Epoch 1: Batch 110/233 loss: 0.8087
# Epoch 1: Batch 111/233 loss: 0.8453
# Epoch 1: Batch 112/233 loss: 0.9411
# Epoch 1: Batch 113/233 loss: 0.8991
# Epoch 1: Batch 114/233 loss: 0.9231
# Epoch 1: Batch 115/233 loss: 0.9376
# Epoch 1: Batch 116/233 loss: 0.8272
# Epoch 1: Batch 117/233 loss: 0.8571
# Epoch 1: Batch 118/233 loss: 0.9186
# Epoch 1: Batch 119/233 loss: 0.9471
# Epoch 1: Batch 120/233 loss: 0.8693
# Epoch 1: Batch 121/233 loss: 0.7905
# Epoch 1: Batch 122/233 loss: 0.8341
# Epoch 1: Batch 123/233 loss: 0.8517
# Epoch 1: Batch 124/233 loss: 0.9368
# Epoch 1: Batch 125/233 loss: 0.8935
# Epoch 1: Batch 126/233 loss: 0.8713
# Epoch 1: Batch 127/233 loss: 0.9325
# Epoch 1: Batch 128/233 loss: 0.8687
# Epoch 1: Batch 129/233 loss: 0.8587
# Epoch 1: Batch 130/233 loss: 0.8934
# Epoch 1: Batch 131/233 loss: 0.8936
# Epoch 1: Batch 132/233 loss: 0.8915
# Epoch 1: Batch 133/233 loss: 0.8711
# Epoch 1: Batch 134/233 loss: 0.8864
# Epoch 1: Batch 135/233 loss: 0.8783
# Epoch 1: Batch 136/233 loss: 0.8982
# Epoch 1: Batch 137/233 loss: 0.8254
# Epoch 1: Batch 138/233 loss: 0.9168
# Epoch 1: Batch 139/233 loss: 0.9182
# Epoch 1: Batch 140/233 loss: 0.8613
# Epoch 1: Batch 141/233 loss: 0.8774
# Epoch 1: Batch 142/233 loss: 0.9364
# Epoch 1: Batch 143/233 loss: 0.8454
# Epoch 1: Batch 144/233 loss: 0.8927
# Epoch 1: Batch 145/233 loss: 0.8824
# Epoch 1: Batch 146/233 loss: 0.8949
# Epoch 1: Batch 147/233 loss: 0.9508
# Epoch 1: Batch 148/233 loss: 0.8480
# Epoch 1: Batch 149/233 loss: 0.9006
# Epoch 1: Batch 150/233 loss: 0.9110
# Epoch 1: Batch 151/233 loss: 0.8586
# Epoch 1: Batch 152/233 loss: 0.8438
# Epoch 1: Batch 153/233 loss: 0.9153
# Epoch 1: Batch 154/233 loss: 0.8678
# Epoch 1: Batch 155/233 loss: 0.9377
# Epoch 1: Batch 156/233 loss: 0.8481
# Epoch 1: Batch 157/233 loss: 0.9013
# Epoch 1: Batch 158/233 loss: 0.9054
# Epoch 1: Batch 159/233 loss: 0.8630
# Epoch 1: Batch 160/233 loss: 0.9211
# Epoch 1: Batch 161/233 loss: 0.8774
# Epoch 1: Batch 162/233 loss: 0.8438
# Epoch 1: Batch 163/233 loss: 0.9118
# Epoch 1: Batch 164/233 loss: 0.8596
# Epoch 1: Batch 165/233 loss: 0.9168
# Epoch 1: Batch 166/233 loss: 0.8923
# Epoch 1: Batch 167/233 loss: 0.7882
# Epoch 1: Batch 168/233 loss: 0.8362
# Epoch 1: Batch 169/233 loss: 0.8831
# Epoch 1: Batch 170/233 loss: 0.9142
# Epoch 1: Batch 171/233 loss: 0.8188
# Epoch 1: Batch 172/233 loss: 0.8738
# Epoch 1: Batch 173/233 loss: 0.8566
# Epoch 1: Batch 174/233 loss: 0.8765
# Epoch 1: Batch 175/233 loss: 0.9197
# Epoch 1: Batch 176/233 loss: 0.8392
# Epoch 1: Batch 177/233 loss: 0.8830
# Epoch 1: Batch 178/233 loss: 0.9574
# Epoch 1: Batch 179/233 loss: 0.8522
# Epoch 1: Batch 180/233 loss: 0.9228
# Epoch 1: Batch 181/233 loss: 0.9081
# Epoch 1: Batch 182/233 loss: 0.8146
# Epoch 1: Batch 183/233 loss: 0.8834
# Epoch 1: Batch 184/233 loss: 0.8848
# Epoch 1: Batch 185/233 loss: 0.8688
# Epoch 1: Batch 186/233 loss: 0.8304
# Epoch 1: Batch 187/233 loss: 0.8221
# Epoch 1: Batch 188/233 loss: 0.8721
# Epoch 1: Batch 189/233 loss: 0.9563
# Epoch 1: Batch 190/233 loss: 0.8857
# Epoch 1: Batch 191/233 loss: 0.9208
# Epoch 1: Batch 192/233 loss: 0.8659
# Epoch 1: Batch 193/233 loss: 0.8925
# Epoch 1: Batch 194/233 loss: 0.8804
# Epoch 1: Batch 195/233 loss: 0.8807
# Epoch 1: Batch 196/233 loss: 0.8478
# Epoch 1: Batch 197/233 loss: 0.8816
# Epoch 1: Batch 198/233 loss: 0.8877
# Epoch 1: Batch 199/233 loss: 0.8696
# Epoch 1: Batch 200/233 loss: 0.8794
# Epoch 1: Batch 201/233 loss: 0.9200
# Epoch 1: Batch 202/233 loss: 0.9335
# Epoch 1: Batch 203/233 loss: 0.8682
# Epoch 1: Batch 204/233 loss: 0.9524
# Epoch 1: Batch 205/233 loss: 0.8048
# Epoch 1: Batch 206/233 loss: 0.8355
# Epoch 1: Batch 207/233 loss: 0.8119
# Epoch 1: Batch 208/233 loss: 0.8682
# Epoch 1: Batch 209/233 loss: 0.8743
# Epoch 1: Batch 210/233 loss: 0.8990
# Epoch 1: Batch 211/233 loss: 0.8866
# Epoch 1: Batch 212/233 loss: 0.9040
# Epoch 1: Batch 213/233 loss: 0.8200
# Epoch 1: Batch 214/233 loss: 0.8981
# Epoch 1: Batch 215/233 loss: 0.8595
# Epoch 1: Batch 216/233 loss: 0.8740
# Epoch 1: Batch 217/233 loss: 0.8772
# Epoch 1: Batch 218/233 loss: 0.8694
# Epoch 1: Batch 219/233 loss: 0.8989
# Epoch 1: Batch 220/233 loss: 0.9494
# Epoch 1: Batch 221/233 loss: 0.8743
# Epoch 1: Batch 222/233 loss: 0.8736
# Epoch 1: Batch 223/233 loss: 0.9742
# Epoch 1: Batch 224/233 loss: 0.8621
# Epoch 1: Batch 225/233 loss: 0.8828
# Epoch 1: Batch 226/233 loss: 0.9171
# Epoch 1: Batch 227/233 loss: 0.8497
# Epoch 1: Batch 228/233 loss: 0.9158
# Epoch 1: Batch 229/233 loss: 0.9055
# Epoch 1: Batch 230/233 loss: 0.8168
# Epoch 1: Batch 231/233 loss: 0.8809
# Epoch 1: Batch 232/233 loss: 0.8679
# Epoch 1: Batch 233/233 loss: 0.8822
# Epoch 1 train loss: 0.8858 valid loss: 0.8735
# Epoch 2: Batch 1/233 loss: 0.9014
# Epoch 2: Batch 2/233 loss: 0.8714
# Epoch 2: Batch 3/233 loss: 0.9076
# Epoch 2: Batch 4/233 loss: 0.9149
# Epoch 2: Batch 5/233 loss: 0.8572
# Epoch 2: Batch 6/233 loss: 0.8465
# Epoch 2: Batch 7/233 loss: 0.9464
# Epoch 2: Batch 8/233 loss: 0.9376
# Epoch 2: Batch 9/233 loss: 0.8701
# Epoch 2: Batch 10/233 loss: 0.8507
# Epoch 2: Batch 11/233 loss: 0.8402
# Epoch 2: Batch 12/233 loss: 0.8722
# Epoch 2: Batch 13/233 loss: 0.9449
# Epoch 2: Batch 14/233 loss: 0.8701
# Epoch 2: Batch 15/233 loss: 0.9329
# Epoch 2: Batch 16/233 loss: 0.8491
# Epoch 2: Batch 17/233 loss: 0.9750
# Epoch 2: Batch 18/233 loss: 0.9136
# Epoch 2: Batch 19/233 loss: 0.9423
# Epoch 2: Batch 20/233 loss: 0.9107
# Epoch 2: Batch 21/233 loss: 0.8788
# Epoch 2: Batch 22/233 loss: 0.8437
# Epoch 2: Batch 23/233 loss: 0.8392
# Epoch 2: Batch 24/233 loss: 0.8290
# Epoch 2: Batch 25/233 loss: 0.9265
# Epoch 2: Batch 26/233 loss: 0.8813
# Epoch 2: Batch 27/233 loss: 0.8112
# Epoch 2: Batch 28/233 loss: 0.8680
# Epoch 2: Batch 29/233 loss: 0.9047
# Epoch 2: Batch 30/233 loss: 0.8622
# Epoch 2: Batch 31/233 loss: 0.9037
# Epoch 2: Batch 32/233 loss: 0.8997
# Epoch 2: Batch 33/233 loss: 0.9014
# Epoch 2: Batch 34/233 loss: 0.8548
# Epoch 2: Batch 35/233 loss: 0.8293
# Epoch 2: Batch 36/233 loss: 0.8653
# Epoch 2: Batch 37/233 loss: 0.8987
# Epoch 2: Batch 38/233 loss: 0.8783
# Epoch 2: Batch 39/233 loss: 0.8438
# Epoch 2: Batch 40/233 loss: 0.9190
# Epoch 2: Batch 41/233 loss: 0.9730
# Epoch 2: Batch 42/233 loss: 0.8216
# Epoch 2: Batch 43/233 loss: 0.8769
# Epoch 2: Batch 44/233 loss: 0.9469
# Epoch 2: Batch 45/233 loss: 0.9505
# Epoch 2: Batch 46/233 loss: 0.9261
# Epoch 2: Batch 47/233 loss: 0.9134
# Epoch 2: Batch 48/233 loss: 0.8325
# Epoch 2: Batch 49/233 loss: 0.8727
# Epoch 2: Batch 50/233 loss: 0.9506
# Epoch 2: Batch 51/233 loss: 0.9594
# Epoch 2: Batch 52/233 loss: 0.9056
# Epoch 2: Batch 53/233 loss: 0.8543
# Epoch 2: Batch 54/233 loss: 0.8774
# Epoch 2: Batch 55/233 loss: 0.9362
# Epoch 2: Batch 56/233 loss: 0.8218
# Epoch 2: Batch 57/233 loss: 0.8158
# Epoch 2: Batch 58/233 loss: 0.9586
# Epoch 2: Batch 59/233 loss: 0.8956
# Epoch 2: Batch 60/233 loss: 0.9008
# Epoch 2: Batch 61/233 loss: 0.9276
# Epoch 2: Batch 62/233 loss: 0.8955
# Epoch 2: Batch 63/233 loss: 0.8859
# Epoch 2: Batch 64/233 loss: 0.8558
# Epoch 2: Batch 65/233 loss: 0.8122
# Epoch 2: Batch 66/233 loss: 0.7951
# Epoch 2: Batch 67/233 loss: 0.8817
# Epoch 2: Batch 68/233 loss: 0.8555
# Epoch 2: Batch 69/233 loss: 0.8796
# Epoch 2: Batch 70/233 loss: 0.8837
# Epoch 2: Batch 71/233 loss: 0.9147
# Epoch 2: Batch 72/233 loss: 0.8876
# Epoch 2: Batch 73/233 loss: 0.8840
# Epoch 2: Batch 74/233 loss: 0.8662
# Epoch 2: Batch 75/233 loss: 0.8377
# Epoch 2: Batch 76/233 loss: 0.8775
# Epoch 2: Batch 77/233 loss: 0.9241
# Epoch 2: Batch 78/233 loss: 0.8677
# Epoch 2: Batch 79/233 loss: 0.9203
# Epoch 2: Batch 80/233 loss: 0.8537
# Epoch 2: Batch 81/233 loss: 0.8306
# Epoch 2: Batch 82/233 loss: 0.9081
# Epoch 2: Batch 83/233 loss: 0.8886
# Epoch 2: Batch 84/233 loss: 0.8965
# Epoch 2: Batch 85/233 loss: 0.8683
# Epoch 2: Batch 86/233 loss: 0.9414
# Epoch 2: Batch 87/233 loss: 0.8110
# Epoch 2: Batch 88/233 loss: 0.9232
# Epoch 2: Batch 89/233 loss: 0.9039
# Epoch 2: Batch 90/233 loss: 0.9449
# Epoch 2: Batch 91/233 loss: 0.9796
# Epoch 2: Batch 92/233 loss: 0.8315
# Epoch 2: Batch 93/233 loss: 0.8633
# Epoch 2: Batch 94/233 loss: 0.8319
# Epoch 2: Batch 95/233 loss: 0.9393
# Epoch 2: Batch 96/233 loss: 0.9036
# Epoch 2: Batch 97/233 loss: 0.8559
# Epoch 2: Batch 98/233 loss: 0.8779
# Epoch 2: Batch 99/233 loss: 0.8892
# Epoch 2: Batch 100/233 loss: 0.8734
# Epoch 2: Batch 101/233 loss: 0.9502
# Epoch 2: Batch 102/233 loss: 0.8769
# Epoch 2: Batch 103/233 loss: 0.8440
# Epoch 2: Batch 104/233 loss: 0.9536
# Epoch 2: Batch 105/233 loss: 0.8912
# Epoch 2: Batch 106/233 loss: 0.8962
# Epoch 2: Batch 107/233 loss: 0.8917
# Epoch 2: Batch 108/233 loss: 0.8780
# Epoch 2: Batch 109/233 loss: 0.8787
# Epoch 2: Batch 110/233 loss: 0.9105
# Epoch 2: Batch 111/233 loss: 0.8908
# Epoch 2: Batch 112/233 loss: 0.8783
# Epoch 2: Batch 113/233 loss: 0.9441
# Epoch 2: Batch 114/233 loss: 0.8333
# Epoch 2: Batch 115/233 loss: 0.8058
# Epoch 2: Batch 116/233 loss: 0.9030
# Epoch 2: Batch 117/233 loss: 0.8642
# Epoch 2: Batch 118/233 loss: 0.8537
# Epoch 2: Batch 119/233 loss: 0.9122
# Epoch 2: Batch 120/233 loss: 0.9127
# Epoch 2: Batch 121/233 loss: 0.9255
# Epoch 2: Batch 122/233 loss: 0.9088
# Epoch 2: Batch 123/233 loss: 0.9024
# Epoch 2: Batch 124/233 loss: 0.8789
# Epoch 2: Batch 125/233 loss: 0.9180
# Epoch 2: Batch 126/233 loss: 0.8995
# Epoch 2: Batch 127/233 loss: 0.8448
# Epoch 2: Batch 128/233 loss: 0.8342
# Epoch 2: Batch 129/233 loss: 0.9323
# Epoch 2: Batch 130/233 loss: 0.8597
# Epoch 2: Batch 131/233 loss: 0.8426
# Epoch 2: Batch 132/233 loss: 0.9295
# Epoch 2: Batch 133/233 loss: 0.8710
# Epoch 2: Batch 134/233 loss: 0.7964
# Epoch 2: Batch 135/233 loss: 0.8454
# Epoch 2: Batch 136/233 loss: 0.9334
# Epoch 2: Batch 137/233 loss: 0.8787
# Epoch 2: Batch 138/233 loss: 0.8943
# Epoch 2: Batch 139/233 loss: 0.8603
# Epoch 2: Batch 140/233 loss: 0.8155
# Epoch 2: Batch 141/233 loss: 0.8961
# Epoch 2: Batch 142/233 loss: 0.9115
# Epoch 2: Batch 143/233 loss: 0.8675
# Epoch 2: Batch 144/233 loss: 0.9065
# Epoch 2: Batch 145/233 loss: 0.8918
# Epoch 2: Batch 146/233 loss: 0.9250
# Epoch 2: Batch 147/233 loss: 0.9149
# Epoch 2: Batch 148/233 loss: 0.8759
# Epoch 2: Batch 149/233 loss: 0.9267
# Epoch 2: Batch 150/233 loss: 0.9208
# Epoch 2: Batch 151/233 loss: 0.8273
# Epoch 2: Batch 152/233 loss: 0.9085
# Epoch 2: Batch 153/233 loss: 0.8258
# Epoch 2: Batch 154/233 loss: 0.8760
# Epoch 2: Batch 155/233 loss: 0.8262
# Epoch 2: Batch 156/233 loss: 0.9177
# Epoch 2: Batch 157/233 loss: 0.8435
# Epoch 2: Batch 158/233 loss: 0.8729
# Epoch 2: Batch 159/233 loss: 0.9138
# Epoch 2: Batch 160/233 loss: 0.8428
# Epoch 2: Batch 161/233 loss: 0.9105
# Epoch 2: Batch 162/233 loss: 0.8208
# Epoch 2: Batch 163/233 loss: 0.9048
# Epoch 2: Batch 164/233 loss: 0.8622
# Epoch 2: Batch 165/233 loss: 0.8849
# Epoch 2: Batch 166/233 loss: 0.9069
# Epoch 2: Batch 167/233 loss: 0.9103
# Epoch 2: Batch 168/233 loss: 0.9614
# Epoch 2: Batch 169/233 loss: 0.9044
# Epoch 2: Batch 170/233 loss: 0.8987
# Epoch 2: Batch 171/233 loss: 0.8748
# Epoch 2: Batch 172/233 loss: 0.8500
# Epoch 2: Batch 173/233 loss: 0.8790
# Epoch 2: Batch 174/233 loss: 0.8934
# Epoch 2: Batch 175/233 loss: 0.8306
# Epoch 2: Batch 176/233 loss: 0.8522
# Epoch 2: Batch 177/233 loss: 0.8370
# Epoch 2: Batch 178/233 loss: 0.8829
# Epoch 2: Batch 179/233 loss: 0.9049
# Epoch 2: Batch 180/233 loss: 0.8908
# Epoch 2: Batch 181/233 loss: 0.9197
# Epoch 2: Batch 182/233 loss: 0.8935
# Epoch 2: Batch 183/233 loss: 0.9385
# Epoch 2: Batch 184/233 loss: 0.8827
# Epoch 2: Batch 185/233 loss: 0.8932
# Epoch 2: Batch 186/233 loss: 0.8737
# Epoch 2: Batch 187/233 loss: 0.8685
# Epoch 2: Batch 188/233 loss: 0.8732
# Epoch 2: Batch 189/233 loss: 0.8843
# Epoch 2: Batch 190/233 loss: 0.9211
# Epoch 2: Batch 191/233 loss: 0.8798
# Epoch 2: Batch 192/233 loss: 0.8862
# Epoch 2: Batch 193/233 loss: 0.8849
# Epoch 2: Batch 194/233 loss: 0.8801
# Epoch 2: Batch 195/233 loss: 0.8758
# Epoch 2: Batch 196/233 loss: 0.8753
# Epoch 2: Batch 197/233 loss: 0.8681
# Epoch 2: Batch 198/233 loss: 0.9275
# Epoch 2: Batch 199/233 loss: 0.8767
# Epoch 2: Batch 200/233 loss: 0.9553
# Epoch 2: Batch 201/233 loss: 0.9196
# Epoch 2: Batch 202/233 loss: 0.8433
# Epoch 2: Batch 203/233 loss: 0.9336
# Epoch 2: Batch 204/233 loss: 0.9003
# Epoch 2: Batch 205/233 loss: 0.8541
# Epoch 2: Batch 206/233 loss: 0.8917
# Epoch 2: Batch 207/233 loss: 0.8775
# Epoch 2: Batch 208/233 loss: 0.8953
# Epoch 2: Batch 209/233 loss: 0.8441
# Epoch 2: Batch 210/233 loss: 0.8310
# Epoch 2: Batch 211/233 loss: 0.9181
# Epoch 2: Batch 212/233 loss: 0.8398
# Epoch 2: Batch 213/233 loss: 0.8494
# Epoch 2: Batch 214/233 loss: 0.9570
# Epoch 2: Batch 215/233 loss: 0.8097
# Epoch 2: Batch 216/233 loss: 0.9047
# Epoch 2: Batch 217/233 loss: 0.9261
# Epoch 2: Batch 218/233 loss: 0.9142
# Epoch 2: Batch 219/233 loss: 0.8196
# Epoch 2: Batch 220/233 loss: 0.8740
# Epoch 2: Batch 221/233 loss: 0.8980
# Epoch 2: Batch 222/233 loss: 0.9202
# Epoch 2: Batch 223/233 loss: 0.8886
# Epoch 2: Batch 224/233 loss: 0.8304
# Epoch 2: Batch 225/233 loss: 0.9160
# Epoch 2: Batch 226/233 loss: 0.9136
# Epoch 2: Batch 227/233 loss: 0.8603
# Epoch 2: Batch 228/233 loss: 0.9081
# Epoch 2: Batch 229/233 loss: 0.8591
# Epoch 2: Batch 230/233 loss: 0.9333
# Epoch 2: Batch 231/233 loss: 0.8854
# Epoch 2: Batch 232/233 loss: 0.8287
# Epoch 2: Batch 233/233 loss: 0.9252
# Epoch 2 train loss: 0.8857 valid loss: 0.8731
# Epoch 3: Batch 1/233 loss: 0.8843
# Epoch 3: Batch 2/233 loss: 0.8623
# Epoch 3: Batch 3/233 loss: 0.9297
# Epoch 3: Batch 4/233 loss: 0.9083
# Epoch 3: Batch 5/233 loss: 0.8556
# Epoch 3: Batch 6/233 loss: 0.8634
# Epoch 3: Batch 7/233 loss: 0.8804
# Epoch 3: Batch 8/233 loss: 0.8727
# Epoch 3: Batch 9/233 loss: 0.8406
# Epoch 3: Batch 10/233 loss: 0.8843
# Epoch 3: Batch 11/233 loss: 0.8944
# Epoch 3: Batch 12/233 loss: 0.8587
# Epoch 3: Batch 13/233 loss: 0.8956
# Epoch 3: Batch 14/233 loss: 0.9244
# Epoch 3: Batch 15/233 loss: 0.8062
# Epoch 3: Batch 16/233 loss: 0.8864
# Epoch 3: Batch 17/233 loss: 0.8736
# Epoch 3: Batch 18/233 loss: 0.9196
# Epoch 3: Batch 19/233 loss: 0.8779
# Epoch 3: Batch 20/233 loss: 0.8704
# Epoch 3: Batch 21/233 loss: 0.9541
# Epoch 3: Batch 22/233 loss: 0.8684
# Epoch 3: Batch 23/233 loss: 0.9290
# Epoch 3: Batch 24/233 loss: 0.8295
# Epoch 3: Batch 25/233 loss: 0.8922
# Epoch 3: Batch 26/233 loss: 0.8594
# Epoch 3: Batch 27/233 loss: 0.8680
# Epoch 3: Batch 28/233 loss: 0.9476
# Epoch 3: Batch 29/233 loss: 0.9331
# Epoch 3: Batch 30/233 loss: 0.9003
# Epoch 3: Batch 31/233 loss: 0.9147
# Epoch 3: Batch 32/233 loss: 0.9231
# Epoch 3: Batch 33/233 loss: 0.9132
# Epoch 3: Batch 34/233 loss: 0.8304
# Epoch 3: Batch 35/233 loss: 0.8433
# Epoch 3: Batch 36/233 loss: 0.9131
# Epoch 3: Batch 37/233 loss: 0.9025
# Epoch 3: Batch 38/233 loss: 0.8534
# Epoch 3: Batch 39/233 loss: 0.8701
# Epoch 3: Batch 40/233 loss: 0.8761
# Epoch 3: Batch 41/233 loss: 0.9100
# Epoch 3: Batch 42/233 loss: 0.8845
# Epoch 3: Batch 43/233 loss: 0.9544
# Epoch 3: Batch 44/233 loss: 0.8282
# Epoch 3: Batch 45/233 loss: 0.8715
# Epoch 3: Batch 46/233 loss: 0.8410
# Epoch 3: Batch 47/233 loss: 0.9042
# Epoch 3: Batch 48/233 loss: 0.8802
# Epoch 3: Batch 49/233 loss: 0.9494
# Epoch 3: Batch 50/233 loss: 0.8339
# Epoch 3: Batch 51/233 loss: 0.8956
# Epoch 3: Batch 52/233 loss: 0.8591
# Epoch 3: Batch 53/233 loss: 0.8825
# Epoch 3: Batch 54/233 loss: 0.9159
# Epoch 3: Batch 55/233 loss: 0.8820
# Epoch 3: Batch 56/233 loss: 0.9277
# Epoch 3: Batch 57/233 loss: 0.9277
# Epoch 3: Batch 58/233 loss: 0.9113
# Epoch 3: Batch 59/233 loss: 0.9038
# Epoch 3: Batch 60/233 loss: 0.8708
# Epoch 3: Batch 61/233 loss: 0.9429
# Epoch 3: Batch 62/233 loss: 0.8884
# Epoch 3: Batch 63/233 loss: 0.8406
# Epoch 3: Batch 64/233 loss: 0.9647
# Epoch 3: Batch 65/233 loss: 0.8288
# Epoch 3: Batch 66/233 loss: 0.8717
# Epoch 3: Batch 67/233 loss: 0.9162
# Epoch 3: Batch 68/233 loss: 0.9147
# Epoch 3: Batch 69/233 loss: 0.9003
# Epoch 3: Batch 70/233 loss: 0.9545
# Epoch 3: Batch 71/233 loss: 0.8193
# Epoch 3: Batch 72/233 loss: 0.8830
# Epoch 3: Batch 73/233 loss: 0.8818
# Epoch 3: Batch 74/233 loss: 0.8517
# Epoch 3: Batch 75/233 loss: 0.8641
# Epoch 3: Batch 76/233 loss: 0.9263
# Epoch 3: Batch 77/233 loss: 0.9048
# Epoch 3: Batch 78/233 loss: 0.9083
# Epoch 3: Batch 79/233 loss: 0.8575
# Epoch 3: Batch 80/233 loss: 0.9084
# Epoch 3: Batch 81/233 loss: 0.8958
# Epoch 3: Batch 82/233 loss: 0.8785
# Epoch 3: Batch 83/233 loss: 0.8869
# Epoch 3: Batch 84/233 loss: 0.8855
# Epoch 3: Batch 85/233 loss: 0.8299
# Epoch 3: Batch 86/233 loss: 0.9203
# Epoch 3: Batch 87/233 loss: 0.8912
# Epoch 3: Batch 88/233 loss: 0.8864
# Epoch 3: Batch 89/233 loss: 0.9540
# Epoch 3: Batch 90/233 loss: 0.9057
# Epoch 3: Batch 91/233 loss: 0.9053
# Epoch 3: Batch 92/233 loss: 0.8806
# Epoch 3: Batch 93/233 loss: 0.8750
# Epoch 3: Batch 94/233 loss: 0.9202
# Epoch 3: Batch 95/233 loss: 0.9192
# Epoch 3: Batch 96/233 loss: 0.8930
# Epoch 3: Batch 97/233 loss: 0.9396
# Epoch 3: Batch 98/233 loss: 0.9406
# Epoch 3: Batch 99/233 loss: 0.8872
# Epoch 3: Batch 100/233 loss: 0.9450
# Epoch 3: Batch 101/233 loss: 0.9317
# Epoch 3: Batch 102/233 loss: 0.8838
# Epoch 3: Batch 103/233 loss: 0.9039
# Epoch 3: Batch 104/233 loss: 0.9001
# Epoch 3: Batch 105/233 loss: 0.9576
# Epoch 3: Batch 106/233 loss: 0.8874
# Epoch 3: Batch 107/233 loss: 0.8772
# Epoch 3: Batch 108/233 loss: 0.9228
# Epoch 3: Batch 109/233 loss: 0.8980
# Epoch 3: Batch 110/233 loss: 0.8698
# Epoch 3: Batch 111/233 loss: 0.9112
# Epoch 3: Batch 112/233 loss: 0.8889
# Epoch 3: Batch 113/233 loss: 0.9060
# Epoch 3: Batch 114/233 loss: 0.9238
# Epoch 3: Batch 115/233 loss: 0.9412
# Epoch 3: Batch 116/233 loss: 0.8869
# Epoch 3: Batch 117/233 loss: 0.8518
# Epoch 3: Batch 118/233 loss: 0.8677
# Epoch 3: Batch 119/233 loss: 0.9155
# Epoch 3: Batch 120/233 loss: 0.9042
# Epoch 3: Batch 121/233 loss: 0.8547
# Epoch 3: Batch 122/233 loss: 0.9041
# Epoch 3: Batch 123/233 loss: 0.8571
# Epoch 3: Batch 124/233 loss: 0.8803
# Epoch 3: Batch 125/233 loss: 0.9484
# Epoch 3: Batch 126/233 loss: 0.9015
# Epoch 3: Batch 127/233 loss: 0.9413
# Epoch 3: Batch 128/233 loss: 0.8221
# Epoch 3: Batch 129/233 loss: 0.8733
# Epoch 3: Batch 130/233 loss: 0.8924
# Epoch 3: Batch 131/233 loss: 0.8824
# Epoch 3: Batch 132/233 loss: 0.8657
# Epoch 3: Batch 133/233 loss: 0.9167
# Epoch 3: Batch 134/233 loss: 0.9037
# Epoch 3: Batch 135/233 loss: 0.8329
# Epoch 3: Batch 136/233 loss: 0.8449
# Epoch 3: Batch 137/233 loss: 0.8997
# Epoch 3: Batch 138/233 loss: 0.8565
# Epoch 3: Batch 139/233 loss: 0.9206
# Epoch 3: Batch 140/233 loss: 0.9282
# Epoch 3: Batch 141/233 loss: 0.9045
# Epoch 3: Batch 142/233 loss: 0.8794
# Epoch 3: Batch 143/233 loss: 0.8720
# Epoch 3: Batch 144/233 loss: 0.8999
# Epoch 3: Batch 145/233 loss: 0.8652
# Epoch 3: Batch 146/233 loss: 0.8426
# Epoch 3: Batch 147/233 loss: 0.9314
# Epoch 3: Batch 148/233 loss: 0.8562
# Epoch 3: Batch 149/233 loss: 0.8852
# Epoch 3: Batch 150/233 loss: 0.8819
# Epoch 3: Batch 151/233 loss: 0.9033
# Epoch 3: Batch 152/233 loss: 0.8265
# Epoch 3: Batch 153/233 loss: 0.8290
# Epoch 3: Batch 154/233 loss: 0.8659
# Epoch 3: Batch 155/233 loss: 0.8306
# Epoch 3: Batch 156/233 loss: 0.9045
# Epoch 3: Batch 157/233 loss: 0.8863
# Epoch 3: Batch 158/233 loss: 0.8892
# Epoch 3: Batch 159/233 loss: 0.9176
# Epoch 3: Batch 160/233 loss: 0.8399
# Epoch 3: Batch 161/233 loss: 0.8557
# Epoch 3: Batch 162/233 loss: 0.8430
# Epoch 3: Batch 163/233 loss: 0.9091
# Epoch 3: Batch 164/233 loss: 0.9070
# Epoch 3: Batch 165/233 loss: 0.8826
# Epoch 3: Batch 166/233 loss: 0.8800
# Epoch 3: Batch 167/233 loss: 0.9214
# Epoch 3: Batch 168/233 loss: 0.8576
# Epoch 3: Batch 169/233 loss: 0.8104
# Epoch 3: Batch 170/233 loss: 0.7743
# Epoch 3: Batch 171/233 loss: 0.8354
# Epoch 3: Batch 172/233 loss: 0.8650
# Epoch 3: Batch 173/233 loss: 0.8822
# Epoch 3: Batch 174/233 loss: 0.8498
# Epoch 3: Batch 175/233 loss: 0.9214
# Epoch 3: Batch 176/233 loss: 0.8888
# Epoch 3: Batch 177/233 loss: 0.8588
# Epoch 3: Batch 178/233 loss: 0.9029
# Epoch 3: Batch 179/233 loss: 0.8977
# Epoch 3: Batch 180/233 loss: 0.8667
# Epoch 3: Batch 181/233 loss: 0.8134
# Epoch 3: Batch 182/233 loss: 0.8485
# Epoch 3: Batch 183/233 loss: 0.9556
# Epoch 3: Batch 184/233 loss: 0.8278
# Epoch 3: Batch 185/233 loss: 0.8469
# Epoch 3: Batch 186/233 loss: 0.8866
# Epoch 3: Batch 187/233 loss: 0.8574
# Epoch 3: Batch 188/233 loss: 0.9272
# Epoch 3: Batch 189/233 loss: 0.8678
# Epoch 3: Batch 190/233 loss: 0.8737
# Epoch 3: Batch 191/233 loss: 0.9444
# Epoch 3: Batch 192/233 loss: 0.8526
# Epoch 3: Batch 193/233 loss: 0.8813
# Epoch 3: Batch 194/233 loss: 0.8261
# Epoch 3: Batch 195/233 loss: 0.8808
# Epoch 3: Batch 196/233 loss: 0.9028
# Epoch 3: Batch 197/233 loss: 0.8788
# Epoch 3: Batch 198/233 loss: 0.8888
# Epoch 3: Batch 199/233 loss: 0.8700
# Epoch 3: Batch 200/233 loss: 0.8489
# Epoch 3: Batch 201/233 loss: 0.8704
# Epoch 3: Batch 202/233 loss: 0.8900
# Epoch 3: Batch 203/233 loss: 0.8640
# Epoch 3: Batch 204/233 loss: 0.8949
# Epoch 3: Batch 205/233 loss: 0.9050
# Epoch 3: Batch 206/233 loss: 0.7952
# Epoch 3: Batch 207/233 loss: 0.8924
# Epoch 3: Batch 208/233 loss: 0.8854
# Epoch 3: Batch 209/233 loss: 0.8774
# Epoch 3: Batch 210/233 loss: 0.9032
# Epoch 3: Batch 211/233 loss: 0.9257
# Epoch 3: Batch 212/233 loss: 0.8845
# Epoch 3: Batch 213/233 loss: 0.8159
# Epoch 3: Batch 214/233 loss: 0.8933
# Epoch 3: Batch 215/233 loss: 0.8440
# Epoch 3: Batch 216/233 loss: 0.9017
# Epoch 3: Batch 217/233 loss: 0.9295
# Epoch 3: Batch 218/233 loss: 0.9279
# Epoch 3: Batch 219/233 loss: 0.8546
# Epoch 3: Batch 220/233 loss: 0.8650
# Epoch 3: Batch 221/233 loss: 0.8496
# Epoch 3: Batch 222/233 loss: 0.9451
# Epoch 3: Batch 223/233 loss: 0.8765
# Epoch 3: Batch 224/233 loss: 0.9247
# Epoch 3: Batch 225/233 loss: 0.8827
# Epoch 3: Batch 226/233 loss: 0.8649
# Epoch 3: Batch 227/233 loss: 0.8825
# Epoch 3: Batch 228/233 loss: 0.9252
# Epoch 3: Batch 229/233 loss: 0.8993
# Epoch 3: Batch 230/233 loss: 0.8292
# Epoch 3: Batch 231/233 loss: 0.8965
# Epoch 3: Batch 232/233 loss: 0.8892
# Epoch 3: Batch 233/233 loss: 0.8378
# Epoch 3 train loss: 0.8858 valid loss: 0.8716
# Epoch 4: Batch 1/233 loss: 0.9630
# Epoch 4: Batch 2/233 loss: 0.8741
# Epoch 4: Batch 3/233 loss: 0.9076
# Epoch 4: Batch 4/233 loss: 0.8363
# Epoch 4: Batch 5/233 loss: 0.9326
# Epoch 4: Batch 6/233 loss: 0.8412
# Epoch 4: Batch 7/233 loss: 0.9015
# Epoch 4: Batch 8/233 loss: 0.8588
# Epoch 4: Batch 9/233 loss: 0.8072
# Epoch 4: Batch 10/233 loss: 0.7996
# Epoch 4: Batch 11/233 loss: 0.8756
# Epoch 4: Batch 12/233 loss: 0.9243
# Epoch 4: Batch 13/233 loss: 0.8859
# Epoch 4: Batch 14/233 loss: 0.9104
# Epoch 4: Batch 15/233 loss: 0.9521
# Epoch 4: Batch 16/233 loss: 0.8993
# Epoch 4: Batch 17/233 loss: 0.9690
# Epoch 4: Batch 18/233 loss: 0.8729
# Epoch 4: Batch 19/233 loss: 0.8328
# Epoch 4: Batch 20/233 loss: 0.8665
# Epoch 4: Batch 21/233 loss: 0.8437
# Epoch 4: Batch 22/233 loss: 0.9099
# Epoch 4: Batch 23/233 loss: 0.9339
# Epoch 4: Batch 24/233 loss: 0.9335
# Epoch 4: Batch 25/233 loss: 0.8767
# Epoch 4: Batch 26/233 loss: 0.8993
# Epoch 4: Batch 27/233 loss: 0.8637
# Epoch 4: Batch 28/233 loss: 0.8729
# Epoch 4: Batch 29/233 loss: 0.8680
# Epoch 4: Batch 30/233 loss: 0.9402
# Epoch 4: Batch 31/233 loss: 0.9112
# Epoch 4: Batch 32/233 loss: 0.8648
# Epoch 4: Batch 33/233 loss: 0.9431
# Epoch 4: Batch 34/233 loss: 0.8781
# Epoch 4: Batch 35/233 loss: 0.9492
# Epoch 4: Batch 36/233 loss: 0.9399
# Epoch 4: Batch 37/233 loss: 0.8218
# Epoch 4: Batch 38/233 loss: 0.9551
# Epoch 4: Batch 39/233 loss: 0.9137
# Epoch 4: Batch 40/233 loss: 0.8945
# Epoch 4: Batch 41/233 loss: 0.8388
# Epoch 4: Batch 42/233 loss: 0.8098
# Epoch 4: Batch 43/233 loss: 0.9004
# Epoch 4: Batch 44/233 loss: 0.8862
# Epoch 4: Batch 45/233 loss: 0.8920
# Epoch 4: Batch 46/233 loss: 0.9147
# Epoch 4: Batch 47/233 loss: 0.8995
# Epoch 4: Batch 48/233 loss: 0.8870
# Epoch 4: Batch 49/233 loss: 0.9416
# Epoch 4: Batch 50/233 loss: 0.9522
# Epoch 4: Batch 51/233 loss: 0.8919
# Epoch 4: Batch 52/233 loss: 0.8663
# Epoch 4: Batch 53/233 loss: 0.9062
# Epoch 4: Batch 54/233 loss: 0.9066
# Epoch 4: Batch 55/233 loss: 0.8916
# Epoch 4: Batch 56/233 loss: 0.8731
# Epoch 4: Batch 57/233 loss: 0.9251
# Epoch 4: Batch 58/233 loss: 0.9099
# Epoch 4: Batch 59/233 loss: 0.8818
# Epoch 4: Batch 60/233 loss: 0.9545
# Epoch 4: Batch 61/233 loss: 0.9005
# Epoch 4: Batch 62/233 loss: 0.9133
# Epoch 4: Batch 63/233 loss: 0.8909
# Epoch 4: Batch 64/233 loss: 0.8434
# Epoch 4: Batch 65/233 loss: 0.9340
# Epoch 4: Batch 66/233 loss: 0.9075
# Epoch 4: Batch 67/233 loss: 0.9343
# Epoch 4: Batch 68/233 loss: 0.9201
# Epoch 4: Batch 69/233 loss: 0.8357
# Epoch 4: Batch 70/233 loss: 0.8811
# Epoch 4: Batch 71/233 loss: 0.9051
# Epoch 4: Batch 72/233 loss: 0.8351
# Epoch 4: Batch 73/233 loss: 0.8994
# Epoch 4: Batch 74/233 loss: 0.8931
# Epoch 4: Batch 75/233 loss: 0.8898
# Epoch 4: Batch 76/233 loss: 0.8700
# Epoch 4: Batch 77/233 loss: 0.9298
# Epoch 4: Batch 78/233 loss: 0.9328
# Epoch 4: Batch 79/233 loss: 0.8820
# Epoch 4: Batch 80/233 loss: 0.8995
# Epoch 4: Batch 81/233 loss: 0.8948
# Epoch 4: Batch 82/233 loss: 0.8870
# Epoch 4: Batch 83/233 loss: 0.9023
# Epoch 4: Batch 84/233 loss: 0.8661
# Epoch 4: Batch 85/233 loss: 0.8721
# Epoch 4: Batch 86/233 loss: 0.9076
# Epoch 4: Batch 87/233 loss: 0.8615
# Epoch 4: Batch 88/233 loss: 0.9056
# Epoch 4: Batch 89/233 loss: 0.9385
# Epoch 4: Batch 90/233 loss: 0.9161
# Epoch 4: Batch 91/233 loss: 0.9005
# Epoch 4: Batch 92/233 loss: 0.9035
# Epoch 4: Batch 93/233 loss: 0.8554
# Epoch 4: Batch 94/233 loss: 0.8860
# Epoch 4: Batch 95/233 loss: 0.8816
# Epoch 4: Batch 96/233 loss: 0.8526
# Epoch 4: Batch 97/233 loss: 0.8089
# Epoch 4: Batch 98/233 loss: 0.8431
# Epoch 4: Batch 99/233 loss: 0.9161
# Epoch 4: Batch 100/233 loss: 0.9457
# Epoch 4: Batch 101/233 loss: 0.9133
# Epoch 4: Batch 102/233 loss: 0.8768
# Epoch 4: Batch 103/233 loss: 0.8956
# Epoch 4: Batch 104/233 loss: 0.8527
# Epoch 4: Batch 105/233 loss: 0.8825
# Epoch 4: Batch 106/233 loss: 0.9179
# Epoch 4: Batch 107/233 loss: 0.8812
# Epoch 4: Batch 108/233 loss: 0.8539
# Epoch 4: Batch 109/233 loss: 0.8796
# Epoch 4: Batch 110/233 loss: 0.8831
# Epoch 4: Batch 111/233 loss: 0.9085
# Epoch 4: Batch 112/233 loss: 0.9489
# Epoch 4: Batch 113/233 loss: 0.8899
# Epoch 4: Batch 114/233 loss: 0.8412
# Epoch 4: Batch 115/233 loss: 0.8906
# Epoch 4: Batch 116/233 loss: 0.8154
# Epoch 4: Batch 117/233 loss: 0.9264
# Epoch 4: Batch 118/233 loss: 0.9186
# Epoch 4: Batch 119/233 loss: 0.8528
# Epoch 4: Batch 120/233 loss: 0.8699
# Epoch 4: Batch 121/233 loss: 0.8614
# Epoch 4: Batch 122/233 loss: 0.9023
# Epoch 4: Batch 123/233 loss: 0.8853
# Epoch 4: Batch 124/233 loss: 0.9164
# Epoch 4: Batch 125/233 loss: 0.9320
# Epoch 4: Batch 126/233 loss: 0.8444
# Epoch 4: Batch 127/233 loss: 0.9374
# Epoch 4: Batch 128/233 loss: 0.8735
# Epoch 4: Batch 129/233 loss: 0.8191
# Epoch 4: Batch 130/233 loss: 0.8863
# Epoch 4: Batch 131/233 loss: 0.9531
# Epoch 4: Batch 132/233 loss: 0.9279
# Epoch 4: Batch 133/233 loss: 0.9265
# Epoch 4: Batch 134/233 loss: 0.9012
# Epoch 4: Batch 135/233 loss: 0.7936
# Epoch 4: Batch 136/233 loss: 0.8309
# Epoch 4: Batch 137/233 loss: 0.9147
# Epoch 4: Batch 138/233 loss: 0.8728
# Epoch 4: Batch 139/233 loss: 0.8868
# Epoch 4: Batch 140/233 loss: 0.9287
# Epoch 4: Batch 141/233 loss: 0.8187
# Epoch 4: Batch 142/233 loss: 0.8738
# Epoch 4: Batch 143/233 loss: 0.8823
# Epoch 4: Batch 144/233 loss: 0.8886
# Epoch 4: Batch 145/233 loss: 0.9241
# Epoch 4: Batch 146/233 loss: 0.8402
# Epoch 4: Batch 147/233 loss: 0.9229
# Epoch 4: Batch 148/233 loss: 0.9077
# Epoch 4: Batch 149/233 loss: 0.9234
# Epoch 4: Batch 150/233 loss: 0.9242
# Epoch 4: Batch 151/233 loss: 0.8919
# Epoch 4: Batch 152/233 loss: 0.9091
# Epoch 4: Batch 153/233 loss: 0.8786
# Epoch 4: Batch 154/233 loss: 0.8513
# Epoch 4: Batch 155/233 loss: 0.9001
# Epoch 4: Batch 156/233 loss: 0.9158
# Epoch 4: Batch 157/233 loss: 0.8580
# Epoch 4: Batch 158/233 loss: 0.8963
# Epoch 4: Batch 159/233 loss: 0.7979
# Epoch 4: Batch 160/233 loss: 0.8314
# Epoch 4: Batch 161/233 loss: 0.8527
# Epoch 4: Batch 162/233 loss: 0.9184
# Epoch 4: Batch 163/233 loss: 0.8137
# Epoch 4: Batch 164/233 loss: 0.8986
# Epoch 4: Batch 165/233 loss: 0.8790
# Epoch 4: Batch 166/233 loss: 0.8754
# Epoch 4: Batch 167/233 loss: 0.9122
# Epoch 4: Batch 168/233 loss: 0.8968
# Epoch 4: Batch 169/233 loss: 0.8825
# Epoch 4: Batch 170/233 loss: 0.8981
# Epoch 4: Batch 171/233 loss: 0.8177
# Epoch 4: Batch 172/233 loss: 0.8651
# Epoch 4: Batch 173/233 loss: 0.8456
# Epoch 4: Batch 174/233 loss: 0.8605
# Epoch 4: Batch 175/233 loss: 0.8709
# Epoch 4: Batch 176/233 loss: 0.9150
# Epoch 4: Batch 177/233 loss: 0.9309
# Epoch 4: Batch 178/233 loss: 0.9173
# Epoch 4: Batch 179/233 loss: 0.8629
# Epoch 4: Batch 180/233 loss: 0.8300
# Epoch 4: Batch 181/233 loss: 0.8903
# Epoch 4: Batch 182/233 loss: 0.8790
# Epoch 4: Batch 183/233 loss: 0.9020
# Epoch 4: Batch 184/233 loss: 0.8716
# Epoch 4: Batch 185/233 loss: 0.9011
# Epoch 4: Batch 186/233 loss: 0.9594
# Epoch 4: Batch 187/233 loss: 0.8804
# Epoch 4: Batch 188/233 loss: 0.9056
# Epoch 4: Batch 189/233 loss: 0.8126
# Epoch 4: Batch 190/233 loss: 0.8430
# Epoch 4: Batch 191/233 loss: 0.9374
# Epoch 4: Batch 192/233 loss: 0.8316
# Epoch 4: Batch 193/233 loss: 0.8545
# Epoch 4: Batch 194/233 loss: 0.9003
# Epoch 4: Batch 195/233 loss: 0.9104
# Epoch 4: Batch 196/233 loss: 0.8408
# Epoch 4: Batch 197/233 loss: 0.8721
# Epoch 4: Batch 198/233 loss: 0.9052
# Epoch 4: Batch 199/233 loss: 0.8897
# Epoch 4: Batch 200/233 loss: 0.7770
# Epoch 4: Batch 201/233 loss: 0.8543
# Epoch 4: Batch 202/233 loss: 0.8575
# Epoch 4: Batch 203/233 loss: 0.8738
# Epoch 4: Batch 204/233 loss: 0.9047
# Epoch 4: Batch 205/233 loss: 0.9012
# Epoch 4: Batch 206/233 loss: 0.8575
# Epoch 4: Batch 207/233 loss: 0.8780
# Epoch 4: Batch 208/233 loss: 0.8614
# Epoch 4: Batch 209/233 loss: 0.8246
# Epoch 4: Batch 210/233 loss: 0.8738
# Epoch 4: Batch 211/233 loss: 0.9039
# Epoch 4: Batch 212/233 loss: 0.8394
# Epoch 4: Batch 213/233 loss: 0.8891
# Epoch 4: Batch 214/233 loss: 0.9248
# Epoch 4: Batch 215/233 loss: 0.8544
# Epoch 4: Batch 216/233 loss: 0.8749
# Epoch 4: Batch 217/233 loss: 0.8656
# Epoch 4: Batch 218/233 loss: 0.8723
# Epoch 4: Batch 219/233 loss: 0.8904
# Epoch 4: Batch 220/233 loss: 0.8839
# Epoch 4: Batch 221/233 loss: 0.8714
# Epoch 4: Batch 222/233 loss: 0.8253
# Epoch 4: Batch 223/233 loss: 0.8880
# Epoch 4: Batch 224/233 loss: 0.8916
# Epoch 4: Batch 225/233 loss: 0.8852
# Epoch 4: Batch 226/233 loss: 0.8805
# Epoch 4: Batch 227/233 loss: 0.7985
# Epoch 4: Batch 228/233 loss: 0.8897
# Epoch 4: Batch 229/233 loss: 0.8484
# Epoch 4: Batch 230/233 loss: 0.9519
# Epoch 4: Batch 231/233 loss: 0.8954
# Epoch 4: Batch 232/233 loss: 0.8423
# Epoch 4: Batch 233/233 loss: 0.9010
# Epoch 4 train loss: 0.8858 valid loss: 0.8737
# performance reducing: 1
# Epoch 5: Batch 1/233 loss: 0.8939
# Epoch 5: Batch 2/233 loss: 0.8756
# Epoch 5: Batch 3/233 loss: 0.9029
# Epoch 5: Batch 4/233 loss: 0.8500
# Epoch 5: Batch 5/233 loss: 0.8524
# Epoch 5: Batch 6/233 loss: 0.9525
# Epoch 5: Batch 7/233 loss: 0.8724
# Epoch 5: Batch 8/233 loss: 0.8751
# Epoch 5: Batch 9/233 loss: 0.9247
# Epoch 5: Batch 10/233 loss: 0.9416
# Epoch 5: Batch 11/233 loss: 0.8310
# Epoch 5: Batch 12/233 loss: 0.8933
# Epoch 5: Batch 13/233 loss: 0.8838
# Epoch 5: Batch 14/233 loss: 0.9245
# Epoch 5: Batch 15/233 loss: 0.8897
# Epoch 5: Batch 16/233 loss: 0.9022
# Epoch 5: Batch 17/233 loss: 0.9386
# Epoch 5: Batch 18/233 loss: 0.9126
# Epoch 5: Batch 19/233 loss: 0.9240
# Epoch 5: Batch 20/233 loss: 0.9232
# Epoch 5: Batch 21/233 loss: 0.9312
# Epoch 5: Batch 22/233 loss: 0.9455
# Epoch 5: Batch 23/233 loss: 0.9371
# Epoch 5: Batch 24/233 loss: 0.9224
# Epoch 5: Batch 25/233 loss: 0.8602
# Epoch 5: Batch 26/233 loss: 0.8746
# Epoch 5: Batch 27/233 loss: 0.8408
# Epoch 5: Batch 28/233 loss: 0.8791
# Epoch 5: Batch 29/233 loss: 0.9097
# Epoch 5: Batch 30/233 loss: 0.9051
# Epoch 5: Batch 31/233 loss: 0.8825
# Epoch 5: Batch 32/233 loss: 0.8019
# Epoch 5: Batch 33/233 loss: 0.9319
# Epoch 5: Batch 34/233 loss: 0.9316
# Epoch 5: Batch 35/233 loss: 0.8833
# Epoch 5: Batch 36/233 loss: 0.8533
# Epoch 5: Batch 37/233 loss: 0.8783
# Epoch 5: Batch 38/233 loss: 0.9073
# Epoch 5: Batch 39/233 loss: 0.8373
# Epoch 5: Batch 40/233 loss: 0.8488
# Epoch 5: Batch 41/233 loss: 0.9115
# Epoch 5: Batch 42/233 loss: 0.9129
# Epoch 5: Batch 43/233 loss: 0.9327
# Epoch 5: Batch 44/233 loss: 0.8882
# Epoch 5: Batch 45/233 loss: 0.8612
# Epoch 5: Batch 46/233 loss: 0.8765
# Epoch 5: Batch 47/233 loss: 0.8713
# Epoch 5: Batch 48/233 loss: 0.9088
# Epoch 5: Batch 49/233 loss: 0.8965
# Epoch 5: Batch 50/233 loss: 0.9243
# Epoch 5: Batch 51/233 loss: 0.9459
# Epoch 5: Batch 52/233 loss: 0.8926
# Epoch 5: Batch 53/233 loss: 0.8506
# Epoch 5: Batch 54/233 loss: 0.9400
# Epoch 5: Batch 55/233 loss: 0.9237
# Epoch 5: Batch 56/233 loss: 0.8541
# Epoch 5: Batch 57/233 loss: 0.9399
# Epoch 5: Batch 58/233 loss: 0.8384
# Epoch 5: Batch 59/233 loss: 0.9342
# Epoch 5: Batch 60/233 loss: 0.8402
# Epoch 5: Batch 61/233 loss: 0.8569
# Epoch 5: Batch 62/233 loss: 0.7885
# Epoch 5: Batch 63/233 loss: 0.8753
# Epoch 5: Batch 64/233 loss: 0.8490
# Epoch 5: Batch 65/233 loss: 0.8502
# Epoch 5: Batch 66/233 loss: 0.8536
# Epoch 5: Batch 67/233 loss: 0.9208
# Epoch 5: Batch 68/233 loss: 0.8576
# Epoch 5: Batch 69/233 loss: 0.8370
# Epoch 5: Batch 70/233 loss: 0.8861
# Epoch 5: Batch 71/233 loss: 0.8968
# Epoch 5: Batch 72/233 loss: 0.8192
# Epoch 5: Batch 73/233 loss: 0.8753
# Epoch 5: Batch 74/233 loss: 0.8877
# Epoch 5: Batch 75/233 loss: 0.8949
# Epoch 5: Batch 76/233 loss: 0.8958
# Epoch 5: Batch 77/233 loss: 0.9371
# Epoch 5: Batch 78/233 loss: 0.8797
# Epoch 5: Batch 79/233 loss: 0.8712
# Epoch 5: Batch 80/233 loss: 0.9584
# Epoch 5: Batch 81/233 loss: 0.8560
# Epoch 5: Batch 82/233 loss: 0.8380
# Epoch 5: Batch 83/233 loss: 0.8785
# Epoch 5: Batch 84/233 loss: 0.9289
# Epoch 5: Batch 85/233 loss: 0.9085
# Epoch 5: Batch 86/233 loss: 0.9097
# Epoch 5: Batch 87/233 loss: 0.8671
# Epoch 5: Batch 88/233 loss: 0.9486
# Epoch 5: Batch 89/233 loss: 0.8906
# Epoch 5: Batch 90/233 loss: 0.8697
# Epoch 5: Batch 91/233 loss: 0.9309
# Epoch 5: Batch 92/233 loss: 0.8794
# Epoch 5: Batch 93/233 loss: 0.9862
# Epoch 5: Batch 94/233 loss: 0.9187
# Epoch 5: Batch 95/233 loss: 0.8891
# Epoch 5: Batch 96/233 loss: 0.9166
# Epoch 5: Batch 97/233 loss: 0.9033
# Epoch 5: Batch 98/233 loss: 0.8731
# Epoch 5: Batch 99/233 loss: 0.9728
# Epoch 5: Batch 100/233 loss: 0.8198
# Epoch 5: Batch 101/233 loss: 0.8860
# Epoch 5: Batch 102/233 loss: 0.9192
# Epoch 5: Batch 103/233 loss: 0.7824
# Epoch 5: Batch 104/233 loss: 0.8870
# Epoch 5: Batch 105/233 loss: 0.9343
# Epoch 5: Batch 106/233 loss: 0.8805
# Epoch 5: Batch 107/233 loss: 0.9131
# Epoch 5: Batch 108/233 loss: 0.8575
# Epoch 5: Batch 109/233 loss: 0.9316
# Epoch 5: Batch 110/233 loss: 0.9349
# Epoch 5: Batch 111/233 loss: 0.8588
# Epoch 5: Batch 112/233 loss: 0.8729
# Epoch 5: Batch 113/233 loss: 0.9442
# Epoch 5: Batch 114/233 loss: 0.8681
# Epoch 5: Batch 115/233 loss: 0.8890
# Epoch 5: Batch 116/233 loss: 0.8967
# Epoch 5: Batch 117/233 loss: 0.8552
# Epoch 5: Batch 118/233 loss: 0.9467
# Epoch 5: Batch 119/233 loss: 0.8993
# Epoch 5: Batch 120/233 loss: 0.8271
# Epoch 5: Batch 121/233 loss: 0.8776
# Epoch 5: Batch 122/233 loss: 0.8499
# Epoch 5: Batch 123/233 loss: 0.8797
# Epoch 5: Batch 124/233 loss: 0.9220
# Epoch 5: Batch 125/233 loss: 0.8645
# Epoch 5: Batch 126/233 loss: 0.9102
# Epoch 5: Batch 127/233 loss: 0.8742
# Epoch 5: Batch 128/233 loss: 0.9037
# Epoch 5: Batch 129/233 loss: 0.8511
# Epoch 5: Batch 130/233 loss: 0.8680
# Epoch 5: Batch 131/233 loss: 0.8716
# Epoch 5: Batch 132/233 loss: 0.8775
# Epoch 5: Batch 133/233 loss: 0.8499
# Epoch 5: Batch 134/233 loss: 0.9390
# Epoch 5: Batch 135/233 loss: 0.8630
# Epoch 5: Batch 136/233 loss: 0.9050
# Epoch 5: Batch 137/233 loss: 0.8841
# Epoch 5: Batch 138/233 loss: 0.8479
# Epoch 5: Batch 139/233 loss: 0.8115
# Epoch 5: Batch 140/233 loss: 0.8537
# Epoch 5: Batch 141/233 loss: 0.9029
# Epoch 5: Batch 142/233 loss: 0.8792
# Epoch 5: Batch 143/233 loss: 0.8865
# Epoch 5: Batch 144/233 loss: 0.9124
# Epoch 5: Batch 145/233 loss: 0.9054
# Epoch 5: Batch 146/233 loss: 0.9015
# Epoch 5: Batch 147/233 loss: 0.8477
# Epoch 5: Batch 148/233 loss: 0.8792
# Epoch 5: Batch 149/233 loss: 0.8253
# Epoch 5: Batch 150/233 loss: 0.8673
# Epoch 5: Batch 151/233 loss: 0.8661
# Epoch 5: Batch 152/233 loss: 0.9261
# Epoch 5: Batch 153/233 loss: 0.8789
# Epoch 5: Batch 154/233 loss: 0.8799
# Epoch 5: Batch 155/233 loss: 0.8094
# Epoch 5: Batch 156/233 loss: 0.8470
# Epoch 5: Batch 157/233 loss: 0.8742
# Epoch 5: Batch 158/233 loss: 0.8469
# Epoch 5: Batch 159/233 loss: 0.8572
# Epoch 5: Batch 160/233 loss: 0.8146
# Epoch 5: Batch 161/233 loss: 0.9235
# Epoch 5: Batch 162/233 loss: 0.8483
# Epoch 5: Batch 163/233 loss: 0.9170
# Epoch 5: Batch 164/233 loss: 0.8337
# Epoch 5: Batch 165/233 loss: 0.8255
# Epoch 5: Batch 166/233 loss: 0.9059
# Epoch 5: Batch 167/233 loss: 0.9479
# Epoch 5: Batch 168/233 loss: 0.9118
# Epoch 5: Batch 169/233 loss: 0.8463
# Epoch 5: Batch 170/233 loss: 0.8702
# Epoch 5: Batch 171/233 loss: 0.9522
# Epoch 5: Batch 172/233 loss: 0.9106
# Epoch 5: Batch 173/233 loss: 0.8064
# Epoch 5: Batch 174/233 loss: 0.8659
# Epoch 5: Batch 175/233 loss: 0.8518
# Epoch 5: Batch 176/233 loss: 0.8695
# Epoch 5: Batch 177/233 loss: 0.9394
# Epoch 5: Batch 178/233 loss: 0.8268
# Epoch 5: Batch 179/233 loss: 0.8451
# Epoch 5: Batch 180/233 loss: 0.8460
# Epoch 5: Batch 181/233 loss: 0.9006
# Epoch 5: Batch 182/233 loss: 0.9251
# Epoch 5: Batch 183/233 loss: 0.9430
# Epoch 5: Batch 184/233 loss: 0.9360
# Epoch 5: Batch 185/233 loss: 0.8579
# Epoch 5: Batch 186/233 loss: 0.8038
# Epoch 5: Batch 187/233 loss: 0.9233
# Epoch 5: Batch 188/233 loss: 0.9343
# Epoch 5: Batch 189/233 loss: 0.8572
# Epoch 5: Batch 190/233 loss: 0.8906
# Epoch 5: Batch 191/233 loss: 0.9149
# Epoch 5: Batch 192/233 loss: 0.8909
# Epoch 5: Batch 193/233 loss: 0.9370
# Epoch 5: Batch 194/233 loss: 0.8482
# Epoch 5: Batch 195/233 loss: 0.7779
# Epoch 5: Batch 196/233 loss: 0.8985
# Epoch 5: Batch 197/233 loss: 0.9351
# Epoch 5: Batch 198/233 loss: 0.8148
# Epoch 5: Batch 199/233 loss: 0.8962
# Epoch 5: Batch 200/233 loss: 0.8805
# Epoch 5: Batch 201/233 loss: 0.9610
# Epoch 5: Batch 202/233 loss: 0.8583
# Epoch 5: Batch 203/233 loss: 0.8346
# Epoch 5: Batch 204/233 loss: 0.9102
# Epoch 5: Batch 205/233 loss: 0.9084
# Epoch 5: Batch 206/233 loss: 0.8406
# Epoch 5: Batch 207/233 loss: 0.8791
# Epoch 5: Batch 208/233 loss: 0.9183
# Epoch 5: Batch 209/233 loss: 0.8427
# Epoch 5: Batch 210/233 loss: 0.8932
# Epoch 5: Batch 211/233 loss: 0.8420
# Epoch 5: Batch 212/233 loss: 0.8923
# Epoch 5: Batch 213/233 loss: 0.8315
# Epoch 5: Batch 214/233 loss: 0.8768
# Epoch 5: Batch 215/233 loss: 0.9590
# Epoch 5: Batch 216/233 loss: 0.9199
# Epoch 5: Batch 217/233 loss: 0.8698
# Epoch 5: Batch 218/233 loss: 0.8610
# Epoch 5: Batch 219/233 loss: 0.9020
# Epoch 5: Batch 220/233 loss: 0.9160
# Epoch 5: Batch 221/233 loss: 0.8626
# Epoch 5: Batch 222/233 loss: 0.9043
# Epoch 5: Batch 223/233 loss: 0.9103
# Epoch 5: Batch 224/233 loss: 0.8983
# Epoch 5: Batch 225/233 loss: 0.9004
# Epoch 5: Batch 226/233 loss: 0.8106
# Epoch 5: Batch 227/233 loss: 0.9071
# Epoch 5: Batch 228/233 loss: 0.9182
# Epoch 5: Batch 229/233 loss: 0.8780
# Epoch 5: Batch 230/233 loss: 0.8656
# Epoch 5: Batch 231/233 loss: 0.8809
# Epoch 5: Batch 232/233 loss: 0.9234
# Epoch 5: Batch 233/233 loss: 0.8239
# Epoch 5 train loss: 0.8856 valid loss: 0.8742
# performance reducing: 2
# Epoch 6: Batch 1/233 loss: 0.9317
# Epoch 6: Batch 2/233 loss: 0.8598
# Epoch 6: Batch 3/233 loss: 0.9346
# Epoch 6: Batch 4/233 loss: 0.8492
# Epoch 6: Batch 5/233 loss: 0.9016
# Epoch 6: Batch 6/233 loss: 0.9337
# Epoch 6: Batch 7/233 loss: 0.8796
# Epoch 6: Batch 8/233 loss: 0.9395
# Epoch 6: Batch 9/233 loss: 0.8336
# Epoch 6: Batch 10/233 loss: 0.9423
# Epoch 6: Batch 11/233 loss: 0.8897
# Epoch 6: Batch 12/233 loss: 0.7801
# Epoch 6: Batch 13/233 loss: 0.8786
# Epoch 6: Batch 14/233 loss: 0.8194
# Epoch 6: Batch 15/233 loss: 0.9138
# Epoch 6: Batch 16/233 loss: 0.8832
# Epoch 6: Batch 17/233 loss: 0.9377
# Epoch 6: Batch 18/233 loss: 0.8981
# Epoch 6: Batch 19/233 loss: 0.8885
# Epoch 6: Batch 20/233 loss: 0.8854
# Epoch 6: Batch 21/233 loss: 0.8645
# Epoch 6: Batch 22/233 loss: 0.9251
# Epoch 6: Batch 23/233 loss: 0.9291
# Epoch 6: Batch 24/233 loss: 0.8751
# Epoch 6: Batch 25/233 loss: 0.9059
# Epoch 6: Batch 26/233 loss: 0.8410
# Epoch 6: Batch 27/233 loss: 0.9288
# Epoch 6: Batch 28/233 loss: 0.8691
# Epoch 6: Batch 29/233 loss: 0.9043
# Epoch 6: Batch 30/233 loss: 0.8982
# Epoch 6: Batch 31/233 loss: 0.8572
# Epoch 6: Batch 32/233 loss: 0.8586
# Epoch 6: Batch 33/233 loss: 0.8721
# Epoch 6: Batch 34/233 loss: 0.7929
# Epoch 6: Batch 35/233 loss: 0.8920
# Epoch 6: Batch 36/233 loss: 0.8894
# Epoch 6: Batch 37/233 loss: 0.9164
# Epoch 6: Batch 38/233 loss: 0.8650
# Epoch 6: Batch 39/233 loss: 0.7393
# Epoch 6: Batch 40/233 loss: 0.9346
# Epoch 6: Batch 41/233 loss: 0.8347
# Epoch 6: Batch 42/233 loss: 0.9097
# Epoch 6: Batch 43/233 loss: 0.8527
# Epoch 6: Batch 44/233 loss: 0.9064
# Epoch 6: Batch 45/233 loss: 0.8977
# Epoch 6: Batch 46/233 loss: 0.9415
# Epoch 6: Batch 47/233 loss: 0.8944
# Epoch 6: Batch 48/233 loss: 0.9070
# Epoch 6: Batch 49/233 loss: 0.9547
# Epoch 6: Batch 50/233 loss: 0.8153
# Epoch 6: Batch 51/233 loss: 0.8749
# Epoch 6: Batch 52/233 loss: 0.9018
# Epoch 6: Batch 53/233 loss: 0.9439
# Epoch 6: Batch 54/233 loss: 0.8864
# Epoch 6: Batch 55/233 loss: 0.8622
# Epoch 6: Batch 56/233 loss: 0.9409
# Epoch 6: Batch 57/233 loss: 0.9114
# Epoch 6: Batch 58/233 loss: 0.8476
# Epoch 6: Batch 59/233 loss: 0.8854
# Epoch 6: Batch 60/233 loss: 0.8559
# Epoch 6: Batch 61/233 loss: 0.8998
# Epoch 6: Batch 62/233 loss: 0.8636
# Epoch 6: Batch 63/233 loss: 0.8735
# Epoch 6: Batch 64/233 loss: 0.9539
# Epoch 6: Batch 65/233 loss: 0.8465
# Epoch 6: Batch 66/233 loss: 0.8918
# Epoch 6: Batch 67/233 loss: 0.8982
# Epoch 6: Batch 68/233 loss: 0.8732
# Epoch 6: Batch 69/233 loss: 0.9089
# Epoch 6: Batch 70/233 loss: 0.9600
# Epoch 6: Batch 71/233 loss: 0.8832
# Epoch 6: Batch 72/233 loss: 0.8575
# Epoch 6: Batch 73/233 loss: 0.8746
# Epoch 6: Batch 74/233 loss: 0.8811
# Epoch 6: Batch 75/233 loss: 0.9595
# Epoch 6: Batch 76/233 loss: 0.7926
# Epoch 6: Batch 77/233 loss: 0.9173
# Epoch 6: Batch 78/233 loss: 0.8335
# Epoch 6: Batch 79/233 loss: 0.8748
# Epoch 6: Batch 80/233 loss: 0.8853
# Epoch 6: Batch 81/233 loss: 0.9348
# Epoch 6: Batch 82/233 loss: 0.8169
# Epoch 6: Batch 83/233 loss: 0.8930
# Epoch 6: Batch 84/233 loss: 0.8800
# Epoch 6: Batch 85/233 loss: 0.8397
# Epoch 6: Batch 86/233 loss: 0.9065
# Epoch 6: Batch 87/233 loss: 0.9806
# Epoch 6: Batch 88/233 loss: 0.8093
# Epoch 6: Batch 89/233 loss: 0.8524
# Epoch 6: Batch 90/233 loss: 0.9152
# Epoch 6: Batch 91/233 loss: 0.9163
# Epoch 6: Batch 92/233 loss: 0.9008
# Epoch 6: Batch 93/233 loss: 0.9202
# Epoch 6: Batch 94/233 loss: 0.8642
# Epoch 6: Batch 95/233 loss: 0.9196
# Epoch 6: Batch 96/233 loss: 0.8441
# Epoch 6: Batch 97/233 loss: 0.8789
# Epoch 6: Batch 98/233 loss: 0.8532
# Epoch 6: Batch 99/233 loss: 0.9375
# Epoch 6: Batch 100/233 loss: 0.8815
# Epoch 6: Batch 101/233 loss: 0.8976
# Epoch 6: Batch 102/233 loss: 0.8377
# Epoch 6: Batch 103/233 loss: 0.8460
# Epoch 6: Batch 104/233 loss: 0.8098
# Epoch 6: Batch 105/233 loss: 0.8841
# Epoch 6: Batch 106/233 loss: 0.9506
# Epoch 6: Batch 107/233 loss: 0.8369
# Epoch 6: Batch 108/233 loss: 0.8793
# Epoch 6: Batch 109/233 loss: 0.8927
# Epoch 6: Batch 110/233 loss: 0.8533
# Epoch 6: Batch 111/233 loss: 0.9268
# Epoch 6: Batch 112/233 loss: 0.8628
# Epoch 6: Batch 113/233 loss: 0.8409
# Epoch 6: Batch 114/233 loss: 0.8531
# Epoch 6: Batch 115/233 loss: 0.9234
# Epoch 6: Batch 116/233 loss: 0.8828
# Epoch 6: Batch 117/233 loss: 0.9230
# Epoch 6: Batch 118/233 loss: 0.9291
# Epoch 6: Batch 119/233 loss: 0.9050
# Epoch 6: Batch 120/233 loss: 0.8907
# Epoch 6: Batch 121/233 loss: 0.8133
# Epoch 6: Batch 122/233 loss: 0.8514
# Epoch 6: Batch 123/233 loss: 0.8992
# Epoch 6: Batch 124/233 loss: 0.9074
# Epoch 6: Batch 125/233 loss: 0.8148
# Epoch 6: Batch 126/233 loss: 0.8852
# Epoch 6: Batch 127/233 loss: 0.9310
# Epoch 6: Batch 128/233 loss: 0.8860
# Epoch 6: Batch 129/233 loss: 0.8774
# Epoch 6: Batch 130/233 loss: 0.8812
# Epoch 6: Batch 131/233 loss: 0.8338
# Epoch 6: Batch 132/233 loss: 0.9452
# Epoch 6: Batch 133/233 loss: 0.8264
# Epoch 6: Batch 134/233 loss: 0.9265
# Epoch 6: Batch 135/233 loss: 0.9016
# Epoch 6: Batch 136/233 loss: 0.9437
# Epoch 6: Batch 137/233 loss: 0.8154
# Epoch 6: Batch 138/233 loss: 0.8466
# Epoch 6: Batch 139/233 loss: 0.9065
# Epoch 6: Batch 140/233 loss: 0.8823
# Epoch 6: Batch 141/233 loss: 0.8627
# Epoch 6: Batch 142/233 loss: 0.8657
# Epoch 6: Batch 143/233 loss: 0.9014
# Epoch 6: Batch 144/233 loss: 0.8336
# Epoch 6: Batch 145/233 loss: 0.8539
# Epoch 6: Batch 146/233 loss: 0.8936
# Epoch 6: Batch 147/233 loss: 0.9493
# Epoch 6: Batch 148/233 loss: 0.9033
# Epoch 6: Batch 149/233 loss: 0.9148
# Epoch 6: Batch 150/233 loss: 0.8960
# Epoch 6: Batch 151/233 loss: 0.9041
# Epoch 6: Batch 152/233 loss: 0.8854
# Epoch 6: Batch 153/233 loss: 0.8809
# Epoch 6: Batch 154/233 loss: 0.9065
# Epoch 6: Batch 155/233 loss: 0.8584
# Epoch 6: Batch 156/233 loss: 0.8628
# Epoch 6: Batch 157/233 loss: 0.8118
# Epoch 6: Batch 158/233 loss: 0.8902
# Epoch 6: Batch 159/233 loss: 0.9052
# Epoch 6: Batch 160/233 loss: 0.9388
# Epoch 6: Batch 161/233 loss: 0.9320
# Epoch 6: Batch 162/233 loss: 0.8545
# Epoch 6: Batch 163/233 loss: 0.9545
# Epoch 6: Batch 164/233 loss: 0.8971
# Epoch 6: Batch 165/233 loss: 0.8518
# Epoch 6: Batch 166/233 loss: 0.7587
# Epoch 6: Batch 167/233 loss: 0.8443
# Epoch 6: Batch 168/233 loss: 0.9214
# Epoch 6: Batch 169/233 loss: 0.8872
# Epoch 6: Batch 170/233 loss: 0.9330
# Epoch 6: Batch 171/233 loss: 0.8537
# Epoch 6: Batch 172/233 loss: 0.9189
# Epoch 6: Batch 173/233 loss: 0.9264
# Epoch 6: Batch 174/233 loss: 0.8859
# Epoch 6: Batch 175/233 loss: 0.9249
# Epoch 6: Batch 176/233 loss: 0.8724
# Epoch 6: Batch 177/233 loss: 0.8736
# Epoch 6: Batch 178/233 loss: 0.8559
# ...
# Epoch 179: Batch 46/233 loss: 0.8482
# Epoch 179: Batch 47/233 loss: 0.8627
# Epoch 179: Batch 48/233 loss: 0.8556
# Epoch 179: Batch 49/233 loss: 0.8786
# Epoch 179: Batch 50/233 loss: 0.8727
# Epoch 179: Batch 51/233 loss: 0.8670
# Epoch 179: Batch 52/233 loss: 0.8619
# Epoch 179: Batch 53/233 loss: 0.8998
# Epoch 179: Batch 54/233 loss: 0.9201
# Epoch 179: Batch 55/233 loss: 0.8619
# Epoch 179: Batch 56/233 loss: 0.9231
# Epoch 179: Batch 57/233 loss: 0.8482
# Epoch 179: Batch 58/233 loss: 0.9255
# Epoch 179: Batch 59/233 loss: 0.8551
# Epoch 179: Batch 60/233 loss: 0.8609
# Epoch 179: Batch 61/233 loss: 0.8605
# Epoch 179: Batch 62/233 loss: 0.9104
# Epoch 179: Batch 63/233 loss: 0.8948
# Epoch 179: Batch 64/233 loss: 0.9007
# Epoch 179: Batch 65/233 loss: 0.8855
# Epoch 179: Batch 66/233 loss: 0.8907
# Epoch 179: Batch 67/233 loss: 0.8865
# Epoch 179: Batch 68/233 loss: 0.8830
# Epoch 179: Batch 69/233 loss: 0.8203
# Epoch 179: Batch 70/233 loss: 0.9094
# Epoch 179: Batch 71/233 loss: 0.8886
# Epoch 179: Batch 72/233 loss: 0.9430
# Epoch 179: Batch 73/233 loss: 0.8783
# Epoch 179: Batch 74/233 loss: 0.8917
# Epoch 179: Batch 75/233 loss: 0.8826
# Epoch 179: Batch 76/233 loss: 0.8948
# Epoch 179: Batch 77/233 loss: 0.9195
# Epoch 179: Batch 78/233 loss: 0.9296
# Epoch 179: Batch 79/233 loss: 0.8509
# Epoch 179: Batch 80/233 loss: 0.9286
# Epoch 179: Batch 81/233 loss: 0.9372
# Epoch 179: Batch 82/233 loss: 0.9708
# Epoch 179: Batch 83/233 loss: 0.8790
# Epoch 179: Batch 84/233 loss: 0.9127
# Epoch 179: Batch 85/233 loss: 0.9287
# Epoch 179: Batch 86/233 loss: 0.8417
# Epoch 179: Batch 87/233 loss: 0.9377
# Epoch 179: Batch 88/233 loss: 0.8339
# Epoch 179: Batch 89/233 loss: 0.9105
# Epoch 179: Batch 90/233 loss: 0.8800
# Epoch 179: Batch 91/233 loss: 0.8549
# Epoch 179: Batch 92/233 loss: 0.8753
# Epoch 179: Batch 93/233 loss: 0.8548
# Epoch 179: Batch 94/233 loss: 0.8320
# Epoch 179: Batch 95/233 loss: 0.8768
# Epoch 179: Batch 96/233 loss: 0.8996
# Epoch 179: Batch 97/233 loss: 0.8272
# Epoch 179: Batch 98/233 loss: 0.8638
# Epoch 179: Batch 99/233 loss: 0.8646
# Epoch 179: Batch 100/233 loss: 0.8944
# Epoch 179: Batch 101/233 loss: 0.8840
# Epoch 179: Batch 102/233 loss: 0.8728
# Epoch 179: Batch 103/233 loss: 0.8329
# Epoch 179: Batch 104/233 loss: 0.8865
# Epoch 179: Batch 105/233 loss: 0.8971
# Epoch 179: Batch 106/233 loss: 0.9009
# Epoch 179: Batch 107/233 loss: 0.9494
# Epoch 179: Batch 108/233 loss: 0.9135
# Epoch 179: Batch 109/233 loss: 0.8969
# Epoch 179: Batch 110/233 loss: 0.8050
# Epoch 179: Batch 111/233 loss: 0.9112
# Epoch 179: Batch 112/233 loss: 0.9399
# Epoch 179: Batch 113/233 loss: 0.8475
# Epoch 179: Batch 114/233 loss: 0.8649
# Epoch 179: Batch 115/233 loss: 0.8738
# Epoch 179: Batch 116/233 loss: 0.8635
# Epoch 179: Batch 117/233 loss: 0.8339
# Epoch 179: Batch 118/233 loss: 0.9107
# Epoch 179: Batch 119/233 loss: 0.8476
# Epoch 179: Batch 120/233 loss: 0.8485
# Epoch 179: Batch 121/233 loss: 0.8771
# Epoch 179: Batch 122/233 loss: 0.8863
# Epoch 179: Batch 123/233 loss: 0.8761
# Epoch 179: Batch 124/233 loss: 0.9209
# Epoch 179: Batch 125/233 loss: 0.9628
# Epoch 179: Batch 126/233 loss: 0.8137
# Epoch 179: Batch 127/233 loss: 0.9098
# Epoch 179: Batch 128/233 loss: 0.7989
# Epoch 179: Batch 129/233 loss: 0.9221
# Epoch 179: Batch 130/233 loss: 0.9046
# Epoch 179: Batch 131/233 loss: 0.8731
# Epoch 179: Batch 132/233 loss: 0.8529
# Epoch 179: Batch 133/233 loss: 0.8782
# Epoch 179: Batch 134/233 loss: 0.8858
# Epoch 179: Batch 135/233 loss: 0.9328
# Epoch 179: Batch 136/233 loss: 0.9106
# Epoch 179: Batch 137/233 loss: 0.9336
# Epoch 179: Batch 138/233 loss: 0.8360
# Epoch 179: Batch 139/233 loss: 0.9008
# Epoch 179: Batch 140/233 loss: 0.8399
# Epoch 179: Batch 141/233 loss: 0.8704
# Epoch 179: Batch 142/233 loss: 0.8720
# Epoch 179: Batch 143/233 loss: 0.8629
# Epoch 179: Batch 144/233 loss: 0.9378
# Epoch 179: Batch 145/233 loss: 0.9504
# Epoch 179: Batch 146/233 loss: 0.8951
# Epoch 179: Batch 147/233 loss: 0.8330
# Epoch 179: Batch 148/233 loss: 0.8757
# Epoch 179: Batch 149/233 loss: 0.9130
# Epoch 179: Batch 150/233 loss: 0.8358
# Epoch 179: Batch 151/233 loss: 0.8790
# Epoch 179: Batch 152/233 loss: 0.8825
# Epoch 179: Batch 153/233 loss: 0.8852
# Epoch 179: Batch 154/233 loss: 0.8902
# Epoch 179: Batch 155/233 loss: 0.8757
# Epoch 179: Batch 156/233 loss: 0.8330
# Epoch 179: Batch 157/233 loss: 0.8690
# Epoch 179: Batch 158/233 loss: 0.8629
# Epoch 179: Batch 159/233 loss: 0.9509
# Epoch 179: Batch 160/233 loss: 0.9104
# Epoch 179: Batch 161/233 loss: 0.9186
# Epoch 179: Batch 162/233 loss: 0.9512
# Epoch 179: Batch 163/233 loss: 0.9175
# Epoch 179: Batch 164/233 loss: 0.8716
# Epoch 179: Batch 165/233 loss: 0.8480
# Epoch 179: Batch 166/233 loss: 0.9593
# Epoch 179: Batch 167/233 loss: 0.9389
# Epoch 179: Batch 168/233 loss: 0.8593
# Epoch 179: Batch 169/233 loss: 0.9117
# Epoch 179: Batch 170/233 loss: 0.8506
# Epoch 179: Batch 171/233 loss: 0.8967
# Epoch 179: Batch 172/233 loss: 0.8811
# Epoch 179: Batch 173/233 loss: 0.8636
# Epoch 179: Batch 174/233 loss: 0.9143
# Epoch 179: Batch 175/233 loss: 0.8299
# Epoch 179: Batch 176/233 loss: 0.8799
# Epoch 179: Batch 177/233 loss: 0.8710
# Epoch 179: Batch 178/233 loss: 0.7992
# Epoch 179: Batch 179/233 loss: 0.8470
# Epoch 179: Batch 180/233 loss: 0.8491
# Epoch 179: Batch 181/233 loss: 0.9071
# Epoch 179: Batch 182/233 loss: 0.9021
# Epoch 179: Batch 183/233 loss: 0.8497
# Epoch 179: Batch 184/233 loss: 0.8972
# Epoch 179: Batch 185/233 loss: 0.8642
# Epoch 179: Batch 186/233 loss: 0.8982
# Epoch 179: Batch 187/233 loss: 0.8874
# Epoch 179: Batch 188/233 loss: 0.8956
# Epoch 179: Batch 189/233 loss: 0.8126
# Epoch 179: Batch 190/233 loss: 0.9176
# Epoch 179: Batch 191/233 loss: 0.9070
# Epoch 179: Batch 192/233 loss: 0.9041
# Epoch 179: Batch 193/233 loss: 0.8854
# Epoch 179: Batch 194/233 loss: 0.9432
# Epoch 179: Batch 195/233 loss: 0.8106
# Epoch 179: Batch 196/233 loss: 0.9469
# Epoch 179: Batch 197/233 loss: 0.9029
# Epoch 179: Batch 198/233 loss: 0.8797
# Epoch 179: Batch 199/233 loss: 0.9091
# Epoch 179: Batch 200/233 loss: 0.8784
# Epoch 179: Batch 201/233 loss: 0.8220
# Epoch 179: Batch 202/233 loss: 0.8706
# Epoch 179: Batch 203/233 loss: 0.8779
# Epoch 179: Batch 204/233 loss: 0.8522
# Epoch 179: Batch 205/233 loss: 0.8761
# Epoch 179: Batch 206/233 loss: 0.8915
# Epoch 179: Batch 207/233 loss: 0.8948
# Epoch 179: Batch 208/233 loss: 0.8977
# Epoch 179: Batch 209/233 loss: 0.8260
# Epoch 179: Batch 210/233 loss: 0.8141
# Epoch 179: Batch 211/233 loss: 0.8920
# Epoch 179: Batch 212/233 loss: 0.8870
# Epoch 179: Batch 213/233 loss: 0.8809
# Epoch 179: Batch 214/233 loss: 0.9268
# Epoch 179: Batch 215/233 loss: 0.8857
# Epoch 179: Batch 216/233 loss: 0.9061
# Epoch 179: Batch 217/233 loss: 0.8789
# Epoch 179: Batch 218/233 loss: 0.9253
# Epoch 179: Batch 219/233 loss: 0.8896
# Epoch 179: Batch 220/233 loss: 0.9020
# Epoch 179: Batch 221/233 loss: 0.9045
# Epoch 179: Batch 222/233 loss: 0.8903
# Epoch 179: Batch 223/233 loss: 0.9079
# Epoch 179: Batch 224/233 loss: 0.9152
# Epoch 179: Batch 225/233 loss: 0.8549
# Epoch 179: Batch 226/233 loss: 0.8878
# Epoch 179: Batch 227/233 loss: 0.8512
# Epoch 179: Batch 228/233 loss: 0.7763
# Epoch 179: Batch 229/233 loss: 0.8732
# Epoch 179: Batch 230/233 loss: 0.8413
# Epoch 179: Batch 231/233 loss: 0.8405
# Epoch 179: Batch 232/233 loss: 0.8612
# Epoch 179: Batch 233/233 loss: 0.9254
# Epoch 179 train loss: 0.8858 valid loss: 0.8731
# performance reducing: 21
# Epoch 180: Batch 1/233 loss: 0.8563
# Epoch 180: Batch 2/233 loss: 0.8748
# Epoch 180: Batch 3/233 loss: 0.9195
# Epoch 180: Batch 4/233 loss: 0.9507
# Epoch 180: Batch 5/233 loss: 0.8850
# Epoch 180: Batch 6/233 loss: 0.8737
# Epoch 180: Batch 7/233 loss: 0.8504
# Epoch 180: Batch 8/233 loss: 0.8694
# Epoch 180: Batch 9/233 loss: 0.9832
# Epoch 180: Batch 10/233 loss: 0.8693
# Epoch 180: Batch 11/233 loss: 0.9774
# Epoch 180: Batch 12/233 loss: 0.9018
# Epoch 180: Batch 13/233 loss: 0.8712
# Epoch 180: Batch 14/233 loss: 0.8289
# Epoch 180: Batch 15/233 loss: 0.9252
# Epoch 180: Batch 16/233 loss: 0.8319
# Epoch 180: Batch 17/233 loss: 0.8572
# Epoch 180: Batch 18/233 loss: 0.9275
# Epoch 180: Batch 19/233 loss: 0.9413
# Epoch 180: Batch 20/233 loss: 0.8903
# Epoch 180: Batch 21/233 loss: 0.9286
# Epoch 180: Batch 22/233 loss: 0.9535
# Epoch 180: Batch 23/233 loss: 0.9002
# Epoch 180: Batch 24/233 loss: 0.8337
# Epoch 180: Batch 25/233 loss: 0.8989
# Epoch 180: Batch 26/233 loss: 0.8928
# Epoch 180: Batch 27/233 loss: 0.8977
# Epoch 180: Batch 28/233 loss: 0.9173
# Epoch 180: Batch 29/233 loss: 0.9141
# Epoch 180: Batch 30/233 loss: 0.8990
# Epoch 180: Batch 31/233 loss: 0.9330
# Epoch 180: Batch 32/233 loss: 0.8892
# Epoch 180: Batch 33/233 loss: 0.9179
# Epoch 180: Batch 34/233 loss: 0.9206
# Epoch 180: Batch 35/233 loss: 0.8266
# Epoch 180: Batch 36/233 loss: 0.8823
# Epoch 180: Batch 37/233 loss: 0.9050
# Epoch 180: Batch 38/233 loss: 0.9205
# Epoch 180: Batch 39/233 loss: 0.7620
# Epoch 180: Batch 40/233 loss: 0.9384
# Epoch 180: Batch 41/233 loss: 0.8676
# Epoch 180: Batch 42/233 loss: 0.9633
# Epoch 180: Batch 43/233 loss: 0.8789
# Epoch 180: Batch 44/233 loss: 0.9046
# Epoch 180: Batch 45/233 loss: 0.9348
# Epoch 180: Batch 46/233 loss: 0.9090
# Epoch 180: Batch 47/233 loss: 0.9433
# Epoch 180: Batch 48/233 loss: 0.8479
# Epoch 180: Batch 49/233 loss: 0.8567
# Epoch 180: Batch 50/233 loss: 0.8875
# Epoch 180: Batch 51/233 loss: 0.8703
# Epoch 180: Batch 52/233 loss: 0.8611
# Epoch 180: Batch 53/233 loss: 0.8788
# Epoch 180: Batch 54/233 loss: 0.9179
# Epoch 180: Batch 55/233 loss: 0.9070
# Epoch 180: Batch 56/233 loss: 0.8830
# Epoch 180: Batch 57/233 loss: 0.7806
# Epoch 180: Batch 58/233 loss: 0.8916
# Epoch 180: Batch 59/233 loss: 0.9171
# Epoch 180: Batch 60/233 loss: 0.8560
# Epoch 180: Batch 61/233 loss: 0.9217
# Epoch 180: Batch 62/233 loss: 0.8884
# Epoch 180: Batch 63/233 loss: 0.8858
# Epoch 180: Batch 64/233 loss: 0.8870
# Epoch 180: Batch 65/233 loss: 0.8658
# Epoch 180: Batch 66/233 loss: 0.8204
# Epoch 180: Batch 67/233 loss: 0.9167
# Epoch 180: Batch 68/233 loss: 0.9018
# Epoch 180: Batch 69/233 loss: 0.8450
# Epoch 180: Batch 70/233 loss: 0.8821
# Epoch 180: Batch 71/233 loss: 0.9282
# Epoch 180: Batch 72/233 loss: 0.9206
# Epoch 180: Batch 73/233 loss: 0.9114
# Epoch 180: Batch 74/233 loss: 0.8732
# Epoch 180: Batch 75/233 loss: 0.9275
# Epoch 180: Batch 76/233 loss: 0.8899
# Epoch 180: Batch 77/233 loss: 0.8182
# Epoch 180: Batch 78/233 loss: 0.8799
# Epoch 180: Batch 79/233 loss: 0.9234
# Epoch 180: Batch 80/233 loss: 0.8947
# Epoch 180: Batch 81/233 loss: 0.9226
# Epoch 180: Batch 82/233 loss: 0.8617
# Epoch 180: Batch 83/233 loss: 0.8461
# Epoch 180: Batch 84/233 loss: 0.8650
# Epoch 180: Batch 85/233 loss: 0.8253
# Epoch 180: Batch 86/233 loss: 0.9187
# Epoch 180: Batch 87/233 loss: 0.9002
# Epoch 180: Batch 88/233 loss: 0.8508
# Epoch 180: Batch 89/233 loss: 0.8630
# Epoch 180: Batch 90/233 loss: 0.8958
# Epoch 180: Batch 91/233 loss: 0.8564
# Epoch 180: Batch 92/233 loss: 0.8706
# Epoch 180: Batch 93/233 loss: 0.8505
# Epoch 180: Batch 94/233 loss: 0.8648
# Epoch 180: Batch 95/233 loss: 0.8078
# Epoch 180: Batch 96/233 loss: 0.8963
# Epoch 180: Batch 97/233 loss: 0.9229
# Epoch 180: Batch 98/233 loss: 0.8011
# Epoch 180: Batch 99/233 loss: 0.9032
# Epoch 180: Batch 100/233 loss: 0.8520
# Epoch 180: Batch 101/233 loss: 0.8955
# Epoch 180: Batch 102/233 loss: 0.9013
# Epoch 180: Batch 103/233 loss: 0.9464
# Epoch 180: Batch 104/233 loss: 0.8726
# Epoch 180: Batch 105/233 loss: 0.8508
# Epoch 180: Batch 106/233 loss: 0.8893
# Epoch 180: Batch 107/233 loss: 0.9204
# Epoch 180: Batch 108/233 loss: 0.9381
# Epoch 180: Batch 109/233 loss: 0.8660
# Epoch 180: Batch 110/233 loss: 0.9163
# Epoch 180: Batch 111/233 loss: 0.9278
# Epoch 180: Batch 112/233 loss: 0.8969
# Epoch 180: Batch 113/233 loss: 0.9110
# Epoch 180: Batch 114/233 loss: 0.9051
# Epoch 180: Batch 115/233 loss: 0.8535
# Epoch 180: Batch 116/233 loss: 0.8951
# Epoch 180: Batch 117/233 loss: 0.8488
# Epoch 180: Batch 118/233 loss: 0.9535
# Epoch 180: Batch 119/233 loss: 0.9213
# Epoch 180: Batch 120/233 loss: 0.8613
# Epoch 180: Batch 121/233 loss: 0.8995
# Epoch 180: Batch 122/233 loss: 0.8288
# Epoch 180: Batch 123/233 loss: 0.8804
# Epoch 180: Batch 124/233 loss: 0.8719
# Epoch 180: Batch 125/233 loss: 0.8530
# Epoch 180: Batch 126/233 loss: 0.8309
# Epoch 180: Batch 127/233 loss: 0.8579
# Epoch 180: Batch 128/233 loss: 0.8593
# Epoch 180: Batch 129/233 loss: 0.8812
# Epoch 180: Batch 130/233 loss: 0.8888
# Epoch 180: Batch 131/233 loss: 0.9425
# Epoch 180: Batch 132/233 loss: 0.9786
# Epoch 180: Batch 133/233 loss: 0.9173
# Epoch 180: Batch 134/233 loss: 0.9214
# Epoch 180: Batch 135/233 loss: 0.8979
# Epoch 180: Batch 136/233 loss: 0.9323
# Epoch 180: Batch 137/233 loss: 0.8201
# Epoch 180: Batch 138/233 loss: 0.8900
# Epoch 180: Batch 139/233 loss: 0.8745
# Epoch 180: Batch 140/233 loss: 0.9027
# Epoch 180: Batch 141/233 loss: 0.8878
# Epoch 180: Batch 142/233 loss: 0.8187
# Epoch 180: Batch 143/233 loss: 0.7628
# Epoch 180: Batch 144/233 loss: 0.9113
# Epoch 180: Batch 145/233 loss: 0.8954
# Epoch 180: Batch 146/233 loss: 0.9156
# Epoch 180: Batch 147/233 loss: 0.7915
# Epoch 180: Batch 148/233 loss: 0.8649
# Epoch 180: Batch 149/233 loss: 0.8135
# Epoch 180: Batch 150/233 loss: 0.9070
# Epoch 180: Batch 151/233 loss: 0.9508
# Epoch 180: Batch 152/233 loss: 0.8751
# Epoch 180: Batch 153/233 loss: 0.8695
# Epoch 180: Batch 154/233 loss: 0.8942
# Epoch 180: Batch 155/233 loss: 0.9179
# Epoch 180: Batch 156/233 loss: 0.8558
# Epoch 180: Batch 157/233 loss: 0.9095
# Epoch 180: Batch 158/233 loss: 0.8969
# Epoch 180: Batch 159/233 loss: 0.8177
# Epoch 180: Batch 160/233 loss: 0.9009
# Epoch 180: Batch 161/233 loss: 0.9047
# Epoch 180: Batch 162/233 loss: 0.9122
# Epoch 180: Batch 163/233 loss: 0.9165
# Epoch 180: Batch 164/233 loss: 0.9481
# Epoch 180: Batch 165/233 loss: 0.8899
# Epoch 180: Batch 166/233 loss: 0.8308
# Epoch 180: Batch 167/233 loss: 0.8527
# Epoch 180: Batch 168/233 loss: 0.9277
# Epoch 180: Batch 169/233 loss: 0.8659
# Epoch 180: Batch 170/233 loss: 0.9282
# Epoch 180: Batch 171/233 loss: 0.8921
# Epoch 180: Batch 172/233 loss: 0.8454
# Epoch 180: Batch 173/233 loss: 0.8518
# Epoch 180: Batch 174/233 loss: 0.9013
# Epoch 180: Batch 175/233 loss: 0.9101
# Epoch 180: Batch 176/233 loss: 0.8544
# Epoch 180: Batch 177/233 loss: 0.9724
# Epoch 180: Batch 178/233 loss: 0.9197
# Epoch 180: Batch 179/233 loss: 0.9416
# Epoch 180: Batch 180/233 loss: 0.9485
# Epoch 180: Batch 181/233 loss: 0.9071
# Epoch 180: Batch 182/233 loss: 0.9095
# Epoch 180: Batch 183/233 loss: 0.8409
# Epoch 180: Batch 184/233 loss: 0.8207
# Epoch 180: Batch 185/233 loss: 0.8068
# Epoch 180: Batch 186/233 loss: 0.8398
# Epoch 180: Batch 187/233 loss: 0.9350
# Epoch 180: Batch 188/233 loss: 0.8478
# Epoch 180: Batch 189/233 loss: 0.8852
# Epoch 180: Batch 190/233 loss: 0.9063
# Epoch 180: Batch 191/233 loss: 0.8525
# Epoch 180: Batch 192/233 loss: 0.8840
# Epoch 180: Batch 193/233 loss: 0.8987
# Epoch 180: Batch 194/233 loss: 0.8258
# Epoch 180: Batch 195/233 loss: 0.8913
# Epoch 180: Batch 196/233 loss: 0.8923
# Epoch 180: Batch 197/233 loss: 0.8166
# Epoch 180: Batch 198/233 loss: 0.9101
# Epoch 180: Batch 199/233 loss: 0.8926
# Epoch 180: Batch 200/233 loss: 0.8899
# Epoch 180: Batch 201/233 loss: 0.9415
# Epoch 180: Batch 202/233 loss: 0.9067
# Epoch 180: Batch 203/233 loss: 0.8583
# Epoch 180: Batch 204/233 loss: 0.8838
# Epoch 180: Batch 205/233 loss: 0.8727
# Epoch 180: Batch 206/233 loss: 0.8535
# Epoch 180: Batch 207/233 loss: 0.9334
# Epoch 180: Batch 208/233 loss: 0.8640
# Epoch 180: Batch 209/233 loss: 0.8668
# Epoch 180: Batch 210/233 loss: 0.8917
# Epoch 180: Batch 211/233 loss: 0.8473
# Epoch 180: Batch 212/233 loss: 0.8659
# Epoch 180: Batch 213/233 loss: 0.8718
# Epoch 180: Batch 214/233 loss: 0.8448
# Epoch 180: Batch 215/233 loss: 0.8936
# Epoch 180: Batch 216/233 loss: 0.8804
# Epoch 180: Batch 217/233 loss: 0.8716
# Epoch 180: Batch 218/233 loss: 0.8544
# Epoch 180: Batch 219/233 loss: 0.8987
# Epoch 180: Batch 220/233 loss: 0.8916
# Epoch 180: Batch 221/233 loss: 0.9002
# Epoch 180: Batch 222/233 loss: 0.9185
# Epoch 180: Batch 223/233 loss: 0.7828
# Epoch 180: Batch 224/233 loss: 0.9009
# Epoch 180: Batch 225/233 loss: 0.8817
# Epoch 180: Batch 226/233 loss: 0.9767
# Epoch 180: Batch 227/233 loss: 0.9240
# Epoch 180: Batch 228/233 loss: 0.8856
# Epoch 180: Batch 229/233 loss: 0.8788
# Epoch 180: Batch 230/233 loss: 0.9044
# Epoch 180: Batch 231/233 loss: 0.8685
# Epoch 180: Batch 232/233 loss: 0.8212
# Epoch 180: Batch 233/233 loss: 0.8988
# Epoch 180 train loss: 0.8862 valid loss: 0.8717
# performance reducing: 22
