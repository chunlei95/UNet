# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import random

import numpy as np
import torch
import torchvision.transforms
import torchvision.transforms.functional as Func


class ToPILImage(object):
    def __call__(self, image, target=None):
        image = Func.to_pil_image(image)
        if target is not None:
            target = Func.to_pil_image(target)
        return image, target


class RandomCrop(object):
    def __init__(self, size):
        self.size = size

    def __call__(self, image, target=None):
        seed = np.random.randint(65536)
        torch.manual_seed(seed)
        crop = torchvision.transforms.RandomCrop(self.size)
        image = crop(image)
        if target is not None:
            target = crop(target)
        return image, target


class Resize(object):
    def __init__(self, size):
        super(Resize, self).__init__()
        self.size = size

    def __call__(self, image, target=None):
        image = Func.resize(image, self.size)
        if target is not None:
            target = Func.resize(target, self.size, interpolation=Func.InterpolationMode.NEAREST)
        return image, target


class RandomHorizontalFlip(object):
    def __init__(self, flip_prob=0.5):
        self.flip_prob = flip_prob

    def __call__(self, image, target=None):
        if random.random() < self.flip_prob:
            image = Func.hflip(image)
            if target is not None:
                target = Func.hflip(target)
        return image, target


class ColorJitter(object):
    def __call__(self, image, target):
        color_jitter = torchvision.transforms.ColorJitter()
        image = color_jitter(image)
        return image, target


class GrayScale(object):
    def __call__(self, image, target):
        gray_scale = torchvision.transforms.Grayscale()
        image = gray_scale(image)
        return image, target


class RandomRotation(object):
    def __init__(self, degrees):
        super(RandomRotation, self).__init__()
        self.degrees = degrees

    def __call__(self, image, target=None):
        degree = random.randint(self.degrees[0], self.degrees[1])
        image = Func.rotate(image, degree)
        if target is not None:
            target = Func.rotate(target, degree)
        return image, target


class Normalize(object):
    def __init__(self, mean, std):
        super(Normalize, self).__init__()
        self.mean = mean
        self.std = std

    def __call__(self, image, target):
        image = Func.normalize(image, mean=self.mean, std=self.std)
        return image, target


class ToTensor(object):
    def __call__(self, image, target=None):
        image = Func.to_tensor(image)
        if target is not None:
            target = torch.as_tensor(np.array(target), dtype=torch.int64)
        return image, target


class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target

# %%
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Dataset

class CustomDataset(Dataset):
    def __init__(self, data_path, target_path, transforms=None):
        super(CustomDataset, self).__init__()
        self.data_paths = data_path
        self.target_paths = target_path
        self.transforms = transforms

    def __getitem__(self, item):

        image = plt.imread(self.data_paths[item])
        target = plt.imread(self.target_paths[item])

        image = np.expand_dims(image, axis=-1)

        # image = torch.from_numpy(image)
        # target = torch.from_numpy(target)

        if self.transforms is not None:
            image, target = self.transforms(image, target)
        return image, target

    def __len__(self):
        return len(self.data_paths)


def load_data(data_path, target_path, batch_size, drop_last=False, transforms=None):
    datas = CustomDataset(data_path=data_path, target_path=target_path, transforms=transforms)
    data_loader = DataLoader(datas, shuffle=True, batch_size=batch_size, drop_last=drop_last)
    return data_loader

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.transforms.functional as functional


class UNet(nn.Module):
    """U-Net模型的pytorch实现。
    论文地址：https://arxiv.org/abs/1505.04597
    模型的总体结构: 编码器 -> 一个ConvBlock -> 解码器 -> 一个Conv 1 * 1
    """

    def __init__(self):
        super(UNet, self).__init__()
        # 编码器部分
        self.eb1 = EncoderBlock(1, 64, kernel_size=2)
        self.eb2 = EncoderBlock(64, 128, kernel_size=2)
        self.eb3 = EncoderBlock(128, 256, kernel_size=2)
        self.eb4 = EncoderBlock(256, 512, kernel_size=2)
        # 编码器与解码器之间有一个ConvBlock
        self.cb = ConvBlock(512, 1024)
        # 解码器部分
        self.db1 = DecoderBlock(1024, 512)
        self.db2 = DecoderBlock(512, 256)
        self.db3 = DecoderBlock(256, 128)
        self.db4 = DecoderBlock(128, 64)
        # 一个Conv 1 * 1, 二分类，结果为两个通道
        self.conv1x1 = nn.Conv2d(64, 2, kernel_size=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        ex1, skip_x1 = self.eb1(x)
        ex2, skip_x2 = self.eb2(ex1)
        ex3, skip_x3 = self.eb3(ex2)
        ex4, skip_x4 = self.eb4(ex3)
        cbx = self.cb(ex4)
        dx1 = self.db1(cbx, skip_x4)
        dx2 = self.db2(dx1, skip_x3)
        dx3 = self.db3(dx2, skip_x2)
        dx4 = self.db4(dx3, skip_x1)
        crop = transforms.CenterCrop(size=(x.shape[-1], x.shape[-2]))
        # normalize = transforms.Normalize((0.5,), (0.5,))
        return self.sigmoid(self.conv1x1(crop(dx4)))


class BottleBlock(nn.Module):
    def __init__(self, channels):
        super(BottleBlock, self).__init__()

        self.layer = nn.Sequential(
            nn.Conv2d(in_channels=channels, out_channels=channels // 2, kernel_size=1),
            nn.BatchNorm2d(channels // 2),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=channels // 2, out_channels=channels // 2, kernel_size=3, padding=1),
            nn.BatchNorm2d(channels // 2),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=channels // 2, out_channels=channels, kernel_size=1)
        )
        self.bn = nn.BatchNorm2d(channels)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        out = self.layer(x)
        return self.relu(self.bn(torch.add(out, x)))


class ConvBlock(nn.Module):
    """一个Conv2d卷积后跟一个Relu激活函数，卷积核大小为3 * 3

    :param in_channels: 层次块的输入通道数
    :param out_channels: 层次块输出层的通道数
    """

    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()
        self.change_channel = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        self.bk1 = BottleBlock(out_channels)
        self.bk2 = BottleBlock(out_channels)

    def forward(self, x):
        x = self.change_channel(x)
        x = self.bk1(x)
        x = self.bk2(x)
        return x


class DownSampling(nn.Module):
    """下采样，使用max pool方法执行，核大小为 2 * 2，用在编码器的ConvBlock后面

    :param kernel_size: 下采样层（即最大池化层）的核大小
    """

    def __init__(self, kernel_size):
        super(DownSampling, self).__init__()
        self.down_sample = nn.MaxPool2d(kernel_size=kernel_size)

    def forward(self, x):
        return self.down_sample(x)


class UpSampling(nn.Module):
    """上采样，用在解码器的ConvBlock前面，使用转置卷积，同时通道数减半，

    C_out = out_channels
    H_out = (H_in - 1) * stride - 2 * padding + dilation * (kernel_size - 1) + output_padding + 1
    W_out = (W_in - 1) * stride - 2 * padding + dilation * (kernel_size - 1) + output_padding + 1

    :param in_channels: 转置卷积的输入通道数
    :param out_channels: 转置卷积的输出通道数
    :param kernel_size: 转置卷积的卷积核大小，默认为2
    :param stride: 转置卷积的步幅，默认为2
    """

    def __init__(self, in_channels, out_channels, kernel_size=7, stride=2, dilation=1, padding=0, output_padding=1):
        super(UpSampling, self).__init__()
        # self.up_sample = nn.Upsample(scale_factor=scale_factor, mode='bilinear')
        # stride=2, kernel_size=2相当于宽高翻倍
        self.up_sample = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride,
                                            dilation=dilation, padding=padding, output_padding=output_padding)

    def forward(self, x):
        return self.up_sample(x)


class EncoderBlock(nn.Module):
    """编码器中的一个层次块

    :param in_channels: 层次块的输入通道数
    :param out_channels: 层次块输出层的通道数
    :param kernel_size: 下采样层（即最大池化层）的核大小
    """

    def __init__(self, in_channels, out_channels, kernel_size):
        super(EncoderBlock, self).__init__()
        self.conv_block = ConvBlock(in_channels, out_channels)
        self.down_sample = DownSampling(kernel_size)

    def forward(self, x):
        x1 = self.conv_block(x)
        return self.down_sample(x1), x1


class ConcatLayer(nn.Module):
    """跳跃连接，在通道维上连接

    """

    def __init__(self):
        super(ConcatLayer, self).__init__()

    def forward(self, x, skip_x):
        # 将从编码器传过来的特征图裁剪到与输入相同尺寸
        x1 = functional.center_crop(skip_x, [x.shape[-2], x.shape[-1]])
        # crop = transforms.RandomCrop(x.shape)
        # x1 = crop(skip_x).unsqueeze(dim=0)
        # x1 = x.unsqueeze(dim=0)
        # F.grid_sample()
        # x2 = x.unsqueeze(dim=0)
        if x1.shape != x.shape:
            raise Exception('要连接的两个特征图尺寸不一致，skip_x.shape={}，x.shape={}'.format(skip_x.shape, x.shape))
        # 通道维连接
        return torch.cat([x, x1], dim=1)


class DecoderBlock(nn.Module):
    """解码器中的层次块，每个层次块都是UpSampling -> Concat -> ConvBlock

    :param in_channels: 层次块的输入通道数
    :param out_channels: 层次块输出层的通道数
    """

    def __init__(self, in_channels, out_channels):
        super(DecoderBlock, self).__init__()
        self.up_sample = UpSampling(in_channels, out_channels)
        self.conv_block = ConvBlock(in_channels, out_channels)

    def forward(self, x, skip_x):
        x1 = self.up_sample(x)
        concat = ConcatLayer()
        x2 = concat(x1, skip_x)
        return self.conv_block(x2)

# %%
from argparse import ArgumentParser
from glob import glob

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


# noinspection PyShadowingNames,SpellCheckingInspection
def train(train_loader, valid_loader, model, criterion, optimizer, total_epoch, current_epoch=0, num_classes=2,
          device='cpu'):
    model.to(device)
    criterion.to(device)
    loss_change_list = []
    valid_loss_change_list = []
    saved_last = {}
    saved_best = {}
    loss_change = {}

    search_best = SearchBest()

    for i in range(current_epoch, total_epoch):
        model.train()
        total_loss = 0.0
        for index, (x, y) in enumerate(train_loader):
            x = x.to(device)
            y = y.to(device)
            y_onehot = convert_to_one_hot(y, num_classes=num_classes)
            predict = model(x)

            loss_value = criterion(predict, y_onehot)
            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()

            total_loss += loss_value.item()
            print('Epoch {}: Batch {}/{} loss: {:.4f}'.format(i + 1, index + 1, len(train_loader), loss_value.item()))

        loss_change_list.append(total_loss / len(train_loader))
        valid_avg_loss = valid(model, criterion, valid_loader, num_classes, device)
        valid_loss_change_list.append(valid_avg_loss)
        print('Epoch {} train loss: {:.4f} valid loss: {:.4f}'.format(i + 1, total_loss / len(train_loader),
                                                                      valid_avg_loss))
        search_best(valid_avg_loss)
        if search_best.counter == 0:
            # save the relevant params of the best model state in the current time.
            saved_best['best_model_state_dict'] = model.state_dict()
            saved_best['best_optimizer_state_dict'] = optimizer.state_dict()
            saved_best['epoch'] = i + 1
    loss_change['train_loss_change_history'] = loss_change_list
    loss_change['valid_loss_change_history'] = valid_loss_change_list
    saved_last['last_model_state_dict'] = model.state_dict()
    saved_last['last_optimizer_state_dict'] = optimizer.state_dict()
    saved_last['epoch'] = total_epoch
    torch.save(saved_best, './best_model.pth')
    torch.save(saved_last, './last_model.pth')
    torch.save(loss_change, './loss_change.pth')


def convert_to_one_hot(data, num_classes):
    if type(data) is not torch.Tensor:
        raise RuntimeError('data must be a torch.Tensor')
    if data.dtype is not torch.int64:
        data = data.to(torch.int64)
    data = F.one_hot(data, num_classes=num_classes).permute((0, -1, 1, 2))
    return data.to(torch.float32)


class SearchBest(object):
    def __init__(self, min_delta=0, verbose=True):
        super(SearchBest, self).__init__()
        self.counter = 0
        self.min_delta = min_delta
        self.best_score = None
        self.verbose = verbose

    def __call__(self, valid_loss):
        if self.best_score is None:
            self.best_score = valid_loss
        elif self.best_score - valid_loss >= self.min_delta:
            self.best_score = valid_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print('performance reducing: {}'.format(self.counter))


# noinspection PyShadowingNames
def valid(model, criterion, valid_loader, num_classes, device):
    """
    :return: validate loss
    """
    model.eval()
    valid_total_loss = 0.0
    for index, (x, y) in enumerate(valid_loader):
        x = x.to(device)
        y = y.to(device)
        y_onehot = convert_to_one_hot(y, num_classes)
        with torch.no_grad():
            predict = model(x)
            valid_loss = criterion(predict, y_onehot)
            valid_total_loss += valid_loss.item()
    return valid_total_loss / len(valid_loader)

# %%
if __name__ == '__main__':
    lr = 1e-3
    
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = UNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.5, 0.999))
    
    # 后面修改为Dice损失函数看看效果
    criterion = nn.BCELoss()

    train_image_path = glob('../input/covidxray/covid19-xray/train/images/*')
    train_mask_path = glob('../input/covidxray/covid19-xray/train/masks/*')
    
    val_image_path = glob('../input/covidxray/covid19-xray/val/images/*')
    val_mask_path = glob('../input/covidxray/covid19-xray/val/masks/*')

    train_transforms = Compose([
        # todo 先Resize试一下
        ToPILImage(),
        RandomHorizontalFlip(),
        RandomRotation(degrees=(0, 180)),
#         ColorJitter(), # 这个有问题，但是是什么问题？
#         GrayScale(), # 这个貌似也有问题，问题更大
        RandomCrop(256),
        ToTensor(),
        Normalize((0.5,), (0.5,))
    ])
    valid_transforms = Compose([
        ToPILImage(),
        Resize(256),
        ToTensor(),
        Normalize((0.5,), (0.5,))
    ])
    
    train_loader = load_data(train_image_path, train_mask_path, batch_size=8, drop_last=True,
                             transforms=train_transforms)
    valid_loader = load_data(val_image_path, val_mask_path, batch_size=8, transforms=valid_transforms)
    
    continue_train = False
    torch.cuda.empty_cache()
    if not continue_train:
        epoch = 100
        train(train_loader, valid_loader, model, criterion, optimizer, epoch, device=device)
    else:
        total_epoch = 200
        pretrain_params = torch.load('../input/covid-xray-unet/last_model.pth')
        model.load_state_dict(pretrain_params['last_model_state_dict'])
        optimizer.load_state_dict(pretrain_params['last_optimizer_state_dict'])
        current_epoch = pretrain_params['epoch']
        model.train()
        train(train_loader, valid_loader, model, criterion, optimizer, total_epoch, current_epoch, device=device)
# Out:
# Epoch 1: Batch 1/466 loss: 0.8009
# Epoch 1: Batch 2/466 loss: 0.7220
# Epoch 1: Batch 3/466 loss: 0.6329
# Epoch 1: Batch 4/466 loss: 0.5628
# Epoch 1: Batch 5/466 loss: 0.5124
# Epoch 1: Batch 6/466 loss: 0.4527
# Epoch 1: Batch 7/466 loss: 0.4400
# Epoch 1: Batch 8/466 loss: 0.4309
# Epoch 1: Batch 9/466 loss: 0.3927
# Epoch 1: Batch 10/466 loss: 0.4497
# Epoch 1: Batch 11/466 loss: 0.3834
# Epoch 1: Batch 12/466 loss: 0.4208
# Epoch 1: Batch 13/466 loss: 0.3649
# Epoch 1: Batch 14/466 loss: 0.3193
# Epoch 1: Batch 15/466 loss: 0.3452
# Epoch 1: Batch 16/466 loss: 0.3138
# Epoch 1: Batch 17/466 loss: 0.3822
# Epoch 1: Batch 18/466 loss: 0.3228
# Epoch 1: Batch 19/466 loss: 0.2901
# Epoch 1: Batch 20/466 loss: 0.3520
# Epoch 1: Batch 21/466 loss: 0.3336
# Epoch 1: Batch 22/466 loss: 0.3565
# Epoch 1: Batch 23/466 loss: 0.3533
# Epoch 1: Batch 24/466 loss: 0.3171
# Epoch 1: Batch 25/466 loss: 0.3430
# Epoch 1: Batch 26/466 loss: 0.3134
# Epoch 1: Batch 27/466 loss: 0.2916
# Epoch 1: Batch 28/466 loss: 0.3546
# Epoch 1: Batch 29/466 loss: 0.2644
# Epoch 1: Batch 30/466 loss: 0.2579
# Epoch 1: Batch 31/466 loss: 0.2583
# Epoch 1: Batch 32/466 loss: 0.2663
# Epoch 1: Batch 33/466 loss: 0.3013
# Epoch 1: Batch 34/466 loss: 0.2424
# Epoch 1: Batch 35/466 loss: 0.3479
# Epoch 1: Batch 36/466 loss: 0.2884
# Epoch 1: Batch 37/466 loss: 0.3064
# Epoch 1: Batch 38/466 loss: 0.2337
# Epoch 1: Batch 39/466 loss: 0.3498
# Epoch 1: Batch 40/466 loss: 0.2116
# Epoch 1: Batch 41/466 loss: 0.3033
# Epoch 1: Batch 42/466 loss: 0.3021
# Epoch 1: Batch 43/466 loss: 0.3120
# Epoch 1: Batch 44/466 loss: 0.3017
# Epoch 1: Batch 45/466 loss: 0.2407
# Epoch 1: Batch 46/466 loss: 0.1566
# Epoch 1: Batch 47/466 loss: 0.3238
# Epoch 1: Batch 48/466 loss: 0.1636
# Epoch 1: Batch 49/466 loss: 0.1843
# Epoch 1: Batch 50/466 loss: 0.2837
# Epoch 1: Batch 51/466 loss: 0.1374
# Epoch 1: Batch 52/466 loss: 0.3168
# Epoch 1: Batch 53/466 loss: 0.1876
# Epoch 1: Batch 54/466 loss: 0.1866
# Epoch 1: Batch 55/466 loss: 0.2121
# Epoch 1: Batch 56/466 loss: 0.2733
# Epoch 1: Batch 57/466 loss: 0.3265
# Epoch 1: Batch 58/466 loss: 0.2798
# Epoch 1: Batch 59/466 loss: 0.1861
# Epoch 1: Batch 60/466 loss: 0.2159
# Epoch 1: Batch 61/466 loss: 0.2451
# Epoch 1: Batch 62/466 loss: 0.2293
# Epoch 1: Batch 63/466 loss: 0.2612
# Epoch 1: Batch 64/466 loss: 0.2137
# Epoch 1: Batch 65/466 loss: 0.2980
# Epoch 1: Batch 66/466 loss: 0.1240
# Epoch 1: Batch 67/466 loss: 0.2269
# Epoch 1: Batch 68/466 loss: 0.1867
# Epoch 1: Batch 69/466 loss: 0.1872
# Epoch 1: Batch 70/466 loss: 0.1576
# Epoch 1: Batch 71/466 loss: 0.2281
# Epoch 1: Batch 72/466 loss: 0.2865
# Epoch 1: Batch 73/466 loss: 0.2804
# Epoch 1: Batch 74/466 loss: 0.2305
# Epoch 1: Batch 75/466 loss: 0.2649
# Epoch 1: Batch 76/466 loss: 0.2945
# Epoch 1: Batch 77/466 loss: 0.2999
# Epoch 1: Batch 78/466 loss: 0.2129
# Epoch 1: Batch 79/466 loss: 0.1739
# Epoch 1: Batch 80/466 loss: 0.1914
# Epoch 1: Batch 81/466 loss: 0.3518
# Epoch 1: Batch 82/466 loss: 0.2978
# Epoch 1: Batch 83/466 loss: 0.3165
# Epoch 1: Batch 84/466 loss: 0.2923
# Epoch 1: Batch 85/466 loss: 0.2388
# Epoch 1: Batch 86/466 loss: 0.2154
# Epoch 1: Batch 87/466 loss: 0.2233
# Epoch 1: Batch 88/466 loss: 0.1709
# Epoch 1: Batch 89/466 loss: 0.2709
# Epoch 1: Batch 90/466 loss: 0.2530
# Epoch 1: Batch 91/466 loss: 0.1705
# Epoch 1: Batch 92/466 loss: 0.2154
# Epoch 1: Batch 93/466 loss: 0.2463
# Epoch 1: Batch 94/466 loss: 0.3392
# Epoch 1: Batch 95/466 loss: 0.3209
# Epoch 1: Batch 96/466 loss: 0.2095
# Epoch 1: Batch 97/466 loss: 0.2491
# Epoch 1: Batch 98/466 loss: 0.2476
# Epoch 1: Batch 99/466 loss: 0.2626
# Epoch 1: Batch 100/466 loss: 0.3491
# Epoch 1: Batch 101/466 loss: 0.2958
# Epoch 1: Batch 102/466 loss: 0.2662
# Epoch 1: Batch 103/466 loss: 0.3643
# Epoch 1: Batch 104/466 loss: 0.2202
# Epoch 1: Batch 105/466 loss: 0.3007
# Epoch 1: Batch 106/466 loss: 0.2164
# Epoch 1: Batch 107/466 loss: 0.1223
# Epoch 1: Batch 108/466 loss: 0.1660
# Epoch 1: Batch 109/466 loss: 0.1203
# Epoch 1: Batch 110/466 loss: 0.2567
# Epoch 1: Batch 111/466 loss: 0.2137
# Epoch 1: Batch 112/466 loss: 0.2236
# Epoch 1: Batch 113/466 loss: 0.1507
# Epoch 1: Batch 114/466 loss: 0.2554
# Epoch 1: Batch 115/466 loss: 0.2384
# Epoch 1: Batch 116/466 loss: 0.2548
# Epoch 1: Batch 117/466 loss: 0.2075
# Epoch 1: Batch 118/466 loss: 0.2546
# Epoch 1: Batch 119/466 loss: 0.1680
# Epoch 1: Batch 120/466 loss: 0.2290
# Epoch 1: Batch 121/466 loss: 0.2323
# Epoch 1: Batch 122/466 loss: 0.2328
# Epoch 1: Batch 123/466 loss: 0.3418
# Epoch 1: Batch 124/466 loss: 0.2621
# Epoch 1: Batch 125/466 loss: 0.2536
# Epoch 1: Batch 126/466 loss: 0.1803
# Epoch 1: Batch 127/466 loss: 0.2101
# Epoch 1: Batch 128/466 loss: 0.3064
# Epoch 1: Batch 129/466 loss: 0.1365
# Epoch 1: Batch 130/466 loss: 0.1465
# Epoch 1: Batch 131/466 loss: 0.2962
# Epoch 1: Batch 132/466 loss: 0.2251
# Epoch 1: Batch 133/466 loss: 0.1632
# Epoch 1: Batch 134/466 loss: 0.2418
# Epoch 1: Batch 135/466 loss: 0.2280
# Epoch 1: Batch 136/466 loss: 0.1951
# Epoch 1: Batch 137/466 loss: 0.1511
# Epoch 1: Batch 138/466 loss: 0.3378
# Epoch 1: Batch 139/466 loss: 0.2960
# Epoch 1: Batch 140/466 loss: 0.1425
# Epoch 1: Batch 141/466 loss: 0.2013
# Epoch 1: Batch 142/466 loss: 0.1263
# Epoch 1: Batch 143/466 loss: 0.2765
# Epoch 1: Batch 144/466 loss: 0.2059
# Epoch 1: Batch 145/466 loss: 0.3076
# Epoch 1: Batch 146/466 loss: 0.1559
# Epoch 1: Batch 147/466 loss: 0.0991
# Epoch 1: Batch 148/466 loss: 0.3111
# Epoch 1: Batch 149/466 loss: 0.2097
# Epoch 1: Batch 150/466 loss: 0.2230
# Epoch 1: Batch 151/466 loss: 0.1890
# Epoch 1: Batch 152/466 loss: 0.1919
# Epoch 1: Batch 153/466 loss: 0.1604
# Epoch 1: Batch 154/466 loss: 0.2057
# Epoch 1: Batch 155/466 loss: 0.1161
# Epoch 1: Batch 156/466 loss: 0.1409
# Epoch 1: Batch 157/466 loss: 0.4549
# Epoch 1: Batch 158/466 loss: 0.1764
# Epoch 1: Batch 159/466 loss: 0.1460
# Epoch 1: Batch 160/466 loss: 0.1367
# Epoch 1: Batch 161/466 loss: 0.2827
# Epoch 1: Batch 162/466 loss: 0.1153
# Epoch 1: Batch 163/466 loss: 0.1916
# Epoch 1: Batch 164/466 loss: 0.1554
# Epoch 1: Batch 165/466 loss: 0.3344
# Epoch 1: Batch 166/466 loss: 0.1890
# Epoch 1: Batch 167/466 loss: 0.1231
# Epoch 1: Batch 168/466 loss: 0.2824
# Epoch 1: Batch 169/466 loss: 0.1781
# Epoch 1: Batch 170/466 loss: 0.2807
# Epoch 1: Batch 171/466 loss: 0.4006
# Epoch 1: Batch 172/466 loss: 0.2269
# Epoch 1: Batch 173/466 loss: 0.2039
# Epoch 1: Batch 174/466 loss: 0.1106
# Epoch 1: Batch 175/466 loss: 0.0929
# Epoch 1: Batch 176/466 loss: 0.1871
# Epoch 1: Batch 177/466 loss: 0.1156
# Epoch 1: Batch 178/466 loss: 0.2302
# Epoch 1: Batch 179/466 loss: 0.2543
# Epoch 1: Batch 180/466 loss: 0.1011
# Epoch 1: Batch 181/466 loss: 0.1913
# Epoch 1: Batch 182/466 loss: 0.1251
# Epoch 1: Batch 183/466 loss: 0.3140
# Epoch 1: Batch 184/466 loss: 0.1907
# Epoch 1: Batch 185/466 loss: 0.1843
# Epoch 1: Batch 186/466 loss: 0.1764
# Epoch 1: Batch 187/466 loss: 0.1986
# Epoch 1: Batch 188/466 loss: 0.2035
# Epoch 1: Batch 189/466 loss: 0.1391
# Epoch 1: Batch 190/466 loss: 0.1290
# Epoch 1: Batch 191/466 loss: 0.1281
# Epoch 1: Batch 192/466 loss: 0.1079
# Epoch 1: Batch 193/466 loss: 0.3589
# Epoch 1: Batch 194/466 loss: 0.1332
# Epoch 1: Batch 195/466 loss: 0.1711
# Epoch 1: Batch 196/466 loss: 0.1993
# Epoch 1: Batch 197/466 loss: 0.1412
# Epoch 1: Batch 198/466 loss: 0.3539
# Epoch 1: Batch 199/466 loss: 0.1581
# Epoch 1: Batch 200/466 loss: 0.1518
# Epoch 1: Batch 201/466 loss: 0.0842
# Epoch 1: Batch 202/466 loss: 0.2639
# Epoch 1: Batch 203/466 loss: 0.1075
# Epoch 1: Batch 204/466 loss: 0.2712
# Epoch 1: Batch 205/466 loss: 0.2467
# Epoch 1: Batch 206/466 loss: 0.2740
# Epoch 1: Batch 207/466 loss: 0.3772
# Epoch 1: Batch 208/466 loss: 0.2058
# Epoch 1: Batch 209/466 loss: 0.1850
# Epoch 1: Batch 210/466 loss: 0.1161
# Epoch 1: Batch 211/466 loss: 0.0952
# Epoch 1: Batch 212/466 loss: 0.2761
# Epoch 1: Batch 213/466 loss: 0.1195
# Epoch 1: Batch 214/466 loss: 0.1486
# Epoch 1: Batch 215/466 loss: 0.2301
# Epoch 1: Batch 216/466 loss: 0.1586
# Epoch 1: Batch 217/466 loss: 0.2342
# Epoch 1: Batch 218/466 loss: 0.2151
# Epoch 1: Batch 219/466 loss: 0.0865
# Epoch 1: Batch 220/466 loss: 0.5298
# Epoch 1: Batch 221/466 loss: 0.3534
# Epoch 1: Batch 222/466 loss: 0.1780
# Epoch 1: Batch 223/466 loss: 0.1605
# Epoch 1: Batch 224/466 loss: 0.1001
# Epoch 1: Batch 225/466 loss: 0.2759
# Epoch 1: Batch 226/466 loss: 0.1607
# Epoch 1: Batch 227/466 loss: 0.1272
# Epoch 1: Batch 228/466 loss: 0.1890
# Epoch 1: Batch 229/466 loss: 0.2229
# Epoch 1: Batch 230/466 loss: 0.1908
# Epoch 1: Batch 231/466 loss: 0.2639
# Epoch 1: Batch 232/466 loss: 0.1149
# Epoch 1: Batch 233/466 loss: 0.0862
# Epoch 1: Batch 234/466 loss: 0.1368
# Epoch 1: Batch 235/466 loss: 0.1205
# Epoch 1: Batch 236/466 loss: 0.2520
# Epoch 1: Batch 237/466 loss: 0.2000
# Epoch 1: Batch 238/466 loss: 0.1405
# Epoch 1: Batch 239/466 loss: 0.3250
# Epoch 1: Batch 240/466 loss: 0.3278
# Epoch 1: Batch 241/466 loss: 0.2247
# Epoch 1: Batch 242/466 loss: 0.1786
# Epoch 1: Batch 243/466 loss: 0.1438
# Epoch 1: Batch 244/466 loss: 0.1394
# Epoch 1: Batch 245/466 loss: 0.3668
# Epoch 1: Batch 246/466 loss: 0.1301
# Epoch 1: Batch 247/466 loss: 0.0828
# Epoch 1: Batch 248/466 loss: 0.1675
# Epoch 1: Batch 249/466 loss: 0.2789
# Epoch 1: Batch 250/466 loss: 0.2332
# Epoch 1: Batch 251/466 loss: 0.1997
# Epoch 1: Batch 252/466 loss: 0.2271
# Epoch 1: Batch 253/466 loss: 0.0918
# Epoch 1: Batch 254/466 loss: 0.2175
# Epoch 1: Batch 255/466 loss: 0.1670
# Epoch 1: Batch 256/466 loss: 0.2167
# Epoch 1: Batch 257/466 loss: 0.1548
# Epoch 1: Batch 258/466 loss: 0.1983
# Epoch 1: Batch 259/466 loss: 0.3555
# Epoch 1: Batch 260/466 loss: 0.2203
# Epoch 1: Batch 261/466 loss: 0.3627
# Epoch 1: Batch 262/466 loss: 0.2850
# Epoch 1: Batch 263/466 loss: 0.2318
# Epoch 1: Batch 264/466 loss: 0.2642
# Epoch 1: Batch 265/466 loss: 0.2157
# Epoch 1: Batch 266/466 loss: 0.2198
# Epoch 1: Batch 267/466 loss: 0.2611
# Epoch 1: Batch 268/466 loss: 0.2036
# Epoch 1: Batch 269/466 loss: 0.1528
# Epoch 1: Batch 270/466 loss: 0.2257
# Epoch 1: Batch 271/466 loss: 0.1854
# Epoch 1: Batch 272/466 loss: 0.1787
# Epoch 1: Batch 273/466 loss: 0.2131
# Epoch 1: Batch 274/466 loss: 0.2629
# Epoch 1: Batch 275/466 loss: 0.1687
# Epoch 1: Batch 276/466 loss: 0.1645
# Epoch 1: Batch 277/466 loss: 0.1588
# Epoch 1: Batch 278/466 loss: 0.1862
# Epoch 1: Batch 279/466 loss: 0.2292
# Epoch 1: Batch 280/466 loss: 0.3466
# Epoch 1: Batch 281/466 loss: 0.1722
# Epoch 1: Batch 282/466 loss: 0.1751
# Epoch 1: Batch 283/466 loss: 0.1427
# Epoch 1: Batch 284/466 loss: 0.1322
# Epoch 1: Batch 285/466 loss: 0.2841
# Epoch 1: Batch 286/466 loss: 0.1799
# Epoch 1: Batch 287/466 loss: 0.0815
# Epoch 1: Batch 288/466 loss: 0.1977
# Epoch 1: Batch 289/466 loss: 0.1382
# Epoch 1: Batch 290/466 loss: 0.1241
# Epoch 1: Batch 291/466 loss: 0.2467
# Epoch 1: Batch 292/466 loss: 0.1135
# Epoch 1: Batch 293/466 loss: 0.1874
# Epoch 1: Batch 294/466 loss: 0.2854
# Epoch 1: Batch 295/466 loss: 0.1288
# Epoch 1: Batch 296/466 loss: 0.1650
# Epoch 1: Batch 297/466 loss: 0.1398
# Epoch 1: Batch 298/466 loss: 0.3580
# Epoch 1: Batch 299/466 loss: 0.1676
# Epoch 1: Batch 300/466 loss: 0.2053
# Epoch 1: Batch 301/466 loss: 0.1662
# Epoch 1: Batch 302/466 loss: 0.1309
# Epoch 1: Batch 303/466 loss: 0.0867
# Epoch 1: Batch 304/466 loss: 0.1574
# Epoch 1: Batch 305/466 loss: 0.3165
# Epoch 1: Batch 306/466 loss: 0.1649
# Epoch 1: Batch 307/466 loss: 0.4328
# Epoch 1: Batch 308/466 loss: 0.1709
# Epoch 1: Batch 309/466 loss: 0.2033
# Epoch 1: Batch 310/466 loss: 0.1865
# Epoch 1: Batch 311/466 loss: 0.1965
# Epoch 1: Batch 312/466 loss: 0.2554
# Epoch 1: Batch 313/466 loss: 0.1316
# Epoch 1: Batch 314/466 loss: 0.2486
# Epoch 1: Batch 315/466 loss: 0.1633
# Epoch 1: Batch 316/466 loss: 0.2651
# Epoch 1: Batch 317/466 loss: 0.3367
# Epoch 1: Batch 318/466 loss: 0.2019
# Epoch 1: Batch 319/466 loss: 0.1631
# Epoch 1: Batch 320/466 loss: 0.1986
# Epoch 1: Batch 321/466 loss: 0.1680
# Epoch 1: Batch 322/466 loss: 0.1332
# Epoch 1: Batch 323/466 loss: 0.1976
# Epoch 1: Batch 324/466 loss: 0.1275
# Epoch 1: Batch 325/466 loss: 0.2388
# Epoch 1: Batch 326/466 loss: 0.2227
# Epoch 1: Batch 327/466 loss: 0.2071
# Epoch 1: Batch 328/466 loss: 0.2248
# Epoch 1: Batch 329/466 loss: 0.1966
# Epoch 1: Batch 330/466 loss: 0.2854
# Epoch 1: Batch 331/466 loss: 0.3168
# Epoch 1: Batch 332/466 loss: 0.1542
# Epoch 1: Batch 333/466 loss: 0.3106
# Epoch 1: Batch 334/466 loss: 0.2172
# Epoch 1: Batch 335/466 loss: 0.1640
# Epoch 1: Batch 336/466 loss: 0.1723
# Epoch 1: Batch 337/466 loss: 0.1645
# Epoch 1: Batch 338/466 loss: 0.2224
# Epoch 1: Batch 339/466 loss: 0.2600
# Epoch 1: Batch 340/466 loss: 0.2200
# Epoch 1: Batch 341/466 loss: 0.1930
# Epoch 1: Batch 342/466 loss: 0.2058
# Epoch 1: Batch 343/466 loss: 0.3811
# Epoch 1: Batch 344/466 loss: 0.0969
# Epoch 1: Batch 345/466 loss: 0.0719
# Epoch 1: Batch 346/466 loss: 0.2376
# Epoch 1: Batch 347/466 loss: 0.2144
# Epoch 1: Batch 348/466 loss: 0.1425
# Epoch 1: Batch 349/466 loss: 0.2010
# Epoch 1: Batch 350/466 loss: 0.2731
# Epoch 1: Batch 351/466 loss: 0.3181
# Epoch 1: Batch 352/466 loss: 0.1498
# Epoch 1: Batch 353/466 loss: 0.2669
# Epoch 1: Batch 354/466 loss: 0.1123
# Epoch 1: Batch 355/466 loss: 0.2582
# Epoch 1: Batch 356/466 loss: 0.0954
# Epoch 1: Batch 357/466 loss: 0.1512
# Epoch 1: Batch 358/466 loss: 0.1175
# Epoch 1: Batch 359/466 loss: 0.2384
# Epoch 1: Batch 360/466 loss: 0.2013
# Epoch 1: Batch 361/466 loss: 0.1864
# Epoch 1: Batch 362/466 loss: 0.1147
# Epoch 1: Batch 363/466 loss: 0.1721
# Epoch 1: Batch 364/466 loss: 0.1907
# Epoch 1: Batch 365/466 loss: 0.2423
# Epoch 1: Batch 366/466 loss: 0.2178
# Epoch 1: Batch 367/466 loss: 0.2620
# Epoch 1: Batch 368/466 loss: 0.0986
# Epoch 1: Batch 369/466 loss: 0.1532
# Epoch 1: Batch 370/466 loss: 0.2340
# Epoch 1: Batch 371/466 loss: 0.1662
# Epoch 1: Batch 372/466 loss: 0.1649
# Epoch 1: Batch 373/466 loss: 0.1582
# Epoch 1: Batch 374/466 loss: 0.1758
# Epoch 1: Batch 375/466 loss: 0.3280
# Epoch 1: Batch 376/466 loss: 0.1446
# Epoch 1: Batch 377/466 loss: 0.2057
# Epoch 1: Batch 378/466 loss: 0.1544
# Epoch 1: Batch 379/466 loss: 0.1422
# Epoch 1: Batch 380/466 loss: 0.1739
# Epoch 1: Batch 381/466 loss: 0.1704
# Epoch 1: Batch 382/466 loss: 0.2555
# Epoch 1: Batch 383/466 loss: 0.1748
# Epoch 1: Batch 384/466 loss: 0.1988
# Epoch 1: Batch 385/466 loss: 0.1300
# Epoch 1: Batch 386/466 loss: 0.1633
# Epoch 1: Batch 387/466 loss: 0.2763
# Epoch 1: Batch 388/466 loss: 0.2321
# Epoch 1: Batch 389/466 loss: 0.2363
# Epoch 1: Batch 390/466 loss: 0.2040
# Epoch 1: Batch 391/466 loss: 0.1503
# Epoch 1: Batch 392/466 loss: 0.1742
# Epoch 1: Batch 393/466 loss: 0.1876
# Epoch 1: Batch 394/466 loss: 0.1850
# Epoch 1: Batch 395/466 loss: 0.1370
# Epoch 1: Batch 396/466 loss: 0.2303
# Epoch 1: Batch 397/466 loss: 0.4135
# Epoch 1: Batch 398/466 loss: 0.2482
# Epoch 1: Batch 399/466 loss: 0.1682
# Epoch 1: Batch 400/466 loss: 0.2528
# Epoch 1: Batch 401/466 loss: 0.3442
# Epoch 1: Batch 402/466 loss: 0.3946
# Epoch 1: Batch 403/466 loss: 0.2253
# Epoch 1: Batch 404/466 loss: 0.1428
# Epoch 1: Batch 405/466 loss: 0.1729
# Epoch 1: Batch 406/466 loss: 0.1234
# Epoch 1: Batch 407/466 loss: 0.3113
# Epoch 1: Batch 408/466 loss: 0.1382
# Epoch 1: Batch 409/466 loss: 0.2080
# Epoch 1: Batch 410/466 loss: 0.2274
# Epoch 1: Batch 411/466 loss: 0.1937
# Epoch 1: Batch 412/466 loss: 0.2060
# Epoch 1: Batch 413/466 loss: 0.1101
# Epoch 1: Batch 414/466 loss: 0.1067
# Epoch 1: Batch 415/466 loss: 0.1964
# Epoch 1: Batch 416/466 loss: 0.3313
# Epoch 1: Batch 417/466 loss: 0.3369
# Epoch 1: Batch 418/466 loss: 0.3162
# Epoch 1: Batch 419/466 loss: 0.3337
# Epoch 1: Batch 420/466 loss: 0.1215
# Epoch 1: Batch 421/466 loss: 0.2825
# Epoch 1: Batch 422/466 loss: 0.1418
# Epoch 1: Batch 423/466 loss: 0.3263
# Epoch 1: Batch 424/466 loss: 0.1611
# Epoch 1: Batch 425/466 loss: 0.2830
# Epoch 1: Batch 426/466 loss: 0.2061
# Epoch 1: Batch 427/466 loss: 0.1769
# Epoch 1: Batch 428/466 loss: 0.2627
# Epoch 1: Batch 429/466 loss: 0.2410
# Epoch 1: Batch 430/466 loss: 0.2502
# Epoch 1: Batch 431/466 loss: 0.1405
# Epoch 1: Batch 432/466 loss: 0.1970
# Epoch 1: Batch 433/466 loss: 0.0740
# Epoch 1: Batch 434/466 loss: 0.2000
# Epoch 1: Batch 435/466 loss: 0.1630
# Epoch 1: Batch 436/466 loss: 0.3532
# Epoch 1: Batch 437/466 loss: 0.1638
# Epoch 1: Batch 438/466 loss: 0.1826
# Epoch 1: Batch 439/466 loss: 0.2369
# Epoch 1: Batch 440/466 loss: 0.1427
# Epoch 1: Batch 441/466 loss: 0.2771
# Epoch 1: Batch 442/466 loss: 0.3073
# Epoch 1: Batch 443/466 loss: 0.2040
# Epoch 1: Batch 444/466 loss: 0.2052
# Epoch 1: Batch 445/466 loss: 0.1191
# Epoch 1: Batch 446/466 loss: 0.2915
# Epoch 1: Batch 447/466 loss: 0.1937
# Epoch 1: Batch 448/466 loss: 0.2328
# Epoch 1: Batch 449/466 loss: 0.1593
# Epoch 1: Batch 450/466 loss: 0.1668
# Epoch 1: Batch 451/466 loss: 0.3119
# Epoch 1: Batch 452/466 loss: 0.2662
# Epoch 1: Batch 453/466 loss: 0.1140
# Epoch 1: Batch 454/466 loss: 0.4355
# Epoch 1: Batch 455/466 loss: 0.1761
# Epoch 1: Batch 456/466 loss: 0.2296
# Epoch 1: Batch 457/466 loss: 0.2061
# Epoch 1: Batch 458/466 loss: 0.1686
# Epoch 1: Batch 459/466 loss: 0.2224
# Epoch 1: Batch 460/466 loss: 0.2896
# Epoch 1: Batch 461/466 loss: 0.1199
# Epoch 1: Batch 462/466 loss: 0.2892
# Epoch 1: Batch 463/466 loss: 0.1862
# Epoch 1: Batch 464/466 loss: 0.1532
# Epoch 1: Batch 465/466 loss: 0.1634
# Epoch 1: Batch 466/466 loss: 0.1314
# Epoch 1 train loss: 0.2261 valid loss: 0.2009
# Epoch 2: Batch 1/466 loss: 0.1615
# Epoch 2: Batch 2/466 loss: 0.3724
# Epoch 2: Batch 3/466 loss: 0.1071
# Epoch 2: Batch 4/466 loss: 0.2746
# Epoch 2: Batch 5/466 loss: 0.2050
# Epoch 2: Batch 6/466 loss: 0.2125
# Epoch 2: Batch 7/466 loss: 0.2407
# Epoch 2: Batch 8/466 loss: 0.2103
# Epoch 2: Batch 9/466 loss: 0.1275
# Epoch 2: Batch 10/466 loss: 0.0894
# Epoch 2: Batch 11/466 loss: 0.2633
# Epoch 2: Batch 12/466 loss: 0.2055
# Epoch 2: Batch 13/466 loss: 0.1164
# Epoch 2: Batch 14/466 loss: 0.1967
# Epoch 2: Batch 15/466 loss: 0.4926
# Epoch 2: Batch 16/466 loss: 0.1919
# Epoch 2: Batch 17/466 loss: 0.1358
# Epoch 2: Batch 18/466 loss: 0.2387
# Epoch 2: Batch 19/466 loss: 0.1337
# Epoch 2: Batch 20/466 loss: 0.3313
# Epoch 2: Batch 21/466 loss: 0.3341
# Epoch 2: Batch 22/466 loss: 0.1386
# Epoch 2: Batch 23/466 loss: 0.1411
# Epoch 2: Batch 24/466 loss: 0.3973
# Epoch 2: Batch 25/466 loss: 0.1018
# Epoch 2: Batch 26/466 loss: 0.3390
# Epoch 2: Batch 27/466 loss: 0.2265
# Epoch 2: Batch 28/466 loss: 0.1597
# Epoch 2: Batch 29/466 loss: 0.1708
# Epoch 2: Batch 30/466 loss: 0.2399
# Epoch 2: Batch 31/466 loss: 0.3523
# Epoch 2: Batch 32/466 loss: 0.1794
# Epoch 2: Batch 33/466 loss: 0.1720
# Epoch 2: Batch 34/466 loss: 0.2135
# Epoch 2: Batch 35/466 loss: 0.2404
# Epoch 2: Batch 36/466 loss: 0.2305
# Epoch 2: Batch 37/466 loss: 0.1808
# Epoch 2: Batch 38/466 loss: 0.2429
# Epoch 2: Batch 39/466 loss: 0.1752
# Epoch 2: Batch 40/466 loss: 0.1442
# Epoch 2: Batch 41/466 loss: 0.2330
# Epoch 2: Batch 42/466 loss: 0.1408
# Epoch 2: Batch 43/466 loss: 0.2921
# Epoch 2: Batch 44/466 loss: 0.1641
# Epoch 2: Batch 45/466 loss: 0.2641
# Epoch 2: Batch 46/466 loss: 0.1645
# Epoch 2: Batch 47/466 loss: 0.2629
# Epoch 2: Batch 48/466 loss: 0.2157
# Epoch 2: Batch 49/466 loss: 0.2191
# Epoch 2: Batch 50/466 loss: 0.2266
# Epoch 2: Batch 51/466 loss: 0.1570
# Epoch 2: Batch 52/466 loss: 0.3987
# Epoch 2: Batch 53/466 loss: 0.1397
# Epoch 2: Batch 54/466 loss: 0.1913
# Epoch 2: Batch 55/466 loss: 0.1322
# Epoch 2: Batch 56/466 loss: 0.1991
# Epoch 2: Batch 57/466 loss: 0.0802
# Epoch 2: Batch 58/466 loss: 0.2217
# Epoch 2: Batch 59/466 loss: 0.1420
# Epoch 2: Batch 60/466 loss: 0.1522
# Epoch 2: Batch 61/466 loss: 0.2948
# Epoch 2: Batch 62/466 loss: 0.2051
# Epoch 2: Batch 63/466 loss: 0.1649
# Epoch 2: Batch 64/466 loss: 0.2047
# Epoch 2: Batch 65/466 loss: 0.1894
# Epoch 2: Batch 66/466 loss: 0.3897
# Epoch 2: Batch 67/466 loss: 0.1399
# Epoch 2: Batch 68/466 loss: 0.2232
# Epoch 2: Batch 69/466 loss: 0.1411
# Epoch 2: Batch 70/466 loss: 0.2654
# Epoch 2: Batch 71/466 loss: 0.0958
# Epoch 2: Batch 72/466 loss: 0.1657
# Epoch 2: Batch 73/466 loss: 0.1835
# Epoch 2: Batch 74/466 loss: 0.1214
# Epoch 2: Batch 75/466 loss: 0.1440
# Epoch 2: Batch 76/466 loss: 0.1499
# Epoch 2: Batch 77/466 loss: 0.3467
# Epoch 2: Batch 78/466 loss: 0.2089
# Epoch 2: Batch 79/466 loss: 0.2175
# Epoch 2: Batch 80/466 loss: 0.2553
# Epoch 2: Batch 81/466 loss: 0.1738
# Epoch 2: Batch 82/466 loss: 0.2365
# Epoch 2: Batch 83/466 loss: 0.1237
# Epoch 2: Batch 84/466 loss: 0.2152
# Epoch 2: Batch 85/466 loss: 0.3544
# Epoch 2: Batch 86/466 loss: 0.2928
# Epoch 2: Batch 87/466 loss: 0.1782
# Epoch 2: Batch 88/466 loss: 0.2200
# Epoch 2: Batch 89/466 loss: 0.2203
# Epoch 2: Batch 90/466 loss: 0.1877
# Epoch 2: Batch 91/466 loss: 0.1146
# Epoch 2: Batch 92/466 loss: 0.1358
# Epoch 2: Batch 93/466 loss: 0.3153
# Epoch 2: Batch 94/466 loss: 0.4157
# Epoch 2: Batch 95/466 loss: 0.1381
# Epoch 2: Batch 96/466 loss: 0.1320
# Epoch 2: Batch 97/466 loss: 0.2293
# Epoch 2: Batch 98/466 loss: 0.1418
# Epoch 2: Batch 99/466 loss: 0.2156
# Epoch 2: Batch 100/466 loss: 0.2702
# Epoch 2: Batch 101/466 loss: 0.1518
# Epoch 2: Batch 102/466 loss: 0.2210
# Epoch 2: Batch 103/466 loss: 0.1789
# Epoch 2: Batch 104/466 loss: 0.1209
# Epoch 2: Batch 105/466 loss: 0.2496
# Epoch 2: Batch 106/466 loss: 0.0850
# Epoch 2: Batch 107/466 loss: 0.2136
# Epoch 2: Batch 108/466 loss: 0.1125
# Epoch 2: Batch 109/466 loss: 0.2533
# Epoch 2: Batch 110/466 loss: 0.0914
# Epoch 2: Batch 111/466 loss: 0.2956
# Epoch 2: Batch 112/466 loss: 0.1908
# Epoch 2: Batch 113/466 loss: 0.2468
# Epoch 2: Batch 114/466 loss: 0.1918
# Epoch 2: Batch 115/466 loss: 0.1637
# Epoch 2: Batch 116/466 loss: 0.1326
# Epoch 2: Batch 117/466 loss: 0.1077
# Epoch 2: Batch 118/466 loss: 0.3059
# Epoch 2: Batch 119/466 loss: 0.2028
# Epoch 2: Batch 120/466 loss: 0.2286
# Epoch 2: Batch 121/466 loss: 0.1564
# Epoch 2: Batch 122/466 loss: 0.2406
# Epoch 2: Batch 123/466 loss: 0.2302
# Epoch 2: Batch 124/466 loss: 0.2050
# Epoch 2: Batch 125/466 loss: 0.1527
# Epoch 2: Batch 126/466 loss: 0.1513
# Epoch 2: Batch 127/466 loss: 0.1571
# Epoch 2: Batch 128/466 loss: 0.2008
# Epoch 2: Batch 129/466 loss: 0.2085
# Epoch 2: Batch 130/466 loss: 0.1518
# Epoch 2: Batch 131/466 loss: 0.1605
# Epoch 2: Batch 132/466 loss: 0.1836
# Epoch 2: Batch 133/466 loss: 0.1636
# Epoch 2: Batch 134/466 loss: 0.1390
# Epoch 2: Batch 135/466 loss: 0.1495
# Epoch 2: Batch 136/466 loss: 0.2146
# Epoch 2: Batch 137/466 loss: 0.1571
# Epoch 2: Batch 138/466 loss: 0.1780
# Epoch 2: Batch 139/466 loss: 0.1610
# Epoch 2: Batch 140/466 loss: 0.2777
# Epoch 2: Batch 141/466 loss: 0.1447
# Epoch 2: Batch 142/466 loss: 0.2093
# Epoch 2: Batch 143/466 loss: 0.1979
# Epoch 2: Batch 144/466 loss: 0.5017
# Epoch 2: Batch 145/466 loss: 0.2336
# Epoch 2: Batch 146/466 loss: 0.2527
# Epoch 2: Batch 147/466 loss: 0.2444
# Epoch 2: Batch 148/466 loss: 0.1225
# Epoch 2: Batch 149/466 loss: 0.2087
# Epoch 2: Batch 150/466 loss: 0.2344
# Epoch 2: Batch 151/466 loss: 0.3213
# Epoch 2: Batch 152/466 loss: 0.2455
# Epoch 2: Batch 153/466 loss: 0.1325
# Epoch 2: Batch 154/466 loss: 0.1612
# Epoch 2: Batch 155/466 loss: 0.1679
# Epoch 2: Batch 156/466 loss: 0.2781
# Epoch 2: Batch 157/466 loss: 0.1823
# Epoch 2: Batch 158/466 loss: 0.1306
# Epoch 2: Batch 159/466 loss: 0.2193
# Epoch 2: Batch 160/466 loss: 0.1481
# Epoch 2: Batch 161/466 loss: 0.1034
# Epoch 2: Batch 162/466 loss: 0.2258
# Epoch 2: Batch 163/466 loss: 0.2642
# Epoch 2: Batch 164/466 loss: 0.1325
# Epoch 2: Batch 165/466 loss: 0.1051
# Epoch 2: Batch 166/466 loss: 0.1152
# Epoch 2: Batch 167/466 loss: 0.1060
# Epoch 2: Batch 168/466 loss: 0.1911
# Epoch 2: Batch 169/466 loss: 0.2211
# Epoch 2: Batch 170/466 loss: 0.3650
# Epoch 2: Batch 171/466 loss: 0.1028
# Epoch 2: Batch 172/466 loss: 0.1824
# Epoch 2: Batch 173/466 loss: 0.1368
# Epoch 2: Batch 174/466 loss: 0.1154
# Epoch 2: Batch 175/466 loss: 0.3144
# Epoch 2: Batch 176/466 loss: 0.2182
# Epoch 2: Batch 177/466 loss: 0.2313
# Epoch 2: Batch 178/466 loss: 0.1897
# Epoch 2: Batch 179/466 loss: 0.1681
# Epoch 2: Batch 180/466 loss: 0.1829
# Epoch 2: Batch 181/466 loss: 0.1714
# Epoch 2: Batch 182/466 loss: 0.2239
# Epoch 2: Batch 183/466 loss: 0.0952
# Epoch 2: Batch 184/466 loss: 0.1345
# Epoch 2: Batch 185/466 loss: 0.1193
# Epoch 2: Batch 186/466 loss: 0.2748
# Epoch 2: Batch 187/466 loss: 0.1675
# Epoch 2: Batch 188/466 loss: 0.1898
# Epoch 2: Batch 189/466 loss: 0.3446
# Epoch 2: Batch 190/466 loss: 0.2198
# Epoch 2: Batch 191/466 loss: 0.1670
# Epoch 2: Batch 192/466 loss: 0.1906
# Epoch 2: Batch 193/466 loss: 0.1633
# Epoch 2: Batch 194/466 loss: 0.1907
# Epoch 2: Batch 195/466 loss: 0.2064
# Epoch 2: Batch 196/466 loss: 0.2200
# Epoch 2: Batch 197/466 loss: 0.2642
# Epoch 2: Batch 198/466 loss: 0.2242
# Epoch 2: Batch 199/466 loss: 0.1730
# Epoch 2: Batch 200/466 loss: 0.1493
# Epoch 2: Batch 201/466 loss: 0.1660
# Epoch 2: Batch 202/466 loss: 0.1210
# Epoch 2: Batch 203/466 loss: 0.2315
# Epoch 2: Batch 204/466 loss: 0.1653
# Epoch 2: Batch 205/466 loss: 0.0970
# Epoch 2: Batch 206/466 loss: 0.1924
# Epoch 2: Batch 207/466 loss: 0.2085
# Epoch 2: Batch 208/466 loss: 0.1924
# Epoch 2: Batch 209/466 loss: 0.2079
# Epoch 2: Batch 210/466 loss: 0.1571
# Epoch 2: Batch 211/466 loss: 0.1722
# Epoch 2: Batch 212/466 loss: 0.2745
# Epoch 2: Batch 213/466 loss: 0.1511
# Epoch 2: Batch 214/466 loss: 0.1486
# Epoch 2: Batch 215/466 loss: 0.2134
# Epoch 2: Batch 216/466 loss: 0.1982
# Epoch 2: Batch 217/466 loss: 0.1556
# Epoch 2: Batch 218/466 loss: 0.1398
# Epoch 2: Batch 219/466 loss: 0.2176
# Epoch 2: Batch 220/466 loss: 0.1705
# Epoch 2: Batch 221/466 loss: 0.1198
# Epoch 2: Batch 222/466 loss: 0.1871
# Epoch 2: Batch 223/466 loss: 0.0839
# Epoch 2: Batch 224/466 loss: 0.1712
# Epoch 2: Batch 225/466 loss: 0.1374
# Epoch 2: Batch 226/466 loss: 0.1217
# Epoch 2: Batch 227/466 loss: 0.1785
# Epoch 2: Batch 228/466 loss: 0.1317
# Epoch 2: Batch 229/466 loss: 0.2080
# Epoch 2: Batch 230/466 loss: 0.1508
# Epoch 2: Batch 231/466 loss: 0.2346
# Epoch 2: Batch 232/466 loss: 0.1540
# Epoch 2: Batch 233/466 loss: 0.0780
# Epoch 2: Batch 234/466 loss: 0.1726
# Epoch 2: Batch 235/466 loss: 0.1953
# Epoch 2: Batch 236/466 loss: 0.2451
# Epoch 2: Batch 237/466 loss: 0.1461
# Epoch 2: Batch 238/466 loss: 0.1372
# Epoch 2: Batch 239/466 loss: 0.1158
# Epoch 2: Batch 240/466 loss: 0.1503
# Epoch 2: Batch 241/466 loss: 0.1291
# Epoch 2: Batch 242/466 loss: 0.2285
# Epoch 2: Batch 243/466 loss: 0.2527
# Epoch 2: Batch 244/466 loss: 0.3078
# Epoch 2: Batch 245/466 loss: 0.1680
# Epoch 2: Batch 246/466 loss: 0.1860
# Epoch 2: Batch 247/466 loss: 0.1270
# Epoch 2: Batch 248/466 loss: 0.1747
# Epoch 2: Batch 249/466 loss: 0.1023
# Epoch 2: Batch 250/466 loss: 0.2989
# Epoch 2: Batch 251/466 loss: 0.2954
# Epoch 2: Batch 252/466 loss: 0.1393
# Epoch 2: Batch 253/466 loss: 0.2002
# Epoch 2: Batch 254/466 loss: 0.1431
# Epoch 2: Batch 255/466 loss: 0.2180
# Epoch 2: Batch 256/466 loss: 0.2647
# Epoch 2: Batch 257/466 loss: 0.1351
# Epoch 2: Batch 258/466 loss: 0.1512
# Epoch 2: Batch 259/466 loss: 0.2789
# Epoch 2: Batch 260/466 loss: 0.2092
# Epoch 2: Batch 261/466 loss: 0.2110
# Epoch 2: Batch 262/466 loss: 0.1296
# Epoch 2: Batch 263/466 loss: 0.1136
# Epoch 2: Batch 264/466 loss: 0.2689
# Epoch 2: Batch 265/466 loss: 0.2076
# Epoch 2: Batch 266/466 loss: 0.1833
# Epoch 2: Batch 267/466 loss: 0.1508
# Epoch 2: Batch 268/466 loss: 0.2283
# Epoch 2: Batch 269/466 loss: 0.1218
# Epoch 2: Batch 270/466 loss: 0.0985
# Epoch 2: Batch 271/466 loss: 0.1400
# Epoch 2: Batch 272/466 loss: 0.1186
# Epoch 2: Batch 273/466 loss: 0.2747
# Epoch 2: Batch 274/466 loss: 0.2278
# Epoch 2: Batch 275/466 loss: 0.1845
# Epoch 2: Batch 276/466 loss: 0.0882
# Epoch 2: Batch 277/466 loss: 0.0950
# Epoch 2: Batch 278/466 loss: 0.1670
# Epoch 2: Batch 279/466 loss: 0.1629
# Epoch 2: Batch 280/466 loss: 0.1716
# Epoch 2: Batch 281/466 loss: 0.2556
# Epoch 2: Batch 282/466 loss: 0.2170
# Epoch 2: Batch 283/466 loss: 0.1759
# Epoch 2: Batch 284/466 loss: 0.1839
# Epoch 2: Batch 285/466 loss: 0.1476
# Epoch 2: Batch 286/466 loss: 0.1643
# Epoch 2: Batch 287/466 loss: 0.2528
# Epoch 2: Batch 288/466 loss: 0.1378
# Epoch 2: Batch 289/466 loss: 0.2992
# Epoch 2: Batch 290/466 loss: 0.1460
# Epoch 2: Batch 291/466 loss: 0.1347
# Epoch 2: Batch 292/466 loss: 0.1065
# Epoch 2: Batch 293/466 loss: 0.1387
# Epoch 2: Batch 294/466 loss: 0.1007
# Epoch 2: Batch 295/466 loss: 0.2042
# Epoch 2: Batch 296/466 loss: 0.3744
# Epoch 2: Batch 297/466 loss: 0.1277
# Epoch 2: Batch 298/466 loss: 0.3017
# Epoch 2: Batch 299/466 loss: 0.4177
# Epoch 2: Batch 300/466 loss: 0.3399
# Epoch 2: Batch 301/466 loss: 0.1944
# Epoch 2: Batch 302/466 loss: 0.1916
# Epoch 2: Batch 303/466 loss: 0.2666
# Epoch 2: Batch 304/466 loss: 0.2809
# Epoch 2: Batch 305/466 loss: 0.2172
# Epoch 2: Batch 306/466 loss: 0.2082
# Epoch 2: Batch 307/466 loss: 0.1824
# Epoch 2: Batch 308/466 loss: 0.1898
# Epoch 2: Batch 309/466 loss: 0.2061
# Epoch 2: Batch 310/466 loss: 0.2297
# Epoch 2: Batch 311/466 loss: 0.1869
# Epoch 2: Batch 312/466 loss: 0.2020
# Epoch 2: Batch 313/466 loss: 0.1280
# Epoch 2: Batch 314/466 loss: 0.2155
# Epoch 2: Batch 315/466 loss: 0.1294
# Epoch 2: Batch 316/466 loss: 0.1156
# Epoch 2: Batch 317/466 loss: 0.0966
# Epoch 2: Batch 318/466 loss: 0.1753
# Epoch 2: Batch 319/466 loss: 0.1371
# Epoch 2: Batch 320/466 loss: 0.1153
# Epoch 2: Batch 321/466 loss: 0.1988
# Epoch 2: Batch 322/466 loss: 0.1248
# Epoch 2: Batch 323/466 loss: 0.1200
# Epoch 2: Batch 324/466 loss: 0.1746
# Epoch 2: Batch 325/466 loss: 0.2634
# Epoch 2: Batch 326/466 loss: 0.2582
# Epoch 2: Batch 327/466 loss: 0.1729
# Epoch 2: Batch 328/466 loss: 0.1022
# Epoch 2: Batch 329/466 loss: 0.1772
# Epoch 2: Batch 330/466 loss: 0.0796
# Epoch 2: Batch 331/466 loss: 0.1593
# Epoch 2: Batch 332/466 loss: 0.1219
# Epoch 2: Batch 333/466 loss: 0.1127
# Epoch 2: Batch 334/466 loss: 0.1624
# Epoch 2: Batch 335/466 loss: 0.1823
# Epoch 2: Batch 336/466 loss: 0.3486
# Epoch 2: Batch 337/466 loss: 0.2318
# Epoch 2: Batch 338/466 loss: 0.1913
# Epoch 2: Batch 339/466 loss: 0.1232
# Epoch 2: Batch 340/466 loss: 0.1545
# Epoch 2: Batch 341/466 loss: 0.1499
# Epoch 2: Batch 342/466 loss: 0.2149
# Epoch 2: Batch 343/466 loss: 0.2070
# Epoch 2: Batch 344/466 loss: 0.1542
# Epoch 2: Batch 345/466 loss: 0.1091
# Epoch 2: Batch 346/466 loss: 0.1377
# Epoch 2: Batch 347/466 loss: 0.0919
# Epoch 2: Batch 348/466 loss: 0.1897
# Epoch 2: Batch 349/466 loss: 0.1653
# Epoch 2: Batch 350/466 loss: 0.1012
# Epoch 2: Batch 351/466 loss: 0.1324
# Epoch 2: Batch 352/466 loss: 0.1972
# Epoch 2: Batch 353/466 loss: 0.1677
# Epoch 2: Batch 354/466 loss: 0.2448
# Epoch 2: Batch 355/466 loss: 0.1113
# Epoch 2: Batch 356/466 loss: 0.1723
# Epoch 2: Batch 357/466 loss: 0.2161
# Epoch 2: Batch 358/466 loss: 0.1674
# Epoch 2: Batch 359/466 loss: 0.1990
# Epoch 2: Batch 360/466 loss: 0.2142
# Epoch 2: Batch 361/466 loss: 0.0951
# Epoch 2: Batch 362/466 loss: 0.2316
# Epoch 2: Batch 363/466 loss: 0.1463
# Epoch 2: Batch 364/466 loss: 0.2608
# Epoch 2: Batch 365/466 loss: 0.2545
# Epoch 2: Batch 366/466 loss: 0.1454
# Epoch 2: Batch 367/466 loss: 0.0832
# Epoch 2: Batch 368/466 loss: 0.2235
# Epoch 2: Batch 369/466 loss: 0.2814
# Epoch 2: Batch 370/466 loss: 0.1207
# Epoch 2: Batch 371/466 loss: 0.1747
# Epoch 2: Batch 372/466 loss: 0.1328
# Epoch 2: Batch 373/466 loss: 0.2031
# Epoch 2: Batch 374/466 loss: 0.1846
# Epoch 2: Batch 375/466 loss: 0.2795
# Epoch 2: Batch 376/466 loss: 0.1297
# Epoch 2: Batch 377/466 loss: 0.2045
# Epoch 2: Batch 378/466 loss: 0.3026
# Epoch 2: Batch 379/466 loss: 0.1579
# Epoch 2: Batch 380/466 loss: 0.2269
# Epoch 2: Batch 381/466 loss: 0.3042
# Epoch 2: Batch 382/466 loss: 0.2291
# Epoch 2: Batch 383/466 loss: 0.1562
# Epoch 2: Batch 384/466 loss: 0.1819
# Epoch 2: Batch 385/466 loss: 0.0969
# Epoch 2: Batch 386/466 loss: 0.1138
# Epoch 2: Batch 387/466 loss: 0.2543
# Epoch 2: Batch 388/466 loss: 0.1249
# Epoch 2: Batch 389/466 loss: 0.1059
# Epoch 2: Batch 390/466 loss: 0.1873
# Epoch 2: Batch 391/466 loss: 0.2068
# Epoch 2: Batch 392/466 loss: 0.1346
# Epoch 2: Batch 393/466 loss: 0.1159
# Epoch 2: Batch 394/466 loss: 0.1237
# Epoch 2: Batch 395/466 loss: 0.1559
# Epoch 2: Batch 396/466 loss: 0.0650
# Epoch 2: Batch 397/466 loss: 0.2185
# Epoch 2: Batch 398/466 loss: 0.2017
# Epoch 2: Batch 399/466 loss: 0.0725
# Epoch 2: Batch 400/466 loss: 0.1596
# Epoch 2: Batch 401/466 loss: 0.1266
# Epoch 2: Batch 402/466 loss: 0.2166
# Epoch 2: Batch 403/466 loss: 0.1744
# Epoch 2: Batch 404/466 loss: 0.1371
# Epoch 2: Batch 405/466 loss: 0.2156
# Epoch 2: Batch 406/466 loss: 0.1921
# Epoch 2: Batch 407/466 loss: 0.1141
# Epoch 2: Batch 408/466 loss: 0.2100
# Epoch 2: Batch 409/466 loss: 0.1499
# Epoch 2: Batch 410/466 loss: 0.1616
# Epoch 2: Batch 411/466 loss: 0.2177
# Epoch 2: Batch 412/466 loss: 0.0768
# Epoch 2: Batch 413/466 loss: 0.1043
# Epoch 2: Batch 414/466 loss: 0.1436
# Epoch 2: Batch 415/466 loss: 0.2897
# Epoch 2: Batch 416/466 loss: 0.0875
# Epoch 2: Batch 417/466 loss: 0.1441
# Epoch 2: Batch 418/466 loss: 0.1716
# Epoch 2: Batch 419/466 loss: 0.1575
# Epoch 2: Batch 420/466 loss: 0.1479
# Epoch 2: Batch 421/466 loss: 0.3824
# Epoch 2: Batch 422/466 loss: 0.0868
# Epoch 2: Batch 423/466 loss: 0.1351
# Epoch 2: Batch 424/466 loss: 0.1229
# Epoch 2: Batch 425/466 loss: 0.2131
# Epoch 2: Batch 426/466 loss: 0.2173
# Epoch 2: Batch 427/466 loss: 0.2692
# Epoch 2: Batch 428/466 loss: 0.1642
# Epoch 2: Batch 429/466 loss: 0.2024
# Epoch 2: Batch 430/466 loss: 0.1784
# Epoch 2: Batch 431/466 loss: 0.2571
# Epoch 2: Batch 432/466 loss: 0.3087
# Epoch 2: Batch 433/466 loss: 0.1511
# Epoch 2: Batch 434/466 loss: 0.1367
# Epoch 2: Batch 435/466 loss: 0.1264
# Epoch 2: Batch 436/466 loss: 0.2612
# Epoch 2: Batch 437/466 loss: 0.2029
# Epoch 2: Batch 438/466 loss: 0.1882
# Epoch 2: Batch 439/466 loss: 0.1423
# Epoch 2: Batch 440/466 loss: 0.1376
# Epoch 2: Batch 441/466 loss: 0.2051
# Epoch 2: Batch 442/466 loss: 0.1511
# Epoch 2: Batch 443/466 loss: 0.1527
# Epoch 2: Batch 444/466 loss: 0.1999
# Epoch 2: Batch 445/466 loss: 0.1644
# Epoch 2: Batch 446/466 loss: 0.1236
# Epoch 2: Batch 447/466 loss: 0.1073
# Epoch 2: Batch 448/466 loss: 0.1943
# Epoch 2: Batch 449/466 loss: 0.0964
# Epoch 2: Batch 450/466 loss: 0.1246
# Epoch 2: Batch 451/466 loss: 0.1972
# Epoch 2: Batch 452/466 loss: 0.0995
# Epoch 2: Batch 453/466 loss: 0.2134
# Epoch 2: Batch 454/466 loss: 0.0989
# Epoch 2: Batch 455/466 loss: 0.2825
# Epoch 2: Batch 456/466 loss: 0.1214
# Epoch 2: Batch 457/466 loss: 0.1242
# Epoch 2: Batch 458/466 loss: 0.1923
# Epoch 2: Batch 459/466 loss: 0.0916
# Epoch 2: Batch 460/466 loss: 0.1048
# Epoch 2: Batch 461/466 loss: 0.1229
# Epoch 2: Batch 462/466 loss: 0.1411
# Epoch 2: Batch 463/466 loss: 0.1541
# Epoch 2: Batch 464/466 loss: 0.1979
# Epoch 2: Batch 465/466 loss: 0.3946
# Epoch 2: Batch 466/466 loss: 0.2736
# Epoch 2 train loss: 0.1881 valid loss: 0.1788
# Epoch 3: Batch 1/466 loss: 0.1378
# Epoch 3: Batch 2/466 loss: 0.1197
# Epoch 3: Batch 3/466 loss: 0.1024
# Epoch 3: Batch 4/466 loss: 0.2363
# Epoch 3: Batch 5/466 loss: 0.1366
# Epoch 3: Batch 6/466 loss: 0.1861
# Epoch 3: Batch 7/466 loss: 0.1897
# Epoch 3: Batch 8/466 loss: 0.1363
# Epoch 3: Batch 9/466 loss: 0.1487
# Epoch 3: Batch 10/466 loss: 0.1525
# Epoch 3: Batch 11/466 loss: 0.1229
# Epoch 3: Batch 12/466 loss: 0.2013
# Epoch 3: Batch 13/466 loss: 0.1414
# Epoch 3: Batch 14/466 loss: 0.1380
# Epoch 3: Batch 15/466 loss: 0.1406
# Epoch 3: Batch 16/466 loss: 0.0811
# Epoch 3: Batch 17/466 loss: 0.1138
# Epoch 3: Batch 18/466 loss: 0.2969
# Epoch 3: Batch 19/466 loss: 0.2168
# Epoch 3: Batch 20/466 loss: 0.2350
# Epoch 3: Batch 21/466 loss: 0.1157
# Epoch 3: Batch 22/466 loss: 0.2181
# Epoch 3: Batch 23/466 loss: 0.2318
# Epoch 3: Batch 24/466 loss: 0.1260
# Epoch 3: Batch 25/466 loss: 0.2849
# Epoch 3: Batch 26/466 loss: 0.2462
# Epoch 3: Batch 27/466 loss: 0.1482
# Epoch 3: Batch 28/466 loss: 0.1144
# Epoch 3: Batch 29/466 loss: 0.3275
# Epoch 3: Batch 30/466 loss: 0.1651
# Epoch 3: Batch 31/466 loss: 0.2233
# Epoch 3: Batch 32/466 loss: 0.1874
# Epoch 3: Batch 33/466 loss: 0.1208
# Epoch 3: Batch 34/466 loss: 0.1270
# Epoch 3: Batch 35/466 loss: 0.2028
# Epoch 3: Batch 36/466 loss: 0.2727
# Epoch 3: Batch 37/466 loss: 0.1277
# Epoch 3: Batch 38/466 loss: 0.1428
# Epoch 3: Batch 39/466 loss: 0.1868
# Epoch 3: Batch 40/466 loss: 0.1027
# Epoch 3: Batch 41/466 loss: 0.0898
# Epoch 3: Batch 42/466 loss: 0.2260
# Epoch 3: Batch 43/466 loss: 0.1885
# Epoch 3: Batch 44/466 loss: 0.1110
# Epoch 3: Batch 45/466 loss: 0.1295
# Epoch 3: Batch 46/466 loss: 0.1619
# Epoch 3: Batch 47/466 loss: 0.1080
# Epoch 3: Batch 48/466 loss: 0.2539
# Epoch 3: Batch 49/466 loss: 0.1623
# Epoch 3: Batch 50/466 loss: 0.2545
# Epoch 3: Batch 51/466 loss: 0.2147
# Epoch 3: Batch 52/466 loss: 0.1907
# Epoch 3: Batch 53/466 loss: 0.1606
# Epoch 3: Batch 54/466 loss: 0.2535
# Epoch 3: Batch 55/466 loss: 0.1839
# Epoch 3: Batch 56/466 loss: 0.1920
# Epoch 3: Batch 57/466 loss: 0.1483
# Epoch 3: Batch 58/466 loss: 0.3284
# Epoch 3: Batch 59/466 loss: 0.1907
# Epoch 3: Batch 60/466 loss: 0.1509
# Epoch 3: Batch 61/466 loss: 0.3033
# Epoch 3: Batch 62/466 loss: 0.1269
# Epoch 3: Batch 63/466 loss: 0.1112
# Epoch 3: Batch 64/466 loss: 0.1250
# Epoch 3: Batch 65/466 loss: 0.1056
# Epoch 3: Batch 66/466 loss: 0.1712
# Epoch 3: Batch 67/466 loss: 0.2172
# Epoch 3: Batch 68/466 loss: 0.3200
# Epoch 3: Batch 69/466 loss: 0.1803
# Epoch 3: Batch 70/466 loss: 0.1344
# Epoch 3: Batch 71/466 loss: 0.2112
# Epoch 3: Batch 72/466 loss: 0.1029
# Epoch 3: Batch 73/466 loss: 0.1044
# Epoch 3: Batch 74/466 loss: 0.1716
# Epoch 3: Batch 75/466 loss: 0.0663
# Epoch 3: Batch 76/466 loss: 0.1064
# Epoch 3: Batch 77/466 loss: 0.1384
# Epoch 3: Batch 78/466 loss: 0.1367
# Epoch 3: Batch 79/466 loss: 0.1906
# Epoch 3: Batch 80/466 loss: 0.0890
# Epoch 3: Batch 81/466 loss: 0.1971
# Epoch 3: Batch 82/466 loss: 0.1284
# Epoch 3: Batch 83/466 loss: 0.1429
# Epoch 3: Batch 84/466 loss: 0.1627
# Epoch 3: Batch 85/466 loss: 0.2922
# Epoch 3: Batch 86/466 loss: 0.2057
# Epoch 3: Batch 87/466 loss: 0.1449
# Epoch 3: Batch 88/466 loss: 0.1338
# Epoch 3: Batch 89/466 loss: 0.1860
# Epoch 3: Batch 90/466 loss: 0.1837
# Epoch 3: Batch 91/466 loss: 0.1722
# Epoch 3: Batch 92/466 loss: 0.2373
# Epoch 3: Batch 93/466 loss: 0.1841
# Epoch 3: Batch 94/466 loss: 0.1339
# Epoch 3: Batch 95/466 loss: 0.2895
# Epoch 3: Batch 96/466 loss: 0.1163
# Epoch 3: Batch 97/466 loss: 0.3244
# Epoch 3: Batch 98/466 loss: 0.2003
# Epoch 3: Batch 99/466 loss: 0.1739
# Epoch 3: Batch 100/466 loss: 0.1178
# Epoch 3: Batch 101/466 loss: 0.2122
# Epoch 3: Batch 102/466 loss: 0.1977
# Epoch 3: Batch 103/466 loss: 0.1264
# Epoch 3: Batch 104/466 loss: 0.1703
# Epoch 3: Batch 105/466 loss: 0.1183
# Epoch 3: Batch 106/466 loss: 0.1363
# Epoch 3: Batch 107/466 loss: 0.1158
# Epoch 3: Batch 108/466 loss: 0.1746
# Epoch 3: Batch 109/466 loss: 0.1374
# Epoch 3: Batch 110/466 loss: 0.1367
# Epoch 3: Batch 111/466 loss: 0.1313
# Epoch 3: Batch 112/466 loss: 0.1904
# Epoch 3: Batch 113/466 loss: 0.1268
# Epoch 3: Batch 114/466 loss: 0.1613
# Epoch 3: Batch 115/466 loss: 0.3118
# Epoch 3: Batch 116/466 loss: 0.1200
# Epoch 3: Batch 117/466 loss: 0.3462
# Epoch 3: Batch 118/466 loss: 0.1621
# Epoch 3: Batch 119/466 loss: 0.1399
# Epoch 3: Batch 120/466 loss: 0.1920
# Epoch 3: Batch 121/466 loss: 0.1240
# Epoch 3: Batch 122/466 loss: 0.2109
# Epoch 3: Batch 123/466 loss: 0.2559
# Epoch 3: Batch 124/466 loss: 0.1799
# Epoch 3: Batch 125/466 loss: 0.2691
# Epoch 3: Batch 126/466 loss: 0.1805
# Epoch 3: Batch 127/466 loss: 0.1556
# Epoch 3: Batch 128/466 loss: 0.1961
# Epoch 3: Batch 129/466 loss: 0.3304
# Epoch 3: Batch 130/466 loss: 0.1962
# Epoch 3: Batch 131/466 loss: 0.1824
# Epoch 3: Batch 132/466 loss: 0.1307
# Epoch 3: Batch 133/466 loss: 0.1377
# Epoch 3: Batch 134/466 loss: 0.1806
# Epoch 3: Batch 135/466 loss: 0.1075
# Epoch 3: Batch 136/466 loss: 0.2659
# Epoch 3: Batch 137/466 loss: 0.2254
# Epoch 3: Batch 138/466 loss: 0.1290
# Epoch 3: Batch 139/466 loss: 0.1956
# Epoch 3: Batch 140/466 loss: 0.2327
# Epoch 3: Batch 141/466 loss: 0.1763
# Epoch 3: Batch 142/466 loss: 0.1093
# Epoch 3: Batch 143/466 loss: 0.2361
# Epoch 3: Batch 144/466 loss: 0.1231
# Epoch 3: Batch 145/466 loss: 0.1735
# Epoch 3: Batch 146/466 loss: 0.3632
# Epoch 3: Batch 147/466 loss: 0.1369
# Epoch 3: Batch 148/466 loss: 0.1578
# Epoch 3: Batch 149/466 loss: 0.1670
# Epoch 3: Batch 150/466 loss: 0.1545
# Epoch 3: Batch 151/466 loss: 0.2233
# Epoch 3: Batch 152/466 loss: 0.1166
# Epoch 3: Batch 153/466 loss: 0.1022
# Epoch 3: Batch 154/466 loss: 0.1303
# Epoch 3: Batch 155/466 loss: 0.1497
# Epoch 3: Batch 156/466 loss: 0.3744
# Epoch 3: Batch 157/466 loss: 0.0978
# Epoch 3: Batch 158/466 loss: 0.1295
# Epoch 3: Batch 159/466 loss: 0.1962
# Epoch 3: Batch 160/466 loss: 0.1707
# Epoch 3: Batch 161/466 loss: 0.2537
# Epoch 3: Batch 162/466 loss: 0.2142
# Epoch 3: Batch 163/466 loss: 0.2522
# Epoch 3: Batch 164/466 loss: 0.1201
# Epoch 3: Batch 165/466 loss: 0.1418
# Epoch 3: Batch 166/466 loss: 0.1940
# Epoch 3: Batch 167/466 loss: 0.1867
# Epoch 3: Batch 168/466 loss: 0.1477
# Epoch 3: Batch 169/466 loss: 0.1226
# Epoch 3: Batch 170/466 loss: 0.2362
# Epoch 3: Batch 171/466 loss: 0.1390
# Epoch 3: Batch 172/466 loss: 0.1233
# Epoch 3: Batch 173/466 loss: 0.1754
# Epoch 3: Batch 174/466 loss: 0.1149
# Epoch 3: Batch 175/466 loss: 0.1687
# Epoch 3: Batch 176/466 loss: 0.2058
# Epoch 3: Batch 177/466 loss: 0.1069
# Epoch 3: Batch 178/466 loss: 0.2001
# Epoch 3: Batch 179/466 loss: 0.1295
# Epoch 3: Batch 180/466 loss: 0.2233
# Epoch 3: Batch 181/466 loss: 0.1865
# Epoch 3: Batch 182/466 loss: 0.1520
# Epoch 3: Batch 183/466 loss: 0.2342
# Epoch 3: Batch 184/466 loss: 0.2907
# Epoch 3: Batch 185/466 loss: 0.2786
# Epoch 3: Batch 186/466 loss: 0.1148
# Epoch 3: Batch 187/466 loss: 0.1172
# Epoch 3: Batch 188/466 loss: 0.1309
# Epoch 3: Batch 189/466 loss: 0.3609
# Epoch 3: Batch 190/466 loss: 0.2015
# Epoch 3: Batch 191/466 loss: 0.1800
# Epoch 3: Batch 192/466 loss: 0.1627
# Epoch 3: Batch 193/466 loss: 0.1283
# Epoch 3: Batch 194/466 loss: 0.2585
# Epoch 3: Batch 195/466 loss: 0.2591
# Epoch 3: Batch 196/466 loss: 0.1577
# Epoch 3: Batch 197/466 loss: 0.1940
# Epoch 3: Batch 198/466 loss: 0.1987
# Epoch 3: Batch 199/466 loss: 0.1583
# Epoch 3: Batch 200/466 loss: 0.2468
# Epoch 3: Batch 201/466 loss: 0.2242
# Epoch 3: Batch 202/466 loss: 0.3105
# Epoch 3: Batch 203/466 loss: 0.2021
# Epoch 3: Batch 204/466 loss: 0.2997
# Epoch 3: Batch 205/466 loss: 0.2199
# Epoch 3: Batch 206/466 loss: 0.1767
# Epoch 3: Batch 207/466 loss: 0.1427
# Epoch 3: Batch 208/466 loss: 0.1552
# Epoch 3: Batch 209/466 loss: 0.1869
# Epoch 3: Batch 210/466 loss: 0.1498
# Epoch 3: Batch 211/466 loss: 0.2000
# Epoch 3: Batch 212/466 loss: 0.1363
# Epoch 3: Batch 213/466 loss: 0.1053
# Epoch 3: Batch 214/466 loss: 0.1544
# Epoch 3: Batch 215/466 loss: 0.1405
# Epoch 3: Batch 216/466 loss: 0.2506
# Epoch 3: Batch 217/466 loss: 0.1117
# Epoch 3: Batch 218/466 loss: 0.1407
# Epoch 3: Batch 219/466 loss: 0.1227
# Epoch 3: Batch 220/466 loss: 0.1128
# Epoch 3: Batch 221/466 loss: 0.1750
# Epoch 3: Batch 222/466 loss: 0.1258
# Epoch 3: Batch 223/466 loss: 0.2526
# Epoch 3: Batch 224/466 loss: 0.2496
# Epoch 3: Batch 225/466 loss: 0.1587
# Epoch 3: Batch 226/466 loss: 0.1974
# Epoch 3: Batch 227/466 loss: 0.3214
# Epoch 3: Batch 228/466 loss: 0.1344
# Epoch 3: Batch 229/466 loss: 0.1599
# Epoch 3: Batch 230/466 loss: 0.2163
# Epoch 3: Batch 231/466 loss: 0.1268
# Epoch 3: Batch 232/466 loss: 0.1401
# Epoch 3: Batch 233/466 loss: 0.1605
# Epoch 3: Batch 234/466 loss: 0.2420
# Epoch 3: Batch 235/466 loss: 0.1918
# Epoch 3: Batch 236/466 loss: 0.1580
# Epoch 3: Batch 237/466 loss: 0.1210
# Epoch 3: Batch 238/466 loss: 0.1542
# Epoch 3: Batch 239/466 loss: 0.1189
# Epoch 3: Batch 240/466 loss: 0.1642
# Epoch 3: Batch 241/466 loss: 0.0998
# Epoch 3: Batch 242/466 loss: 0.0989
# Epoch 3: Batch 243/466 loss: 0.1969
# Epoch 3: Batch 244/466 loss: 0.1206
# Epoch 3: Batch 245/466 loss: 0.1560
# Epoch 3: Batch 246/466 loss: 0.1839
# Epoch 3: Batch 247/466 loss: 0.1954
# Epoch 3: Batch 248/466 loss: 0.0927
# Epoch 3: Batch 249/466 loss: 0.1357
# Epoch 3: Batch 250/466 loss: 0.1304
# Epoch 3: Batch 251/466 loss: 0.2016
# Epoch 3: Batch 252/466 loss: 0.1710
# Epoch 3: Batch 253/466 loss: 0.1860
# Epoch 3: Batch 254/466 loss: 0.0872
# Epoch 3: Batch 255/466 loss: 0.1542
# Epoch 3: Batch 256/466 loss: 0.2766
# Epoch 3: Batch 257/466 loss: 0.1243
# Epoch 3: Batch 258/466 loss: 0.1763
# Epoch 3: Batch 259/466 loss: 0.2239
# Epoch 3: Batch 260/466 loss: 0.1403
# Epoch 3: Batch 261/466 loss: 0.1707
# Epoch 3: Batch 262/466 loss: 0.2411
# Epoch 3: Batch 263/466 loss: 0.2241
# Epoch 3: Batch 264/466 loss: 0.2182
# Epoch 3: Batch 265/466 loss: 0.1186
# Epoch 3: Batch 266/466 loss: 0.1513
# Epoch 3: Batch 267/466 loss: 0.1366
# Epoch 3: Batch 268/466 loss: 0.2811
# Epoch 3: Batch 269/466 loss: 0.1130
# Epoch 3: Batch 270/466 loss: 0.1195
# Epoch 3: Batch 271/466 loss: 0.1522
# Epoch 3: Batch 272/466 loss: 0.1785
# Epoch 3: Batch 273/466 loss: 0.3021
# Epoch 3: Batch 274/466 loss: 0.1929
# Epoch 3: Batch 275/466 loss: 0.1527
# Epoch 3: Batch 276/466 loss: 0.2249
# Epoch 3: Batch 277/466 loss: 0.2318
# Epoch 3: Batch 278/466 loss: 0.1859
# Epoch 3: Batch 279/466 loss: 0.1348
# Epoch 3: Batch 280/466 loss: 0.1769
# Epoch 3: Batch 281/466 loss: 0.1934
# Epoch 3: Batch 282/466 loss: 0.1458
# Epoch 3: Batch 283/466 loss: 0.1247
# Epoch 3: Batch 284/466 loss: 0.0952
# Epoch 3: Batch 285/466 loss: 0.2343
# Epoch 3: Batch 286/466 loss: 0.0818
# Epoch 3: Batch 287/466 loss: 0.1157
# Epoch 3: Batch 288/466 loss: 0.1732
# Epoch 3: Batch 289/466 loss: 0.1507
# Epoch 3: Batch 290/466 loss: 0.1968
# Epoch 3: Batch 291/466 loss: 0.2089
# Epoch 3: Batch 292/466 loss: 0.2187
# Epoch 3: Batch 293/466 loss: 0.1298
# Epoch 3: Batch 294/466 loss: 0.2492
# Epoch 3: Batch 295/466 loss: 0.1638
# Epoch 3: Batch 296/466 loss: 0.2821
# Epoch 3: Batch 297/466 loss: 0.1411
# Epoch 3: Batch 298/466 loss: 0.1285
# Epoch 3: Batch 299/466 loss: 0.1822
# Epoch 3: Batch 300/466 loss: 0.1623
# Epoch 3: Batch 301/466 loss: 0.1946
# Epoch 3: Batch 302/466 loss: 0.0966
# Epoch 3: Batch 303/466 loss: 0.0977
# Epoch 3: Batch 304/466 loss: 0.2393
# Epoch 3: Batch 305/466 loss: 0.3634
# Epoch 3: Batch 306/466 loss: 0.1946
# Epoch 3: Batch 307/466 loss: 0.1840
# Epoch 3: Batch 308/466 loss: 0.2221
# Epoch 3: Batch 309/466 loss: 0.1497
# Epoch 3: Batch 310/466 loss: 0.1644
# Epoch 3: Batch 311/466 loss: 0.2184
# Epoch 3: Batch 312/466 loss: 0.2588
# Epoch 3: Batch 313/466 loss: 0.1834
# Epoch 3: Batch 314/466 loss: 0.1622
# Epoch 3: Batch 315/466 loss: 0.1511
# Epoch 3: Batch 316/466 loss: 0.1910
# Epoch 3: Batch 317/466 loss: 0.1218
# Epoch 3: Batch 318/466 loss: 0.1691
# Epoch 3: Batch 319/466 loss: 0.1299
# Epoch 3: Batch 320/466 loss: 0.1720
# Epoch 3: Batch 321/466 loss: 0.1051
# Epoch 3: Batch 322/466 loss: 0.3012
# Epoch 3: Batch 323/466 loss: 0.1437
# Epoch 3: Batch 324/466 loss: 0.1380
# Epoch 3: Batch 325/466 loss: 0.1122
# Epoch 3: Batch 326/466 loss: 0.1117
# Epoch 3: Batch 327/466 loss: 0.1144
# Epoch 3: Batch 328/466 loss: 0.1736
# Epoch 3: Batch 329/466 loss: 0.1146
# Epoch 3: Batch 330/466 loss: 0.1270
# Epoch 3: Batch 331/466 loss: 0.1079
# Epoch 3: Batch 332/466 loss: 0.1700
# Epoch 3: Batch 333/466 loss: 0.2988
# Epoch 3: Batch 334/466 loss: 0.1761
# Epoch 3: Batch 335/466 loss: 0.1719
# Epoch 3: Batch 336/466 loss: 0.2954
# Epoch 3: Batch 337/466 loss: 0.1212
# Epoch 3: Batch 338/466 loss: 0.2283
# Epoch 3: Batch 339/466 loss: 0.1572
# Epoch 3: Batch 340/466 loss: 0.1142
# Epoch 3: Batch 341/466 loss: 0.1266
# Epoch 3: Batch 342/466 loss: 0.1219
# Epoch 3: Batch 343/466 loss: 0.1027
# Epoch 3: Batch 344/466 loss: 0.1540
# Epoch 3: Batch 345/466 loss: 0.1566
# Epoch 3: Batch 346/466 loss: 0.2580
# Epoch 3: Batch 347/466 loss: 0.1659
# Epoch 3: Batch 348/466 loss: 0.1072
# Epoch 3: Batch 349/466 loss: 0.2427
# Epoch 3: Batch 350/466 loss: 0.0870
# Epoch 3: Batch 351/466 loss: 0.1166
# Epoch 3: Batch 352/466 loss: 0.0969
# Epoch 3: Batch 353/466 loss: 0.1708
# Epoch 3: Batch 354/466 loss: 0.1896
# Epoch 3: Batch 355/466 loss: 0.1343
# Epoch 3: Batch 356/466 loss: 0.0899
# Epoch 3: Batch 357/466 loss: 0.1152
# Epoch 3: Batch 358/466 loss: 0.1576
# Epoch 3: Batch 359/466 loss: 0.1072
# Epoch 3: Batch 360/466 loss: 0.1532
# Epoch 3: Batch 361/466 loss: 0.1156
# Epoch 3: Batch 362/466 loss: 0.1124
# Epoch 3: Batch 363/466 loss: 0.1372
# Epoch 3: Batch 364/466 loss: 0.1150
# Epoch 3: Batch 365/466 loss: 0.1277
# Epoch 3: Batch 366/466 loss: 0.2011
# Epoch 3: Batch 367/466 loss: 0.1378
# Epoch 3: Batch 368/466 loss: 0.1165
# Epoch 3: Batch 369/466 loss: 0.1525
# Epoch 3: Batch 370/466 loss: 0.1531
# Epoch 3: Batch 371/466 loss: 0.1431
# Epoch 3: Batch 372/466 loss: 0.0946
# Epoch 3: Batch 373/466 loss: 0.1031
# Epoch 3: Batch 374/466 loss: 0.2113
# Epoch 3: Batch 375/466 loss: 0.3580
# Epoch 3: Batch 376/466 loss: 0.1090
# Epoch 3: Batch 377/466 loss: 0.1974
# Epoch 3: Batch 378/466 loss: 0.2978
# Epoch 3: Batch 379/466 loss: 0.1349
# Epoch 3: Batch 380/466 loss: 0.1256
# Epoch 3: Batch 381/466 loss: 0.2512
# Epoch 3: Batch 382/466 loss: 0.2079
# Epoch 3: Batch 383/466 loss: 0.1373
# Epoch 3: Batch 384/466 loss: 0.2330
# Epoch 3: Batch 385/466 loss: 0.1443
# Epoch 3: Batch 386/466 loss: 0.1987
# Epoch 3: Batch 387/466 loss: 0.1861
# Epoch 3: Batch 388/466 loss: 0.2279
# Epoch 3: Batch 389/466 loss: 0.1811
# Epoch 3: Batch 390/466 loss: 0.1585
# Epoch 3: Batch 391/466 loss: 0.1916
# Epoch 3: Batch 392/466 loss: 0.1335
# Epoch 3: Batch 393/466 loss: 0.1198
# Epoch 3: Batch 394/466 loss: 0.1312
# Epoch 3: Batch 395/466 loss: 0.1489
# Epoch 3: Batch 396/466 loss: 0.1311
# Epoch 3: Batch 397/466 loss: 0.1103
# Epoch 3: Batch 398/466 loss: 0.1838
# Epoch 3: Batch 399/466 loss: 0.0860
# Epoch 3: Batch 400/466 loss: 0.1467
# Epoch 3: Batch 401/466 loss: 0.1812
# Epoch 3: Batch 402/466 loss: 0.2194
# Epoch 3: Batch 403/466 loss: 0.1515
# Epoch 3: Batch 404/466 loss: 0.2144
# Epoch 3: Batch 405/466 loss: 0.2071
# Epoch 3: Batch 406/466 loss: 0.1214
# Epoch 3: Batch 407/466 loss: 0.1698
# ...
# Epoch 100: Batch 46/466 loss: 0.0638
# Epoch 100: Batch 47/466 loss: 0.0156
# Epoch 100: Batch 48/466 loss: 0.0498
# Epoch 100: Batch 49/466 loss: 0.0612
# Epoch 100: Batch 50/466 loss: 0.0418
# Epoch 100: Batch 51/466 loss: 0.0536
# Epoch 100: Batch 52/466 loss: 0.1331
# Epoch 100: Batch 53/466 loss: 0.0161
# Epoch 100: Batch 54/466 loss: 0.0171
# Epoch 100: Batch 55/466 loss: 0.0878
# Epoch 100: Batch 56/466 loss: 0.0433
# Epoch 100: Batch 57/466 loss: 0.0702
# Epoch 100: Batch 58/466 loss: 0.0589
# Epoch 100: Batch 59/466 loss: 0.0650
# Epoch 100: Batch 60/466 loss: 0.0441
# Epoch 100: Batch 61/466 loss: 0.0388
# Epoch 100: Batch 62/466 loss: 0.0542
# Epoch 100: Batch 63/466 loss: 0.0537
# Epoch 100: Batch 64/466 loss: 0.0819
# Epoch 100: Batch 65/466 loss: 0.0359
# Epoch 100: Batch 66/466 loss: 0.0710
# Epoch 100: Batch 67/466 loss: 0.0120
# Epoch 100: Batch 68/466 loss: 0.0498
# Epoch 100: Batch 69/466 loss: 0.0572
# Epoch 100: Batch 70/466 loss: 0.0380
# Epoch 100: Batch 71/466 loss: 0.0414
# Epoch 100: Batch 72/466 loss: 0.0292
# Epoch 100: Batch 73/466 loss: 0.0535
# Epoch 100: Batch 74/466 loss: 0.0788
# Epoch 100: Batch 75/466 loss: 0.0224
# Epoch 100: Batch 76/466 loss: 0.0563
# Epoch 100: Batch 77/466 loss: 0.0410
# Epoch 100: Batch 78/466 loss: 0.0352
# Epoch 100: Batch 79/466 loss: 0.0614
# Epoch 100: Batch 80/466 loss: 0.0089
# Epoch 100: Batch 81/466 loss: 0.0829
# Epoch 100: Batch 82/466 loss: 0.0685
# Epoch 100: Batch 83/466 loss: 0.0236
# Epoch 100: Batch 84/466 loss: 0.0282
# Epoch 100: Batch 85/466 loss: 0.0150
# Epoch 100: Batch 86/466 loss: 0.0637
# Epoch 100: Batch 87/466 loss: 0.0737
# Epoch 100: Batch 88/466 loss: 0.0471
# Epoch 100: Batch 89/466 loss: 0.0450
# Epoch 100: Batch 90/466 loss: 0.0845
# Epoch 100: Batch 91/466 loss: 0.0607
# Epoch 100: Batch 92/466 loss: 0.0751
# Epoch 100: Batch 93/466 loss: 0.1452
# Epoch 100: Batch 94/466 loss: 0.0786
# Epoch 100: Batch 95/466 loss: 0.0282
# Epoch 100: Batch 96/466 loss: 0.0653
# Epoch 100: Batch 97/466 loss: 0.0578
# Epoch 100: Batch 98/466 loss: 0.0537
# Epoch 100: Batch 99/466 loss: 0.0457
# Epoch 100: Batch 100/466 loss: 0.0259
# Epoch 100: Batch 101/466 loss: 0.1053
# Epoch 100: Batch 102/466 loss: 0.0650
# Epoch 100: Batch 103/466 loss: 0.0165
# Epoch 100: Batch 104/466 loss: 0.0214
# Epoch 100: Batch 105/466 loss: 0.0422
# Epoch 100: Batch 106/466 loss: 0.0327
# Epoch 100: Batch 107/466 loss: 0.0435
# Epoch 100: Batch 108/466 loss: 0.0547
# Epoch 100: Batch 109/466 loss: 0.0457
# Epoch 100: Batch 110/466 loss: 0.1342
# Epoch 100: Batch 111/466 loss: 0.0376
# Epoch 100: Batch 112/466 loss: 0.0701
# Epoch 100: Batch 113/466 loss: 0.0541
# Epoch 100: Batch 114/466 loss: 0.0812
# Epoch 100: Batch 115/466 loss: 0.0243
# Epoch 100: Batch 116/466 loss: 0.0554
# Epoch 100: Batch 117/466 loss: 0.0681
# Epoch 100: Batch 118/466 loss: 0.0247
# Epoch 100: Batch 119/466 loss: 0.0355
# Epoch 100: Batch 120/466 loss: 0.0608
# Epoch 100: Batch 121/466 loss: 0.0440
# Epoch 100: Batch 122/466 loss: 0.0378
# Epoch 100: Batch 123/466 loss: 0.1178
# Epoch 100: Batch 124/466 loss: 0.0497
# Epoch 100: Batch 125/466 loss: 0.0402
# Epoch 100: Batch 126/466 loss: 0.0170
# Epoch 100: Batch 127/466 loss: 0.0274
# Epoch 100: Batch 128/466 loss: 0.1291
# Epoch 100: Batch 129/466 loss: 0.0734
# Epoch 100: Batch 130/466 loss: 0.0539
# Epoch 100: Batch 131/466 loss: 0.0478
# Epoch 100: Batch 132/466 loss: 0.0120
# Epoch 100: Batch 133/466 loss: 0.0313
# Epoch 100: Batch 134/466 loss: 0.0368
# Epoch 100: Batch 135/466 loss: 0.0559
# Epoch 100: Batch 136/466 loss: 0.0356
# Epoch 100: Batch 137/466 loss: 0.0358
# Epoch 100: Batch 138/466 loss: 0.0319
# Epoch 100: Batch 139/466 loss: 0.0538
# Epoch 100: Batch 140/466 loss: 0.1211
# Epoch 100: Batch 141/466 loss: 0.0433
# Epoch 100: Batch 142/466 loss: 0.0579
# Epoch 100: Batch 143/466 loss: 0.0491
# Epoch 100: Batch 144/466 loss: 0.0569
# Epoch 100: Batch 145/466 loss: 0.0366
# Epoch 100: Batch 146/466 loss: 0.0387
# Epoch 100: Batch 147/466 loss: 0.0381
# Epoch 100: Batch 148/466 loss: 0.0834
# Epoch 100: Batch 149/466 loss: 0.0371
# Epoch 100: Batch 150/466 loss: 0.0481
# Epoch 100: Batch 151/466 loss: 0.0426
# Epoch 100: Batch 152/466 loss: 0.0448
# Epoch 100: Batch 153/466 loss: 0.0122
# Epoch 100: Batch 154/466 loss: 0.0122
# Epoch 100: Batch 155/466 loss: 0.0751
# Epoch 100: Batch 156/466 loss: 0.0272
# Epoch 100: Batch 157/466 loss: 0.0158
# Epoch 100: Batch 158/466 loss: 0.0483
# Epoch 100: Batch 159/466 loss: 0.0668
# Epoch 100: Batch 160/466 loss: 0.0287
# Epoch 100: Batch 161/466 loss: 0.0543
# Epoch 100: Batch 162/466 loss: 0.0437
# Epoch 100: Batch 163/466 loss: 0.0864
# Epoch 100: Batch 164/466 loss: 0.0637
# Epoch 100: Batch 165/466 loss: 0.0276
# Epoch 100: Batch 166/466 loss: 0.0458
# Epoch 100: Batch 167/466 loss: 0.0579
# Epoch 100: Batch 168/466 loss: 0.0767
# Epoch 100: Batch 169/466 loss: 0.0435
# Epoch 100: Batch 170/466 loss: 0.0415
# Epoch 100: Batch 171/466 loss: 0.0556
# Epoch 100: Batch 172/466 loss: 0.1438
# Epoch 100: Batch 173/466 loss: 0.0724
# Epoch 100: Batch 174/466 loss: 0.0559
# Epoch 100: Batch 175/466 loss: 0.0657
# Epoch 100: Batch 176/466 loss: 0.0432
# Epoch 100: Batch 177/466 loss: 0.0763
# Epoch 100: Batch 178/466 loss: 0.0357
# Epoch 100: Batch 179/466 loss: 0.0439
# Epoch 100: Batch 180/466 loss: 0.0235
# Epoch 100: Batch 181/466 loss: 0.0446
# Epoch 100: Batch 182/466 loss: 0.1206
# Epoch 100: Batch 183/466 loss: 0.0986
# Epoch 100: Batch 184/466 loss: 0.0840
# Epoch 100: Batch 185/466 loss: 0.0473
# Epoch 100: Batch 186/466 loss: 0.0124
# Epoch 100: Batch 187/466 loss: 0.0419
# Epoch 100: Batch 188/466 loss: 0.0532
# Epoch 100: Batch 189/466 loss: 0.0510
# Epoch 100: Batch 190/466 loss: 0.1095
# Epoch 100: Batch 191/466 loss: 0.0512
# Epoch 100: Batch 192/466 loss: 0.0496
# Epoch 100: Batch 193/466 loss: 0.0648
# Epoch 100: Batch 194/466 loss: 0.0505
# Epoch 100: Batch 195/466 loss: 0.0625
# Epoch 100: Batch 196/466 loss: 0.0633
# Epoch 100: Batch 197/466 loss: 0.0450
# Epoch 100: Batch 198/466 loss: 0.0434
# Epoch 100: Batch 199/466 loss: 0.0180
# Epoch 100: Batch 200/466 loss: 0.0721
# Epoch 100: Batch 201/466 loss: 0.0494
# Epoch 100: Batch 202/466 loss: 0.0466
# Epoch 100: Batch 203/466 loss: 0.0826
# Epoch 100: Batch 204/466 loss: 0.0963
# Epoch 100: Batch 205/466 loss: 0.0383
# Epoch 100: Batch 206/466 loss: 0.0281
# Epoch 100: Batch 207/466 loss: 0.0459
# Epoch 100: Batch 208/466 loss: 0.0446
# Epoch 100: Batch 209/466 loss: 0.0110
# Epoch 100: Batch 210/466 loss: 0.0347
# Epoch 100: Batch 211/466 loss: 0.0269
# Epoch 100: Batch 212/466 loss: 0.0485
# Epoch 100: Batch 213/466 loss: 0.0571
# Epoch 100: Batch 214/466 loss: 0.0942
# Epoch 100: Batch 215/466 loss: 0.0564
# Epoch 100: Batch 216/466 loss: 0.0461
# Epoch 100: Batch 217/466 loss: 0.0490
# Epoch 100: Batch 218/466 loss: 0.0681
# Epoch 100: Batch 219/466 loss: 0.0444
# Epoch 100: Batch 220/466 loss: 0.0364
# Epoch 100: Batch 221/466 loss: 0.0920
# Epoch 100: Batch 222/466 loss: 0.0639
# Epoch 100: Batch 223/466 loss: 0.0608
# Epoch 100: Batch 224/466 loss: 0.0639
# Epoch 100: Batch 225/466 loss: 0.0409
# Epoch 100: Batch 226/466 loss: 0.0796
# Epoch 100: Batch 227/466 loss: 0.0095
# Epoch 100: Batch 228/466 loss: 0.0499
# Epoch 100: Batch 229/466 loss: 0.0374
# Epoch 100: Batch 230/466 loss: 0.0259
# Epoch 100: Batch 231/466 loss: 0.0361
# Epoch 100: Batch 232/466 loss: 0.0701
# Epoch 100: Batch 233/466 loss: 0.0371
# Epoch 100: Batch 234/466 loss: 0.0199
# Epoch 100: Batch 235/466 loss: 0.0725
# Epoch 100: Batch 236/466 loss: 0.0557
# Epoch 100: Batch 237/466 loss: 0.0368
# Epoch 100: Batch 238/466 loss: 0.0216
# Epoch 100: Batch 239/466 loss: 0.0466
# Epoch 100: Batch 240/466 loss: 0.0716
# Epoch 100: Batch 241/466 loss: 0.0069
# Epoch 100: Batch 242/466 loss: 0.0540
# Epoch 100: Batch 243/466 loss: 0.0251
# Epoch 100: Batch 244/466 loss: 0.0872
# Epoch 100: Batch 245/466 loss: 0.0319
# Epoch 100: Batch 246/466 loss: 0.0737
# Epoch 100: Batch 247/466 loss: 0.0422
# Epoch 100: Batch 248/466 loss: 0.0705
# Epoch 100: Batch 249/466 loss: 0.0394
# Epoch 100: Batch 250/466 loss: 0.0583
# Epoch 100: Batch 251/466 loss: 0.0410
# Epoch 100: Batch 252/466 loss: 0.0371
# Epoch 100: Batch 253/466 loss: 0.0561
# Epoch 100: Batch 254/466 loss: 0.0616
# Epoch 100: Batch 255/466 loss: 0.0980
# Epoch 100: Batch 256/466 loss: 0.0328
# Epoch 100: Batch 257/466 loss: 0.0607
# Epoch 100: Batch 258/466 loss: 0.0581
# Epoch 100: Batch 259/466 loss: 0.0252
# Epoch 100: Batch 260/466 loss: 0.0415
# Epoch 100: Batch 261/466 loss: 0.0715
# Epoch 100: Batch 262/466 loss: 0.0545
# Epoch 100: Batch 263/466 loss: 0.0571
# Epoch 100: Batch 264/466 loss: 0.0456
# Epoch 100: Batch 265/466 loss: 0.0291
# Epoch 100: Batch 266/466 loss: 0.0787
# Epoch 100: Batch 267/466 loss: 0.0266
# Epoch 100: Batch 268/466 loss: 0.0537
# Epoch 100: Batch 269/466 loss: 0.0684
# Epoch 100: Batch 270/466 loss: 0.0659
# Epoch 100: Batch 271/466 loss: 0.0385
# Epoch 100: Batch 272/466 loss: 0.0350
# Epoch 100: Batch 273/466 loss: 0.0500
# Epoch 100: Batch 274/466 loss: 0.0361
# Epoch 100: Batch 275/466 loss: 0.0293
# Epoch 100: Batch 276/466 loss: 0.0536
# Epoch 100: Batch 277/466 loss: 0.0211
# Epoch 100: Batch 278/466 loss: 0.0531
# Epoch 100: Batch 279/466 loss: 0.0480
# Epoch 100: Batch 280/466 loss: 0.0448
# Epoch 100: Batch 281/466 loss: 0.0544
# Epoch 100: Batch 282/466 loss: 0.1006
# Epoch 100: Batch 283/466 loss: 0.0286
# Epoch 100: Batch 284/466 loss: 0.0399
# Epoch 100: Batch 285/466 loss: 0.0538
# Epoch 100: Batch 286/466 loss: 0.0801
# Epoch 100: Batch 287/466 loss: 0.0003
# Epoch 100: Batch 288/466 loss: 0.0274
# Epoch 100: Batch 289/466 loss: 0.0175
# Epoch 100: Batch 290/466 loss: 0.0257
# Epoch 100: Batch 291/466 loss: 0.0585
# Epoch 100: Batch 292/466 loss: 0.0098
# Epoch 100: Batch 293/466 loss: 0.0201
# Epoch 100: Batch 294/466 loss: 0.0898
# Epoch 100: Batch 295/466 loss: 0.0692
# Epoch 100: Batch 296/466 loss: 0.0555
# Epoch 100: Batch 297/466 loss: 0.0357
# Epoch 100: Batch 298/466 loss: 0.0541
# Epoch 100: Batch 299/466 loss: 0.0572
# Epoch 100: Batch 300/466 loss: 0.0349
# Epoch 100: Batch 301/466 loss: 0.0684
# Epoch 100: Batch 302/466 loss: 0.0602
# Epoch 100: Batch 303/466 loss: 0.0343
# Epoch 100: Batch 304/466 loss: 0.0624
# Epoch 100: Batch 305/466 loss: 0.0521
# Epoch 100: Batch 306/466 loss: 0.0542
# Epoch 100: Batch 307/466 loss: 0.0693
# Epoch 100: Batch 308/466 loss: 0.0464
# Epoch 100: Batch 309/466 loss: 0.0672
# Epoch 100: Batch 310/466 loss: 0.0420
# Epoch 100: Batch 311/466 loss: 0.0420
# Epoch 100: Batch 312/466 loss: 0.0252
# Epoch 100: Batch 313/466 loss: 0.0639
# Epoch 100: Batch 314/466 loss: 0.0415
# Epoch 100: Batch 315/466 loss: 0.1315
# Epoch 100: Batch 316/466 loss: 0.0540
# Epoch 100: Batch 317/466 loss: 0.0589
# Epoch 100: Batch 318/466 loss: 0.0699
# Epoch 100: Batch 319/466 loss: 0.0809
# Epoch 100: Batch 320/466 loss: 0.0392
# Epoch 100: Batch 321/466 loss: 0.0591
# Epoch 100: Batch 322/466 loss: 0.0672
# Epoch 100: Batch 323/466 loss: 0.0490
# Epoch 100: Batch 324/466 loss: 0.0265
# Epoch 100: Batch 325/466 loss: 0.0341
# Epoch 100: Batch 326/466 loss: 0.0447
# Epoch 100: Batch 327/466 loss: 0.0408
# Epoch 100: Batch 328/466 loss: 0.0998
# Epoch 100: Batch 329/466 loss: 0.0465
# Epoch 100: Batch 330/466 loss: 0.0291
# Epoch 100: Batch 331/466 loss: 0.1012
# Epoch 100: Batch 332/466 loss: 0.0375
# Epoch 100: Batch 333/466 loss: 0.0650
# Epoch 100: Batch 334/466 loss: 0.0486
# Epoch 100: Batch 335/466 loss: 0.0814
# Epoch 100: Batch 336/466 loss: 0.0436
# Epoch 100: Batch 337/466 loss: 0.0608
# Epoch 100: Batch 338/466 loss: 0.0154
# Epoch 100: Batch 339/466 loss: 0.0412
# Epoch 100: Batch 340/466 loss: 0.0654
# Epoch 100: Batch 341/466 loss: 0.0549
# Epoch 100: Batch 342/466 loss: 0.0487
# Epoch 100: Batch 343/466 loss: 0.0637
# Epoch 100: Batch 344/466 loss: 0.0484
# Epoch 100: Batch 345/466 loss: 0.0665
# Epoch 100: Batch 346/466 loss: 0.0243
# Epoch 100: Batch 347/466 loss: 0.0355
# Epoch 100: Batch 348/466 loss: 0.0537
# Epoch 100: Batch 349/466 loss: 0.0256
# Epoch 100: Batch 350/466 loss: 0.0539
# Epoch 100: Batch 351/466 loss: 0.0543
# Epoch 100: Batch 352/466 loss: 0.0203
# Epoch 100: Batch 353/466 loss: 0.0300
# Epoch 100: Batch 354/466 loss: 0.0311
# Epoch 100: Batch 355/466 loss: 0.1165
# Epoch 100: Batch 356/466 loss: 0.0942
# Epoch 100: Batch 357/466 loss: 0.0149
# Epoch 100: Batch 358/466 loss: 0.0345
# Epoch 100: Batch 359/466 loss: 0.1001
# Epoch 100: Batch 360/466 loss: 0.0151
# Epoch 100: Batch 361/466 loss: 0.0650
# Epoch 100: Batch 362/466 loss: 0.0229
# Epoch 100: Batch 363/466 loss: 0.0087
# Epoch 100: Batch 364/466 loss: 0.0806
# Epoch 100: Batch 365/466 loss: 0.0595
# Epoch 100: Batch 366/466 loss: 0.1013
# Epoch 100: Batch 367/466 loss: 0.0563
# Epoch 100: Batch 368/466 loss: 0.0462
# Epoch 100: Batch 369/466 loss: 0.0543
# Epoch 100: Batch 370/466 loss: 0.0474
# Epoch 100: Batch 371/466 loss: 0.0192
# Epoch 100: Batch 372/466 loss: 0.0932
# Epoch 100: Batch 373/466 loss: 0.0112
# Epoch 100: Batch 374/466 loss: 0.0624
# Epoch 100: Batch 375/466 loss: 0.0260
# Epoch 100: Batch 376/466 loss: 0.0468
# Epoch 100: Batch 377/466 loss: 0.1052
# Epoch 100: Batch 378/466 loss: 0.0308
# Epoch 100: Batch 379/466 loss: 0.0485
# Epoch 100: Batch 380/466 loss: 0.0286
# Epoch 100: Batch 381/466 loss: 0.0705
# Epoch 100: Batch 382/466 loss: 0.0557
# Epoch 100: Batch 383/466 loss: 0.0395
# Epoch 100: Batch 384/466 loss: 0.0533
# Epoch 100: Batch 385/466 loss: 0.0343
# Epoch 100: Batch 386/466 loss: 0.0647
# Epoch 100: Batch 387/466 loss: 0.0383
# Epoch 100: Batch 388/466 loss: 0.0489
# Epoch 100: Batch 389/466 loss: 0.0244
# Epoch 100: Batch 390/466 loss: 0.0949
# Epoch 100: Batch 391/466 loss: 0.0300
# Epoch 100: Batch 392/466 loss: 0.0422
# Epoch 100: Batch 393/466 loss: 0.0551
# Epoch 100: Batch 394/466 loss: 0.0850
# Epoch 100: Batch 395/466 loss: 0.0806
# Epoch 100: Batch 396/466 loss: 0.0622
# Epoch 100: Batch 397/466 loss: 0.0838
# Epoch 100: Batch 398/466 loss: 0.0291
# Epoch 100: Batch 399/466 loss: 0.0672
# Epoch 100: Batch 400/466 loss: 0.0418
# Epoch 100: Batch 401/466 loss: 0.0159
# Epoch 100: Batch 402/466 loss: 0.0711
# Epoch 100: Batch 403/466 loss: 0.0170
# Epoch 100: Batch 404/466 loss: 0.1013
# Epoch 100: Batch 405/466 loss: 0.1227
# Epoch 100: Batch 406/466 loss: 0.0311
# Epoch 100: Batch 407/466 loss: 0.0640
# Epoch 100: Batch 408/466 loss: 0.0228
# Epoch 100: Batch 409/466 loss: 0.0483
# Epoch 100: Batch 410/466 loss: 0.0218
# Epoch 100: Batch 411/466 loss: 0.0371
# Epoch 100: Batch 412/466 loss: 0.0695
# Epoch 100: Batch 413/466 loss: 0.0658
# Epoch 100: Batch 414/466 loss: 0.0602
# Epoch 100: Batch 415/466 loss: 0.0981
# Epoch 100: Batch 416/466 loss: 0.0322
# Epoch 100: Batch 417/466 loss: 0.0959
# Epoch 100: Batch 418/466 loss: 0.0482
# Epoch 100: Batch 419/466 loss: 0.1143
# Epoch 100: Batch 420/466 loss: 0.0378
# Epoch 100: Batch 421/466 loss: 0.0083
# Epoch 100: Batch 422/466 loss: 0.0437
# Epoch 100: Batch 423/466 loss: 0.0723
# Epoch 100: Batch 424/466 loss: 0.0376
# Epoch 100: Batch 425/466 loss: 0.0640
# Epoch 100: Batch 426/466 loss: 0.0367
# Epoch 100: Batch 427/466 loss: 0.0414
# Epoch 100: Batch 428/466 loss: 0.0385
# Epoch 100: Batch 429/466 loss: 0.0765
# Epoch 100: Batch 430/466 loss: 0.0623
# Epoch 100: Batch 431/466 loss: 0.0908
# Epoch 100: Batch 432/466 loss: 0.0307
# Epoch 100: Batch 433/466 loss: 0.0353
# Epoch 100: Batch 434/466 loss: 0.0301
# Epoch 100: Batch 435/466 loss: 0.0329
# Epoch 100: Batch 436/466 loss: 0.0588
# Epoch 100: Batch 437/466 loss: 0.0702
# Epoch 100: Batch 438/466 loss: 0.0150
# Epoch 100: Batch 439/466 loss: 0.0671
# Epoch 100: Batch 440/466 loss: 0.1393
# Epoch 100: Batch 441/466 loss: 0.1098
# Epoch 100: Batch 442/466 loss: 0.0983
# Epoch 100: Batch 443/466 loss: 0.0920
# Epoch 100: Batch 444/466 loss: 0.0361
# Epoch 100: Batch 445/466 loss: 0.0568
# Epoch 100: Batch 446/466 loss: 0.0999
# Epoch 100: Batch 447/466 loss: 0.0377
# Epoch 100: Batch 448/466 loss: 0.0410
# Epoch 100: Batch 449/466 loss: 0.0692
# Epoch 100: Batch 450/466 loss: 0.1305
# Epoch 100: Batch 451/466 loss: 0.0724
# Epoch 100: Batch 452/466 loss: 0.0224
# Epoch 100: Batch 453/466 loss: 0.0395
# Epoch 100: Batch 454/466 loss: 0.0533
# Epoch 100: Batch 455/466 loss: 0.0357
# Epoch 100: Batch 456/466 loss: 0.0776
# Epoch 100: Batch 457/466 loss: 0.0135
# Epoch 100: Batch 458/466 loss: 0.0592
# Epoch 100: Batch 459/466 loss: 0.0386
# Epoch 100: Batch 460/466 loss: 0.0498
# Epoch 100: Batch 461/466 loss: 0.0444
# Epoch 100: Batch 462/466 loss: 0.0648
# Epoch 100: Batch 463/466 loss: 0.0408
# Epoch 100: Batch 464/466 loss: 0.0317
# Epoch 100: Batch 465/466 loss: 0.0280
# Epoch 100: Batch 466/466 loss: 0.0365
# Epoch 100 train loss: 0.0526 valid loss: 0.0575
